# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import selenium
from urllib.parse import  urlparse
import time
import lxml
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd
import re
import pickle
from contextlib import suppress

# %%
# 네이버 카페 게시판의 게시물을 수집하는 크롤러(제목, 본문, 등록일)

# %%
# 기본 정보
keyword = "갤워치버즈"
cafe_code = "anycallusershow" #str # cafe.naver.com/cafecode
board_url = "https://cafe.naver.com/ArticleList.nhn?search.clubid=13764661&search.menuid=749&search.boardtype=L&search.totalCount=151&search.cafeId=13764661" # 게시판 url에서 page정보를 제외
page_range = 30  #int
post_num = []
contents_list = []

# %%
# 대상 게시판의 지정된 페이지만큼 글 번호만 추출 (리스트화)

driver = None
driver = webdriver.Chrome("chromedriver")

driver.get("https://nid.naver.com/nidlogin.login")
time.sleep(6)

for i in range(page_range):
    url = board_url + "&search.page=" + str(i+1)  # 주소 지정
        
    driver.get(url)
    
    time.sleep(1) # implicity_wait, 암묵적, 파싱 대기시간. / #time.sleep은 무조건 대기
    
    driver.switch_to.frame('cafe_main')
    
    html = driver.page_source.encode('utf-8')
    soup = BeautifulSoup(html, 'html.parser')
    a = soup.find_all('div', {'class': 'board-number'})
    
    for n in a:
        post_num.append(re.search("[0-9]{2,8}", str(n)).group())

print(post_num)
print(len(post_num))
        
# 대상 게시물의 제목, 본문, 날짜 수집

temp_title = []
temp_content = []
temp_date = []
    
for i in post_num:
    url = "https://cafe.naver.com/" + cafe_code + "/" + i
    
    driver.get(url)
    
    time.sleep(1)
        
    driver.switch_to.frame('cafe_main')

    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    content = soup.find('div', class_='ArticleContentBox')    

    with suppress(AttributeError):   # 제목 없는 게시글
        temp_title.append(content.find('h3',class_='title_text').text.strip()) 
        temp_content.append(content.find("div", class_="article_viewer").text.strip())
        temp_date.append(content.find('div',class_='article_info').find('span',class_='date').text.strip())
        
driver.quit()
# Out:
# ['3766463', '3765166', '3764420', '3764205', '3763953', '3761352', '3761056', '3760873', '3759707', '3759522', '3755783', '3743377', '3741823', '3739250', '3738101', '3737602', '3736853', '3734841', '3732620', '3727850', '3721779', '3720164', '3719044', '3718702', '3715196', '3712307', '3711675', '3711614', '3710626', '3710201', '3709978', '3709182', '3709056', '3703958', '3703704', '3701265', '3701102', '3697994', '3696021', '3693758', '3692592', '3692063', '3691281', '3689492', '3689439', '3688288', '3688037', '3682278', '3681418', '3681008', '3680570', '3680138', '3679310', '3677417', '3675919', '3675459', '3674989', '3674636', '3674233', '3673689', '3672791', '3672655', '3670764', '3667215', '3666814', '3666741', '3665538', '3664233', '3662466', '3661922', '3661828', '3658974', '3655591', '3655523', '3655279', '3653859', '3652894', '3652579', '3652105', '3651699', '3651006', '3650117', '3649476', '3648783', '3645373', '3643943', '3643753', '3643312', '3643056', '3642508', '3642460', '3642063', '3639554', '3639211', '3636382', '3636247', '3636167', '3635598', '3635472', '3633289', '3632382', '3631965', '3631824', '3631673', '3631281', '3630639', '3630371', '3630273', '3629374', '3629075', '3627722', '3627526', '3627336', '3627327', '3627279', '3626636', '3625481', '3625402', '3625173', '3625042', '3624517', '3624220', '3624148', '3623634', '3621986', '3621610', '3621030', '3620047', '3619874', '3619342', '3618970', '3618457', '3617566', '3617539', '3617358', '3616311', '3615986', '3615046', '3614755', '3614736', '3613889', '3613855', '3613119', '3612558', '3611584', '3611547', '3610311', '3610290', '3609645', '3609560', '3608577', '3608127', '3608057', '3608041', '3607666', '3607016', '3606227', '3606080', '3605274', '3604888', '3604875', '3604345', '3604187', '3603537', '3603278', '3603048', '3602067', '3602033', '3601097', '3599615', '3598511', '3598297', '3597773', '3597614', '3597316', '3596559', '3596204', '3596101', '3595407', '3595351', '3594606', '3594516', '3592571', '3592470', '3592314', '3592130', '3590946', '3590937', '3590901', '3590183', '3589876', '3586464', '3585900', '3585065', '3584918', '3584769', '3584733', '3584215', '3583830', '3583326', '3582711', '3582265', '3581949', '3581707', '3581234', '3581015', '3580978', '3580944', '3580914', '3580619', '3580609', '3580344', '3579818', '3579804', '3579713', '3579290', '3579089', '3578638', '3578497', '3578129', '3577709', '3577581', '3577564', '3577312', '3577191', '3576856', '3576835', '3576506', '3576032', '3575771', '3575518', '3575420', '3575350', '3575256', '3574773', '3574701', '3574318', '3574316', '3574199', '3573891', '3573748', '3573493', '3573273', '3573112', '3573103', '3573055', '3573022', '3572997', '3572881', '3572690', '3572553', '3572268', '3571805', '3571723', '3571689', '3571687', '3571647', '3571483', '3571436', '3571180', '3571138', '3570934', '3570866', '3570714', '3570635', '3570620', '3570520', '3570462', '3570420', '3570358', '3570319', '3570316', '3570306', '3570241', '3569961', '3569883', '3569428', '3569280', '3569246', '3569181', '3569119', '3568981', '3568884', '3568816', '3568806', '3568798', '3568676', '3568581', '3568460', '3568135', '3567783', '3557042', '3556698', '3546123', '3536199', '3534262', '3529573', '3529518', '3528225', '3520066', '3516463', '3516085', '3515321', '3514582', '3512287', '3510847', '3505628', '3505593', '3504704', '3495126', '3494061', '3493241', '3492561', '3492084', '3484129', '3484104', '3484080', '3481652', '3479346', '3478967', '3472154', '3471697', '3471304', '3470883', '3469540', '3468118', '3465192', '3464705', '3463599', '3462669', '3461960', '3458008', '3457263', '3454762', '3452985', '3451465', '3451000', '3450665', '3449980', '3449928', '3449447', '3447207', '3447204', '3446008', '3439054', '3437863', '3436061', '3432523', '3431071', '3429885', '3427323', '3427285', '3426337', '3425462', '3425196', '3424526', '3424459', '3424125', '3423645', '3423198', '3423104', '3422777', '3420001', '34191 ...
# 450

# %%
# 내용 확인
arr = np.vstack([np.array(temp_title), np.array(temp_content), np.array(temp_date)])
df = pd.DataFrame(arr).T
# df
df.to_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNsReview/data/" + keyword + ".csv")

# %%
df = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNsReview/data/" + keyword + ".csv", encoding="utf-8", names=["제목", "본문", "등록일"], header=1)
df
# Out:
#                                      제목  \
# 1                                워치4 후기
# 2               폴드 색상 실물보고 그린결정  (워치실착)
# 3                                버즈2입니다
# 4               언팩 모든 제품 간단 후기 + 버즈2 청음
# 5                    버즈 프로 주절주절 글...ㅠㅅㅠ
# ..                                  ...
# 444  버즈 라이브 확실히 액티브 노이즈 캔슬링이 많이 약하긴 하네요
# 445                           버즈 미쳤네요 캬
# 446                버즈라이브 여러분들이라면 무슨색상이?
# 447             갤럭시 워치 액티브 2 선물로 괜찮네요~!
# 448                         워치3 기본 가죽밴드
#
#                                                     본문                등록일
# 1    질문/추천 금지 X\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\...  2021.08.12. 17:32
# 2    위-블랙  ,   아래-그린​블랙인줄알고 만지작 거리던게  그린이엇네요실물 그린 압...  2021.08.12. 13:23
# 3    ​\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...  2021.08.12. 12:19
# 4    ​\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n버즈2 착용...  2021.08.12. 11:15
# 5    질문/추천 금지 X​\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n...  2021.08.10. 20:50
# ..                                                 ...                ...
# 444  팔까 말까 고민하다가 그냥 사은품으로 받은거니 공짜라고 생각하고 쓰자 생각해서​이거...  2020.08.19. 15:15
# 445  ​\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n...  2020.08.18. 01:58
# 446                  흰색 검정 고민중인데여러분들이라면 무슨 색상 하실래요? ㅎㅎ  2020.08.16. 03:25
# 447  폰질문금지\n\n\n\n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n여자...  2020.08.15. 20:21
# 448  판매를 위한 등업도배 (활동제재대상)1일 1개글 작성 (중복글 작성X)대량(업자)판...  2020.08.15. 17:50
#
# [448 rows x 3 columns]
