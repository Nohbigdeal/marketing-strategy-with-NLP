# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import selenium
from urllib.parse import  urlparse
import time
import lxml
import xlrd
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd

# %%
# for word in ["갤럭시", "버즈라이브", "버즈플러스", "갤탭", "갤럭시북", "갤럭시기어"]:
# for word in ["맥북", "M1", "아이폰", "에어팟", "애플워치", "아이패드"]:
# for word in ["미밴드", "홍미노트", "샤오미워치", "어메이즈핏", "샤오미폰", "샤오미휴대폰"]:

# for 문으로 줄이기
samsung1 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/갤럭시20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
samsung2 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/버즈라이브20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
samsung3 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/버즈플러스20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
samsung4 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/갤탭20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
samsung5 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/갤럭시북20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
samsung6 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/갤럭시기어20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)

apple1 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/M120page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
apple2 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/맥북20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
apple3 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/아이폰20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
apple4 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/에어팟20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
apple5 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/애플워치20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
apple6 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/아이패드20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)

shaomi1 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/미밴드20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
shaomi2 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/홍미노트20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
shaomi3 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/샤오미워치20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
shaomi4 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/어메이즈핏20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
shaomi5 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/샤오미폰20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)
shaomi6 = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNS/data/샤오미휴대폰20page.csv", encoding="utf-8", names=["제목", "가격", "등록일", "리뷰수"], header=1)

# %%
samsung1.head()
# Out:
#                                                 제목      가격           등록일   리뷰수
# 1            삼성 갤럭시S21 256GB 팬텀바이올렛 SKT 5G 중고폰 공기계  670000  등록일 2021.03.  6341
# 2           삼성 갤럭시S9 64GB 코랄블루 SKT 중고폰 공기계,중고폰 공기계   80000  등록일 2018.04.  6267
# 3  삼성 갤럭시S10 5G 256GB 크라운실버 SKT 5G 중고폰 공기계,중고폰 공기계  110000  등록일 2019.05.  6169
# 4        삼성 갤럭시노트20울트라 256GB 미스틱브론즈 SKT 5G 중고폰 공기계  780000  등록일 2021.03.  6161
# 5   삼성 갤럭시노트10 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  300000  등록일 2019.10.  6141

# %%
print(shaomi5.isna().sum()) # na값 없음
print(shaomi5.isnull().sum()) #null값 없음
# Out:
# 제목     0
# 가격     0
# 등록일    0
# 리뷰수    0
# dtype: int64
# 제목     0
# 가격     0
# 등록일    0
# 리뷰수    0
# dtype: int64

# %%
# for문으로 이하 내용 정리 必
#samsung1 갤럭시
sam1 = samsung1.copy()
sam1 = sam1[sam1.가격>100000]

sam1_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sam1_filt:
    sam1["필터"] = pd.DataFrame(sam1['제목'].str.contains(i))
    sam1 = sam1[sam1["필터"]==False]
    print(sam1)
# Out:
#                                                      제목      가격           등록일  \
# 1                 삼성 갤럭시S21 256GB 팬텀바이올렛 SKT 5G 중고폰 공기계  670000  등록일 2021.03.
# 3       삼성 갤럭시S10 5G 256GB 크라운실버 SKT 5G 중고폰 공기계,중고폰 공기계  110000  등록일 2019.05.
# 4             삼성 갤럭시노트20울트라 256GB 미스틱브론즈 SKT 5G 중고폰 공기계  780000  등록일 2021.03.
# 5        삼성 갤럭시노트10 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  300000  등록일 2019.10.
# 6     삼성 갤럭시노트10플러스 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  360000  등록일 2019.10.
# ...                                                 ...     ...           ...
# 1593                    삼성전자 삼성 갤럭시 구매사은품제공 요금제자유 KT프라자  347800  등록일 2021.04.
# 1594                 삼성전자 갤럭시 A42 새제품 미개봉 국내정품 SM-A425N  189000  등록일 2021.03.
# 1596             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
# 1598                     [KT기기변경]삼성전자 갤럭시A32 완납폰 공시지원약정  105000  등록일 2021.04.
# 1599             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
#
#        리뷰수     필터
# 1     6341  False
# 3     6169  False
# 4     6161  False
# 5     6141  False
# 6     6111  False
# ...    ...    ...
# 1593    14  False
# 1594    14  False
# 1596    14  False
# 1598    14  False
# 1599    14  False
#
# [1182 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1                 삼성 갤럭시S21 256GB 팬텀바이올렛 SKT 5G 중고폰 공기계  670000  등록일 2021.03.
# 3       삼성 갤럭시S10 5G 256GB 크라운실버 SKT 5G 중고폰 공기계,중고폰 공기계  110000  등록일 2019.05.
# 4             삼성 갤럭시노트20울트라 256GB 미스틱브론즈 SKT 5G 중고폰 공기계  780000  등록일 2021.03.
# 5        삼성 갤럭시노트10 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  300000  등록일 2019.10.
# 6     삼성 갤럭시노트10플러스 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  360000  등록일 2019.10.
# ...                                                 ...     ...           ...
# 1593                    삼성전자 삼성 갤럭시 구매사은품제공 요금제자유 KT프라자  347800  등록일 2021.04.
# 1594                 삼성전자 갤럭시 A42 새제품 미개봉 국내정품 SM-A425N  189000  등록일 2021.03.
# 1596             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
# 1598                     [KT기기변경]삼성전자 갤럭시A32 완납폰 공시지원약정  105000  등록일 2021.04.
# 1599             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
#
#        리뷰수     필터
# 1     6341  False
# 3     6169  False
# 4     6161  False
# 5     6141  False
# 6     6111  False
# ...    ...    ...
# 1593    14  False
# 1594    14  False
# 1596    14  False
# 1598    14  False
# 1599    14  False
#
# [1178 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1                 삼성 갤럭시S21 256GB 팬텀바이올렛 SKT 5G 중고폰 공기계  670000  등록일 2021.03.
# 3       삼성 갤럭시S10 5G 256GB 크라운실버 SKT 5G 중고폰 공기계,중고폰 공기계  110000  등록일 2019.05.
# 4             삼성 갤럭시노트20울트라 256GB 미스틱브론즈 SKT 5G 중고폰 공기계  780000  등록일 2021.03.
# 5        삼성 갤럭시노트10 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  300000  등록일 2019.10.
# 6     삼성 갤럭시노트10플러스 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  360000  등록일 2019.10.
# ...                                                 ...     ...           ...
# 1593                    삼성전자 삼성 갤럭시 구매사은품제공 요금제자유 KT프라자  347800  등록일 2021.04.
# 1594                 삼성전자 갤럭시 A42 새제품 미개봉 국내정품 SM-A425N  189000  등록일 2021.03.
# 1596             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
# 1598                     [KT기기변경]삼성전자 갤럭시A32 완납폰 공시지원약정  105000  등록일 2021.04.
# 1599             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
#
#        리뷰수     필터
# 1     6341  False
# 3     6169  False
# 4     6161  False
# 5     6141  False
# 6     6111  False
# ...    ...    ...
# 1593    14  False
# 1594    14  False
# 1596    14  False
# 1598    14  False
# 1599    14  False
#
# [1178 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1                 삼성 갤럭시S21 256GB 팬텀바이올렛 SKT 5G 중고폰 공기계  670000  등록일 2021.03.
# 3       삼성 갤럭시S10 5G 256GB 크라운실버 SKT 5G 중고폰 공기계,중고폰 공기계  110000  등록일 2019.05.
# 4             삼성 갤럭시노트20울트라 256GB 미스틱브론즈 SKT 5G 중고폰 공기계  780000  등록일 2021.03.
# 5        삼성 갤럭시노트10 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  300000  등록일 2019.10.
# 6     삼성 갤럭시노트10플러스 256GB 아우라글로우 SKT 5G 중고폰 공기계,중고폰 공기계  360000  등록일 2019.10.
# ...                                                 ...     ...           ...
# 1593                    삼성전자 삼성 갤럭시 구매사은품제공 요금제자유 KT프라자  347800  등록일 2021.04.
# 1594                 삼성전자 갤럭시 A42 새제품 미개봉 국내정품 SM-A425N  189000  등록일 2021.03.
# 1596             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
# 1598                     [KT기기변경]삼성전자 갤럭시A32 완납폰 공시지원약정  105000  등록일 2021.04.
# 1599             [완납폰][SKT 기기변경] 갤럭시 노트20 Ultra 5G 공시지원  610000  등록일 2021.01.
#
#        리뷰수     필터
# 1     6341  False
# 3     6169  False
# 4     6161  False
# 5     6141  False
# 6     6111  False
# ...    ...    ...
# 1593    14  False
# 1594    14  False
# 1596    14  False
# 1598    14  False
# 1599    14  False
#
# [1178 rows x 5 columns]

# %%
#samsung2 버즈라이브
sam2 = samsung2.copy()
sam2 = sam2[sam2.가격>100000]
sam2_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sam2_filt:
    sam2["필터"] = pd.DataFrame(sam2['제목'].str.contains(i))
    sam2 = sam2[sam2["필터"]==False]
    print(sam2)
# Out:
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1483              삼성전자 (빠른직구)갤럭시 버즈 라이브 SM-R180 미스틱 화이트  106930  등록일 2020.08.
# 1485                     [삼성] 국내정품 갤럭시 버즈라이브 블루투스이어폰 레드  102830  등록일 2021.06.
# 1486                  삼성전자 갤럭시버즈 라이브 블루투스 무선이어폰 SM-R180  129000  등록일 2021.01.
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1483     11  False
# 1485     11  False
# 1486     10  False
# 1516     10  False
# 1547     10  False
#
# [148 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1483              삼성전자 (빠른직구)갤럭시 버즈 라이브 SM-R180 미스틱 화이트  106930  등록일 2020.08.
# 1485                     [삼성] 국내정품 갤럭시 버즈라이브 블루투스이어폰 레드  102830  등록일 2021.06.
# 1486                  삼성전자 갤럭시버즈 라이브 블루투스 무선이어폰 SM-R180  129000  등록일 2021.01.
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1483     11  False
# 1485     11  False
# 1486     10  False
# 1516     10  False
# 1547     10  False
#
# [147 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1483              삼성전자 (빠른직구)갤럭시 버즈 라이브 SM-R180 미스틱 화이트  106930  등록일 2020.08.
# 1485                     [삼성] 국내정품 갤럭시 버즈라이브 블루투스이어폰 레드  102830  등록일 2021.06.
# 1486                  삼성전자 갤럭시버즈 라이브 블루투스 무선이어폰 SM-R180  129000  등록일 2021.01.
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1483     11  False
# 1485     11  False
# 1486     10  False
# 1516     10  False
# 1547     10  False
#
# [147 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1483              삼성전자 (빠른직구)갤럭시 버즈 라이브 SM-R180 미스틱 화이트  106930  등록일 2020.08.
# 1485                     [삼성] 국내정품 갤럭시 버즈라이브 블루투스이어폰 레드  102830  등록일 2021.06.
# 1486                  삼성전자 갤럭시버즈 라이브 블루투스 무선이어폰 SM-R180  129000  등록일 2021.01.
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1483     11  False
# 1485     11  False
# 1486     10  False
# 1516     10  False
# 1547     10  False
#
# [147 rows x 5 columns]

# %%
#samsung3 버즈플러스
sam3 = samsung3.copy()
sam3 = sam3[sam3.가격>100000]
sam3_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sam3_filt:
    sam3["필터"] = pd.DataFrame(sam3['제목'].str.contains(i))
    sam3 = sam3[sam3["필터"]==False]
    print(sam3)
# Out:
#                                                     제목      가격           등록일  \
# 3                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 4                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 7    [혜택가 89,060원]갤럭시 버즈 플러스 블루투스이어폰 SM-R175 / AKG튜...  109000  등록일 2020.02.
# 8                  삼성전자 갤럭시 버즈 플러스 블루투스 무선 이어폰 SM-R175  109000  등록일 2020.02.
# 10                             삼성전자 갤럭시 버즈 플러스 BTS 에디션  199220  등록일 2021.01.
# ..                                                 ...     ...           ...
# 227                     정품 갤럭시 버즈 플러스 SM-R175 블루투스 이어폰  233750  등록일 2020.05.
# 228                    삼성전자 갤럭시 버즈 플러스 SM-R175 무선이어폰 H  139960  등록일 2020.02.
# 229                      [삼성국내정품] 갤럭시버즈플러스 BTS에디션 블루투스  199220  등록일 2021.04.
# 236                    삼성 갤럭시버즈 플러스 제니레드 무선이어폰 SM-R175  179000  등록일 2021.05.
# 239                     삼성전자 갤럭시버즈 플러스 (블랙) 우체국택배 당일발송  149040  등록일 2020.02.
#
#        리뷰수     필터
# 3    16298  False
# 4    16298  False
# 7     5092  False
# 8     4672  False
# 10    2131  False
# ..     ...    ...
# 227      4  False
# 228      4  False
# 229      4  False
# 236      3  False
# 239      3  False
#
# [103 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 3                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 4                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 7    [혜택가 89,060원]갤럭시 버즈 플러스 블루투스이어폰 SM-R175 / AKG튜...  109000  등록일 2020.02.
# 8                  삼성전자 갤럭시 버즈 플러스 블루투스 무선 이어폰 SM-R175  109000  등록일 2020.02.
# 10                             삼성전자 갤럭시 버즈 플러스 BTS 에디션  199220  등록일 2021.01.
# ..                                                 ...     ...           ...
# 227                     정품 갤럭시 버즈 플러스 SM-R175 블루투스 이어폰  233750  등록일 2020.05.
# 228                    삼성전자 갤럭시 버즈 플러스 SM-R175 무선이어폰 H  139960  등록일 2020.02.
# 229                      [삼성국내정품] 갤럭시버즈플러스 BTS에디션 블루투스  199220  등록일 2021.04.
# 236                    삼성 갤럭시버즈 플러스 제니레드 무선이어폰 SM-R175  179000  등록일 2021.05.
# 239                     삼성전자 갤럭시버즈 플러스 (블랙) 우체국택배 당일발송  149040  등록일 2020.02.
#
#        리뷰수     필터
# 3    16298  False
# 4    16298  False
# 7     5092  False
# 8     4672  False
# 10    2131  False
# ..     ...    ...
# 227      4  False
# 228      4  False
# 229      4  False
# 236      3  False
# 239      3  False
#
# [103 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 3                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 4                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 7    [혜택가 89,060원]갤럭시 버즈 플러스 블루투스이어폰 SM-R175 / AKG튜...  109000  등록일 2020.02.
# 8                  삼성전자 갤럭시 버즈 플러스 블루투스 무선 이어폰 SM-R175  109000  등록일 2020.02.
# 10                             삼성전자 갤럭시 버즈 플러스 BTS 에디션  199220  등록일 2021.01.
# ..                                                 ...     ...           ...
# 227                     정품 갤럭시 버즈 플러스 SM-R175 블루투스 이어폰  233750  등록일 2020.05.
# 228                    삼성전자 갤럭시 버즈 플러스 SM-R175 무선이어폰 H  139960  등록일 2020.02.
# 229                      [삼성국내정품] 갤럭시버즈플러스 BTS에디션 블루투스  199220  등록일 2021.04.
# 236                    삼성 갤럭시버즈 플러스 제니레드 무선이어폰 SM-R175  179000  등록일 2021.05.
# 239                     삼성전자 갤럭시버즈 플러스 (블랙) 우체국택배 당일발송  149040  등록일 2020.02.
#
#        리뷰수     필터
# 3    16298  False
# 4    16298  False
# 7     5092  False
# 8     4672  False
# 10    2131  False
# ..     ...    ...
# 227      4  False
# 228      4  False
# 229      4  False
# 236      3  False
# 239      3  False
#
# [103 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 3                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 4                       삼성전자 갤럭시버즈 플러스 블루투스이어폰 SM-R175  109000  등록일 2020.02.
# 7    [혜택가 89,060원]갤럭시 버즈 플러스 블루투스이어폰 SM-R175 / AKG튜...  109000  등록일 2020.02.
# 8                  삼성전자 갤럭시 버즈 플러스 블루투스 무선 이어폰 SM-R175  109000  등록일 2020.02.
# 10                             삼성전자 갤럭시 버즈 플러스 BTS 에디션  199220  등록일 2021.01.
# ..                                                 ...     ...           ...
# 227                     정품 갤럭시 버즈 플러스 SM-R175 블루투스 이어폰  233750  등록일 2020.05.
# 228                    삼성전자 갤럭시 버즈 플러스 SM-R175 무선이어폰 H  139960  등록일 2020.02.
# 229                      [삼성국내정품] 갤럭시버즈플러스 BTS에디션 블루투스  199220  등록일 2021.04.
# 236                    삼성 갤럭시버즈 플러스 제니레드 무선이어폰 SM-R175  179000  등록일 2021.05.
# 239                     삼성전자 갤럭시버즈 플러스 (블랙) 우체국택배 당일발송  149040  등록일 2020.02.
#
#        리뷰수     필터
# 3    16298  False
# 4    16298  False
# 7     5092  False
# 8     4672  False
# 10    2131  False
# ..     ...    ...
# 227      4  False
# 228      4  False
# 229      4  False
# 236      3  False
# 239      3  False
#
# [103 rows x 5 columns]

# %%
#samsung4 갤탭         # 소거(자료 없음)
sam4 = samsung4.copy()
sam4 = sam4[sam4.가격>50000]
sam4_filt = ["케이스", "충전기", "필름", "북커버"]
for i in sam4_filt:
    sam4["필터"] = pd.DataFrame(sam4['제목'].str.contains(i))
    sam4 = sam4[sam4["필터"]==False]
    print(sam4)
# Out:
# Empty DataFrame
# Columns: [제목, 가격, 등록일, 리뷰수, 필터]
# Index: []
# Empty DataFrame
# Columns: [제목, 가격, 등록일, 리뷰수, 필터]
# Index: []
# Empty DataFrame
# Columns: [제목, 가격, 등록일, 리뷰수, 필터]
# Index: []
# Empty DataFrame
# Columns: [제목, 가격, 등록일, 리뷰수, 필터]
# Index: []

# %%
#samsung5 갤럭시북
sam5 = samsung5.copy()
sam5 = sam5[sam5.가격>100000]
sam5_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sam5_filt:
    sam5["필터"] = pd.DataFrame(sam5['제목'].str.contains(i))
    sam5 = sam5[sam5["필터"]==False]
    print(sam5)
# Out:
#                                                     제목       가격           등록일  \
# 1                         삼성전자 갤럭시북 플렉스 NT950QCG-X716A  1899970  등록일 2019.12.
# 2    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 3    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 4                          삼성전자 갤럭시북 플렉스 NT950QCT-A58A  1669780  등록일 2019.12.
# 5                         삼성전자 갤럭시북 이온2 NT950XDZ-A58AW  1498990  등록일 2020.12.
# ..                                                 ...      ...           ...
# 635          삼성 갤럭시북 플렉스 알파 NT750QCJ-KF58 SSD 512GB 교체  1560400  등록일 2020.09.
# 636         삼성 삼성갤럭시북 플렉스알파 NT730QCR-A716A-10 WIN10PRO  1493480  등록일 2021.02.
# 637  삼성전자 갤럭시북 플렉스 알파 NT730QCR-A516A 파생 Win10 설치/ 대...  1599000  등록일 2020.07.
# 638               삼성 GOD11 삼성전자 갤럭시북 이온 NT950XDA-KC58W  1650270  등록일 2021.06.
# 639              삼성전자 이온 NT950XCJ-X58L / 마우스 파우치 한컴오피스  1752700  등록일 2020.01.
#
#       리뷰수     필터
# 1    5123  False
# 2    4275  False
# 3    4275  False
# 4    3738  False
# 5    3535  False
# ..    ...    ...
# 635     7  False
# 636     7  False
# 637     7  False
# 638     7  False
# 639     7  False
#
# [576 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1                         삼성전자 갤럭시북 플렉스 NT950QCG-X716A  1899970  등록일 2019.12.
# 2    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 3    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 4                          삼성전자 갤럭시북 플렉스 NT950QCT-A58A  1669780  등록일 2019.12.
# 5                         삼성전자 갤럭시북 이온2 NT950XDZ-A58AW  1498990  등록일 2020.12.
# ..                                                 ...      ...           ...
# 635          삼성 갤럭시북 플렉스 알파 NT750QCJ-KF58 SSD 512GB 교체  1560400  등록일 2020.09.
# 636         삼성 삼성갤럭시북 플렉스알파 NT730QCR-A716A-10 WIN10PRO  1493480  등록일 2021.02.
# 637  삼성전자 갤럭시북 플렉스 알파 NT730QCR-A516A 파생 Win10 설치/ 대...  1599000  등록일 2020.07.
# 638               삼성 GOD11 삼성전자 갤럭시북 이온 NT950XDA-KC58W  1650270  등록일 2021.06.
# 639              삼성전자 이온 NT950XCJ-X58L / 마우스 파우치 한컴오피스  1752700  등록일 2020.01.
#
#       리뷰수     필터
# 1    5123  False
# 2    4275  False
# 3    4275  False
# 4    3738  False
# 5    3535  False
# ..    ...    ...
# 635     7  False
# 636     7  False
# 637     7  False
# 638     7  False
# 639     7  False
#
# [576 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1                         삼성전자 갤럭시북 플렉스 NT950QCG-X716A  1899970  등록일 2019.12.
# 2    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 3    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 4                          삼성전자 갤럭시북 플렉스 NT950QCT-A58A  1669780  등록일 2019.12.
# 5                         삼성전자 갤럭시북 이온2 NT950XDZ-A58AW  1498990  등록일 2020.12.
# ..                                                 ...      ...           ...
# 635          삼성 갤럭시북 플렉스 알파 NT750QCJ-KF58 SSD 512GB 교체  1560400  등록일 2020.09.
# 636         삼성 삼성갤럭시북 플렉스알파 NT730QCR-A716A-10 WIN10PRO  1493480  등록일 2021.02.
# 637  삼성전자 갤럭시북 플렉스 알파 NT730QCR-A516A 파생 Win10 설치/ 대...  1599000  등록일 2020.07.
# 638               삼성 GOD11 삼성전자 갤럭시북 이온 NT950XDA-KC58W  1650270  등록일 2021.06.
# 639              삼성전자 이온 NT950XCJ-X58L / 마우스 파우치 한컴오피스  1752700  등록일 2020.01.
#
#       리뷰수     필터
# 1    5123  False
# 2    4275  False
# 3    4275  False
# 4    3738  False
# 5    3535  False
# ..    ...    ...
# 635     7  False
# 636     7  False
# 637     7  False
# 638     7  False
# 639     7  False
#
# [576 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1                         삼성전자 갤럭시북 플렉스 NT950QCG-X716A  1899970  등록일 2019.12.
# 2    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 3    [최종 102만] 삼성전자 갤럭시북 이온 NT950XCR-G58A 게이밍노트북 인강노트북  1199000  등록일 2019.12.
# 4                          삼성전자 갤럭시북 플렉스 NT950QCT-A58A  1669780  등록일 2019.12.
# 5                         삼성전자 갤럭시북 이온2 NT950XDZ-A58AW  1498990  등록일 2020.12.
# ..                                                 ...      ...           ...
# 635          삼성 갤럭시북 플렉스 알파 NT750QCJ-KF58 SSD 512GB 교체  1560400  등록일 2020.09.
# 636         삼성 삼성갤럭시북 플렉스알파 NT730QCR-A716A-10 WIN10PRO  1493480  등록일 2021.02.
# 637  삼성전자 갤럭시북 플렉스 알파 NT730QCR-A516A 파생 Win10 설치/ 대...  1599000  등록일 2020.07.
# 638               삼성 GOD11 삼성전자 갤럭시북 이온 NT950XDA-KC58W  1650270  등록일 2021.06.
# 639              삼성전자 이온 NT950XCJ-X58L / 마우스 파우치 한컴오피스  1752700  등록일 2020.01.
#
#       리뷰수     필터
# 1    5123  False
# 2    4275  False
# 3    4275  False
# 4    3738  False
# 5    3535  False
# ..    ...    ...
# 635     7  False
# 636     7  False
# 637     7  False
# 638     7  False
# 639     7  False
#
# [576 rows x 5 columns]

# %%
#samsung6 갤럭시기어 > 갤럭시 워치가 더 많음
sam6 = samsung6.copy()
# sam6 = sam6[sam6.가격>100000]
sam6_filt = ["케이스", "충전기", "VR", "스트랩", "밴드", "시계줄"]
for i in sam6_filt:
    sam6["필터"] = pd.DataFrame(sam6['제목'].str.contains(i))
    sam6 = sam6[sam6["필터"]==False]
    print(sam6)
# Out:
#                                                    제목      가격           등록일  \
# 2   갤럭시 워치 시계줄 기어 S2 S3 액티브 2 46mm 44mm 42mm 밀레니즈 ...   11400  등록일 2020.07.
# 3                   삼성전자정품/갤럭시기어2 네오 충전도크/GH98-32132A    8910  등록일 2014.07.
# 4                        갤럭시워치 스트랩 가죽 레트로핏(액티브2/1/기어)   19900  등록일 2020.06.
# 5                        갤럭시 기어S3/클래식/프론티어/실리콘/시계줄/밴드   13590  등록일 2017.02.
# 7                   아이엠판다 갤럭시워치 기어S3 46mm 베젤링 PD46BRA    5900  등록일 2021.05.
# ..                                                ...     ...           ...
# 75  갤럭시워치밴드1/2/3 액티브1/2 기어 골프에디션 시계줄 40/41/42/44 스...    9900  등록일 2019.08.
# 76                     갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/흰색02   13590  등록일 2017.02.
# 77                     갤럭시워치 기어 S3 액티브2 메탈 스트랩 고급형 밴드   11020  등록일 2020.08.
# 78                   삼성 갤럭시 기어핏   블랙 - 삼성 갤럭시기어핏 한정수량  205860  등록일 2017.07.
# 79                KT [기기변경]갤럭시기어워치 46mm SM-R825K 웨어러블  269400  등록일 2020.04.
#
#     리뷰수     필터
# 2   106  False
# 3    93  False
# 4    54  False
# 5    37  False
# 7    32  False
# ..  ...    ...
# 75    2  False
# 76    2  False
# 77    2  False
# 78    2  False
# 79    2  False
#
# [76 rows x 5 columns]
#                                                    제목      가격           등록일  \
# 2   갤럭시 워치 시계줄 기어 S2 S3 액티브 2 46mm 44mm 42mm 밀레니즈 ...   11400  등록일 2020.07.
# 3                   삼성전자정품/갤럭시기어2 네오 충전도크/GH98-32132A    8910  등록일 2014.07.
# 4                        갤럭시워치 스트랩 가죽 레트로핏(액티브2/1/기어)   19900  등록일 2020.06.
# 5                        갤럭시 기어S3/클래식/프론티어/실리콘/시계줄/밴드   13590  등록일 2017.02.
# 7                   아이엠판다 갤럭시워치 기어S3 46mm 베젤링 PD46BRA    5900  등록일 2021.05.
# ..                                                ...     ...           ...
# 75  갤럭시워치밴드1/2/3 액티브1/2 기어 골프에디션 시계줄 40/41/42/44 스...    9900  등록일 2019.08.
# 76                     갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/흰색02   13590  등록일 2017.02.
# 77                     갤럭시워치 기어 S3 액티브2 메탈 스트랩 고급형 밴드   11020  등록일 2020.08.
# 78                   삼성 갤럭시 기어핏   블랙 - 삼성 갤럭시기어핏 한정수량  205860  등록일 2017.07.
# 79                KT [기기변경]갤럭시기어워치 46mm SM-R825K 웨어러블  269400  등록일 2020.04.
#
#     리뷰수     필터
# 2   106  False
# 3    93  False
# 4    54  False
# 5    37  False
# 7    32  False
# ..  ...    ...
# 75    2  False
# 76    2  False
# 77    2  False
# 78    2  False
# 79    2  False
#
# [73 rows x 5 columns]
#                                                    제목      가격           등록일  \
# 2   갤럭시 워치 시계줄 기어 S2 S3 액티브 2 46mm 44mm 42mm 밀레니즈 ...   11400  등록일 2020.07.
# 3                   삼성전자정품/갤럭시기어2 네오 충전도크/GH98-32132A    8910  등록일 2014.07.
# 4                        갤럭시워치 스트랩 가죽 레트로핏(액티브2/1/기어)   19900  등록일 2020.06.
# 5                        갤럭시 기어S3/클래식/프론티어/실리콘/시계줄/밴드   13590  등록일 2017.02.
# 7                   아이엠판다 갤럭시워치 기어S3 46mm 베젤링 PD46BRA    5900  등록일 2021.05.
# ..                                                ...     ...           ...
# 75  갤럭시워치밴드1/2/3 액티브1/2 기어 골프에디션 시계줄 40/41/42/44 스...    9900  등록일 2019.08.
# 76                     갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/흰색02   13590  등록일 2017.02.
# 77                     갤럭시워치 기어 S3 액티브2 메탈 스트랩 고급형 밴드   11020  등록일 2020.08.
# 78                   삼성 갤럭시 기어핏   블랙 - 삼성 갤럭시기어핏 한정수량  205860  등록일 2017.07.
# 79                KT [기기변경]갤럭시기어워치 46mm SM-R825K 웨어러블  269400  등록일 2020.04.
#
#     리뷰수     필터
# 2   106  False
# 3    93  False
# 4    54  False
# 5    37  False
# 7    32  False
# ..  ...    ...
# 75    2  False
# 76    2  False
# 77    2  False
# 78    2  False
# 79    2  False
#
# [73 rows x 5 columns]
#                                                    제목      가격           등록일  \
# 2   갤럭시 워치 시계줄 기어 S2 S3 액티브 2 46mm 44mm 42mm 밀레니즈 ...   11400  등록일 2020.07.
# 3                   삼성전자정품/갤럭시기어2 네오 충전도크/GH98-32132A    8910  등록일 2014.07.
# 4                        갤럭시워치 스트랩 가죽 레트로핏(액티브2/1/기어)   19900  등록일 2020.06.
# 5                        갤럭시 기어S3/클래식/프론티어/실리콘/시계줄/밴드   13590  등록일 2017.02.
# 7                   아이엠판다 갤럭시워치 기어S3 46mm 베젤링 PD46BRA    5900  등록일 2021.05.
# ..                                                ...     ...           ...
# 75  갤럭시워치밴드1/2/3 액티브1/2 기어 골프에디션 시계줄 40/41/42/44 스...    9900  등록일 2019.08.
# 76                     갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/흰색02   13590  등록일 2017.02.
# 77                     갤럭시워치 기어 S3 액티브2 메탈 스트랩 고급형 밴드   11020  등록일 2020.08.
# 78                   삼성 갤럭시 기어핏   블랙 - 삼성 갤럭시기어핏 한정수량  205860  등록일 2017.07.
# 79                KT [기기변경]갤럭시기어워치 46mm SM-R825K 웨어러블  269400  등록일 2020.04.
#
#     리뷰수     필터
# 2   106  False
# 3    93  False
# 4    54  False
# 5    37  False
# 7    32  False
# ..  ...    ...
# 75    2  False
# 76    2  False
# 77    2  False
# 78    2  False
# 79    2  False
#
# [73 rows x 5 columns]
#                                                    제목      가격           등록일  \
# 2   갤럭시 워치 시계줄 기어 S2 S3 액티브 2 46mm 44mm 42mm 밀레니즈 ...   11400  등록일 2020.07.
# 3                   삼성전자정품/갤럭시기어2 네오 충전도크/GH98-32132A    8910  등록일 2014.07.
# 4                        갤럭시워치 스트랩 가죽 레트로핏(액티브2/1/기어)   19900  등록일 2020.06.
# 5                        갤럭시 기어S3/클래식/프론티어/실리콘/시계줄/밴드   13590  등록일 2017.02.
# 7                   아이엠판다 갤럭시워치 기어S3 46mm 베젤링 PD46BRA    5900  등록일 2021.05.
# ..                                                ...     ...           ...
# 75  갤럭시워치밴드1/2/3 액티브1/2 기어 골프에디션 시계줄 40/41/42/44 스...    9900  등록일 2019.08.
# 76                     갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/흰색02   13590  등록일 2017.02.
# 77                     갤럭시워치 기어 S3 액티브2 메탈 스트랩 고급형 밴드   11020  등록일 2020.08.
# 78                   삼성 갤럭시 기어핏   블랙 - 삼성 갤럭시기어핏 한정수량  205860  등록일 2017.07.
# 79                KT [기기변경]갤럭시기어워치 46mm SM-R825K 웨어러블  269400  등록일 2020.04.
#
#     리뷰수     필터
# 2   106  False
# 3    93  False
# 4    54  False
# 5    37  False
# 7    32  False
# ..  ...    ...
# 75    2  False
# 76    2  False
# 77    2  False
# 78    2  False
# 79    2  False
#
# [70 rows x 5 columns]
#                                                    제목      가격           등록일  \
# 3                   삼성전자정품/갤럭시기어2 네오 충전도크/GH98-32132A    8910  등록일 2014.07.
# 5                        갤럭시 기어S3/클래식/프론티어/실리콘/시계줄/밴드   13590  등록일 2017.02.
# 7                   아이엠판다 갤럭시워치 기어S3 46mm 베젤링 PD46BRA    5900  등록일 2021.05.
# 8    갤럭시워치 액티브 기어S3프론티어 S2클래식 스포츠 46mm/42mm 강화유리필름 2매    8900  등록일 2020.07.
# 9                        갤럭시기어S3 클래식/프론티어 아웃도어 시계줄/무배   26750  등록일 2017.02.
# 10                        갤럭시기어핏2프로/갤럭시기어핏/갤럭시기어핏2/갤럭   11680  등록일 2019.05.
# 11                          무배/기어 스포츠 강화 유리/갤럭시 기어스포츠    6440  등록일 2017.10.
# 12  갤럭시워치밴드 1/2/3 액티브1/2 기어 골프에디션 시계줄 메쉬 40/41/42/...   17370  등록일 2019.08.
# 13                         삼성전자 삼성 갤럭시 기어s2 클래식 소프트밴드    8900  등록일 2019.05.
# 14                     기어 갤럭시기어핏2프로/갤럭시기어핏/갤럭시기어핏2/갤럭   11680  등록일 2019.05.
# 15                      블랙 메탈밴드 기어S3 시계줄 기어S2 시계줄 갤럭시   24630  등록일 2021.05.
# 17                      갤럭시 기어 S3/클래식/프론티어/캔버스/시계줄/밴드   18990  등록일 2017.05.
# 19                     갤럭시 기어 S3/클래식/프론티어/소/가죽/시계줄/밴드   18990  등록일 2017.02.
# 20                         갤럭시 기어S3 프론티어/클래식/LTE 삼성페이  168000  등록일 2021.01.
# 21  삼성 갤럭시 기어 S3 프론티어 스마트워치 Galaxy Gear S3 Frontie...  247300  등록일 2019.10.
# 26  [하이마트][번호이동][할부원금:221,900원][SKT] 갤럭시워치 42mm(LT...  221900  등록일 2020.09.
# 27  [하이마트][신규가입][할부원금:221,900원][SKT] 갤럭시워치 42mm(LT...  221900  등록일 2020.09.
# 28  [하이마트][기기변경][할부원금:221,900원][SKT] 갤럭시워치 42mm(LT...  221900  등록일 2020.09.
# 29     갤럭시워치 기어 S2 S3 프론티어 클래식 액티브1 2 기어스포츠 자석 시계줄 밴드   11400  등록일 2020.07.
# 30                     삼성 갤럭시 기어S2 클래식/스포츠/3G/블루투스 정품   98280  등록일 2021.01.
# 31                               대박가이/갤럭시기어1 /SM-V700  150410  등록일 2020.09.
# 32                                         삼성 갤럭시 기어핏  219000  등록일 2019.10.
# 33                         갤럭시 기어S3 프론티어/클래식/LTE 삼성페이  154400  등록일 2021.01.
# 35                      갤럭시워치 46mm/기어S3/실리콘/시계줄/밴드/레드   13590  등록일 2018.11.
# 36                       갤럭시기어S3프론티어/S3클래식/LG어베인/호환메탈   27550  등록일 2016.11.
# 37                     갤럭시워치 46mm/기어S3/실리콘/시계줄/밴드/화이트   13590  등록일 2018.11.
# 38        갤럭시워치 중고 46mm 42mm 스마트워치 웨어러블 스마트시계 기어s2 s3   70000  등록일 2020.12.
# 39                     갤럭시 기어S3/클래식/프론티어/시계줄/밴드/라벤더02   13590  등록일 2017.02.
# 42     삼성전자 갤럭시 워치3 45mm 블루투스 스마트워치 기어 와치 시계 SM-R840N  367000  등록일 2021.03.
# 45                      대박가이/삼성 갤럭시기어S2/3G/스마트워치/써클협찬  129000  등록일 2017.03.
# 47                          무배/기어 스포츠 강화 유리/갤럭시 기어스포츠    5980  등록일 2017.10.
# 49                    갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/검정/03   18990  등록일 2019.07.
# 50                           삼성 갤럭시 기어S3 프론티어 블루투스 A급  171080  등록일 2021.01.
# 51                     삼성 갤럭시 기어S2 클래식/스포츠/3G/블루투스 정품  101420  등록일 2021.01.
# 52                         갤럭시 기어S3 프론티어/클래식/LTE 삼성페이  161280  등록일 2021.01.
# 56                     삼성 갤럭시 기어S2 클래식/스포츠/3G/블루투스 정품   99360  등록일 2021.01.
# 57    갤럭시워치 46mm 갤럭시기어S3 강화유리 보호필름 // 손목 시계 watch i8z    2320  등록일 2019.10.
# 58                     삼성 갤럭시 기어S2 클래식/스포츠/3G/블루투스 정품  108000  등록일 2021.01.
# 59   갤럭시워치 46mm 갤럭시기어S3 강화유리 보호필름 // 시계 클래식 watch h3k    2380  등록일 2020.03.
# 60                   삼성전자 갤럭시 기어 핏 (SM-R370) 밀레니즈 시계줄   14310  등록일 2020.12.
# 62                 삼성정품 갤럭시기어 SM-V700 충전도크 EE-DV700BB   15640  등록일 2020.04.
# 64           [유니커블]갤럭시워치 기어 스테인리스 베젤링 42mm 46mm[바보사랑]    6670  등록일 2021.07.
# 66       갤럭시워치 밴드 123 액티브12 기어 시계줄 골프 에디션 WBG-7202 메쉬   15900  등록일 2019.08.
# 68         갤럭시 기어핏2 마그네틱 이지 밴드 - 편리하고 착용감이 좋은 마그네틱 시계   17860  등록일 2020.05.
# 69       갤럭시 기어S 실리콘 시계줄 밴드 4개 세트 P16 Baaletc Cute Re   35610  등록일 2019.04.
# 70                      대박가이/삼성 갤럭시기어S2/3G/전화단독/스마트워치  129000  등록일 2017.03.
# 71                      갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/브라운   13590  등록일 2017.02.
# 72                      무료배송/갤럭시 기어S2 스포츠 3G 클래식 강화유리    7740  등록일 2016.04.
# 73                  삼성 갤럭시기어S2 SM-R720/R730 기본 무지 시계줄    8840  등록일 2021.06.
# 74                     갤럭시 기어S3/클래식/프론티어/시계줄/밴드/연핑크02   13590  등록일 2017.02.
# 75  갤럭시워치밴드1/2/3 액티브1/2 기어 골프에디션 시계줄 40/41/42/44 스...    9900  등록일 2019.08.
# 76                     갤럭시 기어 S3/클래식/프론티어/시계줄/밴드/흰색02   13590  등록일 2017.02.
# 78                   삼성 갤럭시 기어핏   블랙 - 삼성 갤럭시기어핏 한정수량  205860  등록일 2017.07.
# 79                KT [기기변경]갤럭시기어워치 46mm SM-R825K 웨어러블  269400  등록일 2020.04.
#
#     리뷰수     필터
# 3    93  False
# 5    37  False
# 7    32  False
# 8    28  False
# 9    27  False
# 10   24  False
# 11   19  False
# 12   17  False
# 13   14  False
# 14   13  False
# 15   12  False
# 17   11  False
# 19    9  False
# 20    9  False
# 21    8  False
# 26    7  False
# 27    7  False
# 28    7  False
# 29    7  False
# 30    6  False
# 31    6  False
# 32    6  False
# 33    6  False
# 35    5  False
# 36    5  False
# 37    5  False
# 38    5  False
# 39    4  False
# 42    4  False
# 45    4  False
# 47    4  False
# 49    4  False
# 50    3  False
# 51    3  False
# 52    3  False
# 56    3  False
# 57    3  False
# 58    3  False
# 59    2  False
# 60    2  False
# 62    2  False
# 64    2  False
# 66    2  False
# 68    2  False
# 69    2  False
# 70    2  False
# 71    2  False
# 72    2  False
# 73    2  False
# 74    2  False
# 75    2  False
# 76    2  False
# 78    2  False
# 79    2  False

# %%
#apple1 맥북
app1 = apple1.copy()
app1 = app1[app1.가격>100000]

app1_filt = ["케이스", "충전기", "필름"]
for i in app1_filt:
    app1["필터"] = pd.DataFrame(app1['제목'].str.contains(i))
    app1 = app1[app1["필터"]==False]
    print(app1)
# Out:
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 155  Apple [CTO 업그레이드 사양] MacBook Air 스페이스그레이 Apple...  1870000  등록일 2021.04.
# 156            APPLE 2020 맥북에어 MGN63KH/A (SSD 256GB)-꿈  1163810  등록일 2021.02.
# 157  Apple 맥북 프로 13형 2020년형 M1 CTO 8코어 CPU/8코어 GPU/...  1881600  등록일 2021.03.
# 158   2020년형/ 맥북프로/ M1 칩 512GB/ MYD92KH/A 그레이/ CTO제작상품  1783600  등록일 2021.03.
# 159  Apple 13형 MacBook Pro 실버 Apple M1 512GB MYDC2KH/A  1910000  등록일 2021.02.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 155     3  False
# 156     3  False
# 157     3  False
# 158     3  False
# 159     3  False
#
# [147 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 155  Apple [CTO 업그레이드 사양] MacBook Air 스페이스그레이 Apple...  1870000  등록일 2021.04.
# 156            APPLE 2020 맥북에어 MGN63KH/A (SSD 256GB)-꿈  1163810  등록일 2021.02.
# 157  Apple 맥북 프로 13형 2020년형 M1 CTO 8코어 CPU/8코어 GPU/...  1881600  등록일 2021.03.
# 158   2020년형/ 맥북프로/ M1 칩 512GB/ MYD92KH/A 그레이/ CTO제작상품  1783600  등록일 2021.03.
# 159  Apple 13형 MacBook Pro 실버 Apple M1 512GB MYDC2KH/A  1910000  등록일 2021.02.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 155     3  False
# 156     3  False
# 157     3  False
# 158     3  False
# 159     3  False
#
# [147 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 155  Apple [CTO 업그레이드 사양] MacBook Air 스페이스그레이 Apple...  1870000  등록일 2021.04.
# 156            APPLE 2020 맥북에어 MGN63KH/A (SSD 256GB)-꿈  1163810  등록일 2021.02.
# 157  Apple 맥북 프로 13형 2020년형 M1 CTO 8코어 CPU/8코어 GPU/...  1881600  등록일 2021.03.
# 158   2020년형/ 맥북프로/ M1 칩 512GB/ MYD92KH/A 그레이/ CTO제작상품  1783600  등록일 2021.03.
# 159  Apple 13형 MacBook Pro 실버 Apple M1 512GB MYDC2KH/A  1910000  등록일 2021.02.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 155     3  False
# 156     3  False
# 157     3  False
# 158     3  False
# 159     3  False
#
# [147 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 155  Apple [CTO 업그레이드 사양] MacBook Air 스페이스그레이 Apple...  1870000  등록일 2021.04.
# 156            APPLE 2020 맥북에어 MGN63KH/A (SSD 256GB)-꿈  1163810  등록일 2021.02.
# 157  Apple 맥북 프로 13형 2020년형 M1 CTO 8코어 CPU/8코어 GPU/...  1881600  등록일 2021.03.
# 158   2020년형/ 맥북프로/ M1 칩 512GB/ MYD92KH/A 그레이/ CTO제작상품  1783600  등록일 2021.03.
# 159  Apple 13형 MacBook Pro 실버 Apple M1 512GB MYDC2KH/A  1910000  등록일 2021.02.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 155     3  False
# 156     3  False
# 157     3  False
# 158     3  False
# 159     3  False
#
# [147 rows x 5 columns]

# %%
#apple2 M1
app2 = apple2.copy()
app2 = app2[app2.가격>100000]
app2_filt = ["케이스", "충전기", "필름"]
for i in app2_filt:
    app2["필터"] = pd.DataFrame(app2['제목'].str.contains(i))
    app2 = app2[app2["필터"]==False]
    print(app2)
# Out:
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 392                                 맥북프로 2019 16인치 기본형  3105000  등록일 2019.11.
# 394  Apple 13형 MacBook Pro 스페이스그레이 1TB(2.0쿼드코어/4포트)...  2349000  등록일 2021.04.
# 395  맥북에어 13형 Apple M1칩 512GB SSD 스페이스 그레이 - MGN73K...  1500000  등록일 2020.12.
# 398                   맥북프로 애플 맥북프로 16인치 (MVVK2KH/A) QS  3760000  등록일 2020.11.
# 399          APPLE 2019 맥북프로16 MVVJ2KH/A (SSD 512GB)-꿈  3196000  등록일 2021.01.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 392     6  False
# 394     6  False
# 395     6  False
# 398     6  False
# 399     6  False
#
# [339 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 392                                 맥북프로 2019 16인치 기본형  3105000  등록일 2019.11.
# 394  Apple 13형 MacBook Pro 스페이스그레이 1TB(2.0쿼드코어/4포트)...  2349000  등록일 2021.04.
# 395  맥북에어 13형 Apple M1칩 512GB SSD 스페이스 그레이 - MGN73K...  1500000  등록일 2020.12.
# 398                   맥북프로 애플 맥북프로 16인치 (MVVK2KH/A) QS  3760000  등록일 2020.11.
# 399          APPLE 2019 맥북프로16 MVVJ2KH/A (SSD 512GB)-꿈  3196000  등록일 2021.01.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 392     6  False
# 394     6  False
# 395     6  False
# 398     6  False
# 399     6  False
#
# [339 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1    Apple 2020 맥북 에어 13  스페이스 그레이  M1  512GB  16GB...  1819000  등록일 2021.04.
# 2    Apple 2020 맥북 에어 13  골드  M1  512GB  8GB  MAC O...  1502000  등록일 2021.02.
# 3    Apple 2020 맥북 에어 13  골드  M1  512GB  16GB  MAC ...  1819000  등록일 2021.04.
# 4    Apple 2020 맥북 에어 13  실버  M1  512GB  8GB  MAC O...  1548500  등록일 2021.02.
# 5    Apple 2020 맥북 에어 13  실버  M1  256GB  16GB  MAC ...  1496000  등록일 2021.02.
# ..                                                 ...      ...           ...
# 392                                 맥북프로 2019 16인치 기본형  3105000  등록일 2019.11.
# 394  Apple 13형 MacBook Pro 스페이스그레이 1TB(2.0쿼드코어/4포트)...  2349000  등록일 2021.04.
# 395  맥북에어 13형 Apple M1칩 512GB SSD 스페이스 그레이 - MGN73K...  1500000  등록일 2020.12.
# 398                   맥북프로 애플 맥북프로 16인치 (MVVK2KH/A) QS  3760000  등록일 2020.11.
# 399          APPLE 2019 맥북프로16 MVVJ2KH/A (SSD 512GB)-꿈  3196000  등록일 2021.01.
#
#       리뷰수     필터
# 1    2027  False
# 2    2027  False
# 3    2027  False
# 4    2027  False
# 5    2027  False
# ..    ...    ...
# 392     6  False
# 394     6  False
# 395     6  False
# 398     6  False
# 399     6  False
#
# [339 rows x 5 columns]

# %%
#apple3 아이폰
app3 = apple3.copy()
app3 = app3[app3.가격>100000]
app3_filt = ["케이스", "충전기"]
for i in app3_filt:
    app3["필터"] = pd.DataFrame(app3['제목'].str.contains(i))
    app3 = app3[app3["필터"]==False]
    print(app3)
# Out:
#                                             제목       가격           등록일    리뷰수  \
# 1              Apple 아이폰 SE 2세대 자급제  256GB  블랙   619900  등록일 2020.05.  10640
# 2    Apple 아이폰 SE 2세대 자급제  256GB  (PRODUCT)RED   709740  등록일 2021.07.  10636
# 3          Apple 아이폰 12 Pro 자급제  256GB  퍼시픽 블루  1398280  등록일 2021.02.   7238
# 4              Apple 아이폰 12 Pro 자급제  256GB  실버  1435000  등록일 2021.02.   7238
# 5          Apple 아이폰 12 Pro 자급제  128GB  퍼시픽 블루  1309500  등록일 2021.01.   7238
# ..                                         ...      ...           ...    ...
# 714     Apple 아이폰 12 미니 128GB - 그린 (MGE73KH/A)  1020000  등록일 2021.03.     10
# 716                     Apple 아이폰6s 64GB (SKT)   420300  등록일 2015.10.     10
# 717                       애플 아이폰7 배터리 무상교체 중고폰   149000  등록일 2020.12.      9
# 718         Apple iPhone 12 그린 128GB MGJF3KH/A  1140000  등록일 2021.01.      9
# 719                     아이폰XR 중고 공기계 중고폰 - 폰마블   365000  등록일 2019.10.      9
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 714  False
# 716  False
# 717  False
# 718  False
# 719  False
#
# [629 rows x 5 columns]
#                                             제목       가격           등록일    리뷰수  \
# 1              Apple 아이폰 SE 2세대 자급제  256GB  블랙   619900  등록일 2020.05.  10640
# 2    Apple 아이폰 SE 2세대 자급제  256GB  (PRODUCT)RED   709740  등록일 2021.07.  10636
# 3          Apple 아이폰 12 Pro 자급제  256GB  퍼시픽 블루  1398280  등록일 2021.02.   7238
# 4              Apple 아이폰 12 Pro 자급제  256GB  실버  1435000  등록일 2021.02.   7238
# 5          Apple 아이폰 12 Pro 자급제  128GB  퍼시픽 블루  1309500  등록일 2021.01.   7238
# ..                                         ...      ...           ...    ...
# 714     Apple 아이폰 12 미니 128GB - 그린 (MGE73KH/A)  1020000  등록일 2021.03.     10
# 716                     Apple 아이폰6s 64GB (SKT)   420300  등록일 2015.10.     10
# 717                       애플 아이폰7 배터리 무상교체 중고폰   149000  등록일 2020.12.      9
# 718         Apple iPhone 12 그린 128GB MGJF3KH/A  1140000  등록일 2021.01.      9
# 719                     아이폰XR 중고 공기계 중고폰 - 폰마블   365000  등록일 2019.10.      9
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 714  False
# 716  False
# 717  False
# 718  False
# 719  False
#
# [629 rows x 5 columns]

# %%
#apple4 에어팟
app4 = apple4.copy()
app4 = app4[app4.가격>100000]
app4_filt = ["케이스", "충전기", "낱개", "한쪽", "차이팟"]
for i in app4_filt:
    app4["필터"] = pd.DataFrame(app4['제목'].str.contains(i))
    app4 = app4[app4["필터"]==False]
    print(app4)
# Out:
#                                          제목      가격           등록일    리뷰수  \
# 1              Apple 에어팟 프로  MWP22KH/A  화이트  232070  등록일 2020.01.  69497
# 2                  Apple 에어팟 프로 (MWP22KH/A)  228900  등록일 2019.10.  46895
# 3         Apple 에어팟 2세대 유선충전 모델 (MV7N2KH/A)  142990  등록일 2019.04.  37404
# 4                 Apple 에어팟 1세대 (MMEF2KH/A)  162430  등록일 2016.12.  14121
# 5                  Apple 에어팟 프로 (MWP22KH/A)  269000  등록일 2020.06.  10919
# ..                                      ...     ...           ...    ...
# 631          애플  정품 에어팟 2세대 유선 충전 MV7N2KH/A  169750  등록일 2021.03.      9
# 632       [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  162130  등록일 2021.02.      9
# 636      [애플]정품 에어팟2 유선충전모델 MV7N2KH/A - BUC  156150  등록일 2021.07.      8
# 637         애플 에어팟 프로 Airpods Pro 애플코리아정품 G  258680  등록일 2020.12.      8
# 638  [애플] [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  167500  등록일 2021.01.      8
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 631  False
# 632  False
# 636  False
# 637  False
# 638  False
#
# [368 rows x 5 columns]
#                                          제목      가격           등록일    리뷰수  \
# 1              Apple 에어팟 프로  MWP22KH/A  화이트  232070  등록일 2020.01.  69497
# 2                  Apple 에어팟 프로 (MWP22KH/A)  228900  등록일 2019.10.  46895
# 3         Apple 에어팟 2세대 유선충전 모델 (MV7N2KH/A)  142990  등록일 2019.04.  37404
# 4                 Apple 에어팟 1세대 (MMEF2KH/A)  162430  등록일 2016.12.  14121
# 5                  Apple 에어팟 프로 (MWP22KH/A)  269000  등록일 2020.06.  10919
# ..                                      ...     ...           ...    ...
# 631          애플  정품 에어팟 2세대 유선 충전 MV7N2KH/A  169750  등록일 2021.03.      9
# 632       [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  162130  등록일 2021.02.      9
# 636      [애플]정품 에어팟2 유선충전모델 MV7N2KH/A - BUC  156150  등록일 2021.07.      8
# 637         애플 에어팟 프로 Airpods Pro 애플코리아정품 G  258680  등록일 2020.12.      8
# 638  [애플] [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  167500  등록일 2021.01.      8
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 631  False
# 632  False
# 636  False
# 637  False
# 638  False
#
# [367 rows x 5 columns]
#                                          제목      가격           등록일    리뷰수  \
# 1              Apple 에어팟 프로  MWP22KH/A  화이트  232070  등록일 2020.01.  69497
# 2                  Apple 에어팟 프로 (MWP22KH/A)  228900  등록일 2019.10.  46895
# 3         Apple 에어팟 2세대 유선충전 모델 (MV7N2KH/A)  142990  등록일 2019.04.  37404
# 4                 Apple 에어팟 1세대 (MMEF2KH/A)  162430  등록일 2016.12.  14121
# 5                  Apple 에어팟 프로 (MWP22KH/A)  269000  등록일 2020.06.  10919
# ..                                      ...     ...           ...    ...
# 631          애플  정품 에어팟 2세대 유선 충전 MV7N2KH/A  169750  등록일 2021.03.      9
# 632       [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  162130  등록일 2021.02.      9
# 636      [애플]정품 에어팟2 유선충전모델 MV7N2KH/A - BUC  156150  등록일 2021.07.      8
# 637         애플 에어팟 프로 Airpods Pro 애플코리아정품 G  258680  등록일 2020.12.      8
# 638  [애플] [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  167500  등록일 2021.01.      8
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 631  False
# 632  False
# 636  False
# 637  False
# 638  False
#
# [365 rows x 5 columns]
#                                          제목      가격           등록일    리뷰수  \
# 1              Apple 에어팟 프로  MWP22KH/A  화이트  232070  등록일 2020.01.  69497
# 2                  Apple 에어팟 프로 (MWP22KH/A)  228900  등록일 2019.10.  46895
# 3         Apple 에어팟 2세대 유선충전 모델 (MV7N2KH/A)  142990  등록일 2019.04.  37404
# 4                 Apple 에어팟 1세대 (MMEF2KH/A)  162430  등록일 2016.12.  14121
# 5                  Apple 에어팟 프로 (MWP22KH/A)  269000  등록일 2020.06.  10919
# ..                                      ...     ...           ...    ...
# 631          애플  정품 에어팟 2세대 유선 충전 MV7N2KH/A  169750  등록일 2021.03.      9
# 632       [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  162130  등록일 2021.02.      9
# 636      [애플]정품 에어팟2 유선충전모델 MV7N2KH/A - BUC  156150  등록일 2021.07.      8
# 637         애플 에어팟 프로 Airpods Pro 애플코리아정품 G  258680  등록일 2020.12.      8
# 638  [애플] [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  167500  등록일 2021.01.      8
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 631  False
# 632  False
# 636  False
# 637  False
# 638  False
#
# [360 rows x 5 columns]
#                                          제목      가격           등록일    리뷰수  \
# 1              Apple 에어팟 프로  MWP22KH/A  화이트  232070  등록일 2020.01.  69497
# 2                  Apple 에어팟 프로 (MWP22KH/A)  228900  등록일 2019.10.  46895
# 3         Apple 에어팟 2세대 유선충전 모델 (MV7N2KH/A)  142990  등록일 2019.04.  37404
# 4                 Apple 에어팟 1세대 (MMEF2KH/A)  162430  등록일 2016.12.  14121
# 5                  Apple 에어팟 프로 (MWP22KH/A)  269000  등록일 2020.06.  10919
# ..                                      ...     ...           ...    ...
# 631          애플  정품 에어팟 2세대 유선 충전 MV7N2KH/A  169750  등록일 2021.03.      9
# 632       [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  162130  등록일 2021.02.      9
# 636      [애플]정품 에어팟2 유선충전모델 MV7N2KH/A - BUC  156150  등록일 2021.07.      8
# 637         애플 에어팟 프로 Airpods Pro 애플코리아정품 G  258680  등록일 2020.12.      8
# 638  [애플] [애플]정품 에어팟2 유선충전모델 MV7N2KH/A -BUC  167500  등록일 2021.01.      8
#
#         필터
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# ..     ...
# 631  False
# 632  False
# 636  False
# 637  False
# 638  False
#
# [360 rows x 5 columns]

# %%
#apple5 애플워치
app5 = apple5.copy()
app5 = app5[app5.가격>100000]
app5_filt = ["케이스", "충전기", "이어팁", "낱개", "거치대", "짭플", "스트랩"]
for i in app5_filt:
    app5["필터"] = pd.DataFrame(app5['제목'].str.contains(i))
    app5 = app5[app5["필터"]==False]
    print(app5)
# Out:
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 33                 Apple 워치 SE GPS Nike 40mm (실버 알루미늄)  346000  등록일 2020.11.
# 36    [추가금X] 애플워치3 시리즈 3세대 GPS 38,42mm 국내 AS 가능 정품 새상품  136900  등록일 2019.11.
# 39                Apple 워치 SE GPS 40mm (스페이스 그레이 알루미늄)  339380  등록일 2020.09.
# 40                 Apple 워치 SE GPS Nike 44mm (실버 알루미늄)  390040  등록일 2020.09.
# 41   Apple 정품 애플워치 3/6/SE 밀레니즈 루프  실버  38/40mm  Reg...  122500  등록일 2021.06.
# ..                                                 ...     ...           ...
# 388       [추가금X] 애플워치 SE 나이키 GPS 40, 44mm 국내 정식 A/S 가능  249000  등록일 2020.11.
# 393              KT프라자 애플워치 40mm/44mm 11번가쇼킹가 프리미엄상품제공  412200  등록일 2021.06.
# 394   애플 MYYD2KH/A Apple Watch Nike SE 40mm GPS Silver  431000  등록일 2020.11.
# 398  [카드사 12% 할인]애플 (빠른직구)애플워치SE 40mm GPS 실버+화이트스포츠...  349000  등록일 2021.07.
# 399        [카드사 12% 할인]애플 애플워치SE 40mm GPS 실버+화이트 스포츠밴드  428910  등록일 2020.12.
#
#       리뷰수     필터
# 33   1769  False
# 36   1226  False
# 39    937  False
# 40    766  False
# 41    758  False
# ..    ...    ...
# 388     7  False
# 393     6  False
# 394     6  False
# 398     6  False
# 399     6  False
#
# [125 rows x 5 columns]

# %%
#apple6 아이패드
app6 = apple6.copy()
app6 = app6[app6.가격>100000]
app6_filt = ["케이스", "충전기"]
for i in app6_filt:
    app6["필터"] = pd.DataFrame(app6['제목'].str.contains(i))
    app6 = app6[app6["필터"]==False]
    print(app6)
# Out:
#                                                     제목       가격           등록일  \
# 1           Apple iPad Air 4세대  Wi-Fi  256GB  스페이스 그레이   871860  등록일 2020.11.
# 2     Apple iPad Air 4세대  Wi-Fi+Cellular  256GB  로즈 골드   995690  등록일 2020.12.
# 3                 Apple iPad Air 4세대  Wi-Fi  256GB  실버   866220  등록일 2020.11.
# 4     Apple iPad Air 4세대  Wi-Fi+Cellular  64GB  스카이 블루   870050  등록일 2020.12.
# 5              Apple iPad Air 4세대  Wi-Fi  256GB  로즈 골드   852370  등록일 2020.11.
# ..                                                 ...      ...           ...
# 714    [카드할인 Apple 아이패드 프로 11형 3세대 M1 WIFI + 셀룰러 256GB  1329000  등록일 2021.05.
# 715  애플 4세대 아이패드 에어 10.9형 Wi-Fi 256GB Silver - MYFW...   949630  등록일 2020.11.
# 716                      애플 아이패드 프로 11 3세대 256G + 애플팬슬  1434990  등록일 2019.04.
# 718                JJ몰/애플 아이패드 프로3 11인치 64GB WiFi 정품 D  4631590  등록일 2020.02.
# 719                   애플 아이패드 프로 5세대 12.9인치 WiFi 128GB  1475710  등록일 2021.04.
#
#        리뷰수     필터
# 1    11253  False
# 2    11253  False
# 3    11253  False
# 4    11253  False
# 5    11253  False
# ..     ...    ...
# 714     10  False
# 715     10  False
# 716      9  False
# 718      9  False
# 719      9  False
#
# [653 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1           Apple iPad Air 4세대  Wi-Fi  256GB  스페이스 그레이   871860  등록일 2020.11.
# 2     Apple iPad Air 4세대  Wi-Fi+Cellular  256GB  로즈 골드   995690  등록일 2020.12.
# 3                 Apple iPad Air 4세대  Wi-Fi  256GB  실버   866220  등록일 2020.11.
# 4     Apple iPad Air 4세대  Wi-Fi+Cellular  64GB  스카이 블루   870050  등록일 2020.12.
# 5              Apple iPad Air 4세대  Wi-Fi  256GB  로즈 골드   852370  등록일 2020.11.
# ..                                                 ...      ...           ...
# 714    [카드할인 Apple 아이패드 프로 11형 3세대 M1 WIFI + 셀룰러 256GB  1329000  등록일 2021.05.
# 715  애플 4세대 아이패드 에어 10.9형 Wi-Fi 256GB Silver - MYFW...   949630  등록일 2020.11.
# 716                      애플 아이패드 프로 11 3세대 256G + 애플팬슬  1434990  등록일 2019.04.
# 718                JJ몰/애플 아이패드 프로3 11인치 64GB WiFi 정품 D  4631590  등록일 2020.02.
# 719                   애플 아이패드 프로 5세대 12.9인치 WiFi 128GB  1475710  등록일 2021.04.
#
#        리뷰수     필터
# 1    11253  False
# 2    11253  False
# 3    11253  False
# 4    11253  False
# 5    11253  False
# ..     ...    ...
# 714     10  False
# 715     10  False
# 716      9  False
# 718      9  False
# 719      9  False
#
# [653 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1           Apple iPad Air 4세대  Wi-Fi  256GB  스페이스 그레이   871860  등록일 2020.11.
# 2     Apple iPad Air 4세대  Wi-Fi+Cellular  256GB  로즈 골드   995690  등록일 2020.12.
# 3                 Apple iPad Air 4세대  Wi-Fi  256GB  실버   866220  등록일 2020.11.
# 4     Apple iPad Air 4세대  Wi-Fi+Cellular  64GB  스카이 블루   870050  등록일 2020.12.
# 5              Apple iPad Air 4세대  Wi-Fi  256GB  로즈 골드   852370  등록일 2020.11.
# ..                                                 ...      ...           ...
# 714    [카드할인 Apple 아이패드 프로 11형 3세대 M1 WIFI + 셀룰러 256GB  1329000  등록일 2021.05.
# 715  애플 4세대 아이패드 에어 10.9형 Wi-Fi 256GB Silver - MYFW...   949630  등록일 2020.11.
# 716                      애플 아이패드 프로 11 3세대 256G + 애플팬슬  1434990  등록일 2019.04.
# 718                JJ몰/애플 아이패드 프로3 11인치 64GB WiFi 정품 D  4631590  등록일 2020.02.
# 719                   애플 아이패드 프로 5세대 12.9인치 WiFi 128GB  1475710  등록일 2021.04.
#
#        리뷰수     필터
# 1    11253  False
# 2    11253  False
# 3    11253  False
# 4    11253  False
# 5    11253  False
# ..     ...    ...
# 714     10  False
# 715     10  False
# 716      9  False
# 718      9  False
# 719      9  False
#
# [653 rows x 5 columns]
#                                                     제목       가격           등록일  \
# 1           Apple iPad Air 4세대  Wi-Fi  256GB  스페이스 그레이   871860  등록일 2020.11.
# 2     Apple iPad Air 4세대  Wi-Fi+Cellular  256GB  로즈 골드   995690  등록일 2020.12.
# 3                 Apple iPad Air 4세대  Wi-Fi  256GB  실버   866220  등록일 2020.11.
# 4     Apple iPad Air 4세대  Wi-Fi+Cellular  64GB  스카이 블루   870050  등록일 2020.12.
# 5              Apple iPad Air 4세대  Wi-Fi  256GB  로즈 골드   852370  등록일 2020.11.
# ..                                                 ...      ...           ...
# 714    [카드할인 Apple 아이패드 프로 11형 3세대 M1 WIFI + 셀룰러 256GB  1329000  등록일 2021.05.
# 715  애플 4세대 아이패드 에어 10.9형 Wi-Fi 256GB Silver - MYFW...   949630  등록일 2020.11.
# 716                      애플 아이패드 프로 11 3세대 256G + 애플팬슬  1434990  등록일 2019.04.
# 718                JJ몰/애플 아이패드 프로3 11인치 64GB WiFi 정품 D  4631590  등록일 2020.02.
# 719                   애플 아이패드 프로 5세대 12.9인치 WiFi 128GB  1475710  등록일 2021.04.
#
#        리뷰수     필터
# 1    11253  False
# 2    11253  False
# 3    11253  False
# 4    11253  False
# 5    11253  False
# ..     ...    ...
# 714     10  False
# 715     10  False
# 716      9  False
# 718      9  False
# 719      9  False
#
# [653 rows x 5 columns]

# %%
#shaomi1 미밴드
sha1 = shaomi1.copy()
sha1 = sha1[sha1.가격>20000]

sha1_filt = ["케이스", "충전기", "메탈밴드", "가죽밴드", "스트랩"]
for i in sha1_filt:
    sha1["필터"] = pd.DataFrame(sha1['제목'].str.contains(i))
    sha1 = sha1[sha1["필터"]==False]
    print(sha1)
# Out:
#                                                     제목     가격           등록일  \
# 1                                             샤오미 미밴드5  34700  등록일 2020.09.
# 2                                             샤오미 미밴드2  30630  등록일 2016.08.
# 3    Xiaomi-Mi Band 6 스마트 팔찌, 5 색 AMOLED 스크린 Miband...  41186  등록일 2021.07.
# 4                                             샤오미 미밴드4  35610  등록일 2019.06.
# 6                  샤오미 미밴드5 한글판 스마트워치 스마트밴드 웨어러블 만보기시계  35900  등록일 2020.09.
# ..                                                 ...    ...           ...
# 390                             샤오미 미밴드6 한글판 공식수입 국내발송  52520  등록일 2021.07.
# 391  "2021 New Xiao mi MI Band 6 Smartwatch 1.56 ""...  56609  등록일 2021.04.
# 392  글로벌 버전 Xiaomi Mi Band 5 팔찌 4 색 AMOLED 터치 스크린 팔...  29290  등록일 2020.09.
# 395  샤오미 미밴드6 NFC버전 중국판/1.56인치 풀스크린/30가지 운동모드/마그네틱 ...  39070  등록일 2021.04.
# 396                        샤오미 샤오미 미밴드(1S)Mi Band/해외직구  35900  등록일 2021.02.
#
#        리뷰수     필터
# 1    17026  False
# 2    10736  False
# 3    10248  False
# 4    10244  False
# 6     9466  False
# ..     ...    ...
# 390      9  False
# 391      9  False
# 392      9  False
# 395      9  False
# 396      9  False
#
# [309 rows x 5 columns]
#                                                     제목     가격           등록일  \
# 1                                             샤오미 미밴드5  34700  등록일 2020.09.
# 2                                             샤오미 미밴드2  30630  등록일 2016.08.
# 3    Xiaomi-Mi Band 6 스마트 팔찌, 5 색 AMOLED 스크린 Miband...  41186  등록일 2021.07.
# 4                                             샤오미 미밴드4  35610  등록일 2019.06.
# 6                  샤오미 미밴드5 한글판 스마트워치 스마트밴드 웨어러블 만보기시계  35900  등록일 2020.09.
# ..                                                 ...    ...           ...
# 390                             샤오미 미밴드6 한글판 공식수입 국내발송  52520  등록일 2021.07.
# 391  "2021 New Xiao mi MI Band 6 Smartwatch 1.56 ""...  56609  등록일 2021.04.
# 392  글로벌 버전 Xiaomi Mi Band 5 팔찌 4 색 AMOLED 터치 스크린 팔...  29290  등록일 2020.09.
# 395  샤오미 미밴드6 NFC버전 중국판/1.56인치 풀스크린/30가지 운동모드/마그네틱 ...  39070  등록일 2021.04.
# 396                        샤오미 샤오미 미밴드(1S)Mi Band/해외직구  35900  등록일 2021.02.
#
#        리뷰수     필터
# 1    17026  False
# 2    10736  False
# 3    10248  False
# 4    10244  False
# 6     9466  False
# ..     ...    ...
# 390      9  False
# 391      9  False
# 392      9  False
# 395      9  False
# 396      9  False
#
# [309 rows x 5 columns]
#                                                     제목     가격           등록일  \
# 1                                             샤오미 미밴드5  34700  등록일 2020.09.
# 2                                             샤오미 미밴드2  30630  등록일 2016.08.
# 3    Xiaomi-Mi Band 6 스마트 팔찌, 5 색 AMOLED 스크린 Miband...  41186  등록일 2021.07.
# 4                                             샤오미 미밴드4  35610  등록일 2019.06.
# 6                  샤오미 미밴드5 한글판 스마트워치 스마트밴드 웨어러블 만보기시계  35900  등록일 2020.09.
# ..                                                 ...    ...           ...
# 390                             샤오미 미밴드6 한글판 공식수입 국내발송  52520  등록일 2021.07.
# 391  "2021 New Xiao mi MI Band 6 Smartwatch 1.56 ""...  56609  등록일 2021.04.
# 392  글로벌 버전 Xiaomi Mi Band 5 팔찌 4 색 AMOLED 터치 스크린 팔...  29290  등록일 2020.09.
# 395  샤오미 미밴드6 NFC버전 중국판/1.56인치 풀스크린/30가지 운동모드/마그네틱 ...  39070  등록일 2021.04.
# 396                        샤오미 샤오미 미밴드(1S)Mi Band/해외직구  35900  등록일 2021.02.
#
#        리뷰수     필터
# 1    17026  False
# 2    10736  False
# 3    10248  False
# 4    10244  False
# 6     9466  False
# ..     ...    ...
# 390      9  False
# 391      9  False
# 392      9  False
# 395      9  False
# 396      9  False
#
# [309 rows x 5 columns]
#                                                     제목     가격           등록일  \
# 1                                             샤오미 미밴드5  34700  등록일 2020.09.
# 2                                             샤오미 미밴드2  30630  등록일 2016.08.
# 3    Xiaomi-Mi Band 6 스마트 팔찌, 5 색 AMOLED 스크린 Miband...  41186  등록일 2021.07.
# 4                                             샤오미 미밴드4  35610  등록일 2019.06.
# 6                  샤오미 미밴드5 한글판 스마트워치 스마트밴드 웨어러블 만보기시계  35900  등록일 2020.09.
# ..                                                 ...    ...           ...
# 390                             샤오미 미밴드6 한글판 공식수입 국내발송  52520  등록일 2021.07.
# 391  "2021 New Xiao mi MI Band 6 Smartwatch 1.56 ""...  56609  등록일 2021.04.
# 392  글로벌 버전 Xiaomi Mi Band 5 팔찌 4 색 AMOLED 터치 스크린 팔...  29290  등록일 2020.09.
# 395  샤오미 미밴드6 NFC버전 중국판/1.56인치 풀스크린/30가지 운동모드/마그네틱 ...  39070  등록일 2021.04.
# 396                        샤오미 샤오미 미밴드(1S)Mi Band/해외직구  35900  등록일 2021.02.
#
#        리뷰수     필터
# 1    17026  False
# 2    10736  False
# 3    10248  False
# 4    10244  False
# 6     9466  False
# ..     ...    ...
# 390      9  False
# 391      9  False
# 392      9  False
# 395      9  False
# 396      9  False
#
# [309 rows x 5 columns]
#                                                     제목     가격           등록일  \
# 1                                             샤오미 미밴드5  34700  등록일 2020.09.
# 2                                             샤오미 미밴드2  30630  등록일 2016.08.
# 3    Xiaomi-Mi Band 6 스마트 팔찌, 5 색 AMOLED 스크린 Miband...  41186  등록일 2021.07.
# 4                                             샤오미 미밴드4  35610  등록일 2019.06.
# 6                  샤오미 미밴드5 한글판 스마트워치 스마트밴드 웨어러블 만보기시계  35900  등록일 2020.09.
# ..                                                 ...    ...           ...
# 390                             샤오미 미밴드6 한글판 공식수입 국내발송  52520  등록일 2021.07.
# 391  "2021 New Xiao mi MI Band 6 Smartwatch 1.56 ""...  56609  등록일 2021.04.
# 392  글로벌 버전 Xiaomi Mi Band 5 팔찌 4 색 AMOLED 터치 스크린 팔...  29290  등록일 2020.09.
# 395  샤오미 미밴드6 NFC버전 중국판/1.56인치 풀스크린/30가지 운동모드/마그네틱 ...  39070  등록일 2021.04.
# 396                        샤오미 샤오미 미밴드(1S)Mi Band/해외직구  35900  등록일 2021.02.
#
#        리뷰수     필터
# 1    17026  False
# 2    10736  False
# 3    10248  False
# 4    10244  False
# 6     9466  False
# ..     ...    ...
# 390      9  False
# 391      9  False
# 392      9  False
# 395      9  False
# 396      9  False
#
# [295 rows x 5 columns]

# %%
#shaomi2 홍미노트
sha2 = shaomi2.copy()
sha2 = sha2[sha2.가격>100000]
sha2_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sha2_filt:
    sha2["필터"] = pd.DataFrame(sha2['제목'].str.contains(i))
    sha2 = sha2[sha2["필터"]==False]
    print(sha2)
# Out:
#                                                  제목      가격           등록일  \
# 1        삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2        삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3     삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4      삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5     삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                             ...     ...           ...
# 1530                삼성정품 갤럭시 버즈 라이브 레드 SM-R180 / kh   98410  등록일 2021.06.
# 1536                    갤럭시 갤럭시버즈라이브 충전기 브론즈 이어폰미포함   55410  등록일 2021.01.
# 1547                             삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
# 1564            삼성 갤럭시 버즈라이브 R180 오른쪽 유닛 낱개 블루투스이어폰   59000  등록일 2021.04.
# 1591                          서머너버즈 Live X3 블루투스이어폰   55000  등록일 2019.07.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1530     10  False
# 1536     10  False
# 1547     10  False
# 1564      9  False
# 1591      9  False
#
# [164 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1530                    삼성정품 갤럭시 버즈 라이브 레드 SM-R180 / kh   98410  등록일 2021.06.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
# 1564                삼성 갤럭시 버즈라이브 R180 오른쪽 유닛 낱개 블루투스이어폰   59000  등록일 2021.04.
# 1591                              서머너버즈 Live X3 블루투스이어폰   55000  등록일 2019.07.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1516     10  False
# 1530     10  False
# 1547     10  False
# 1564      9  False
# 1591      9  False
#
# [158 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1530                    삼성정품 갤럭시 버즈 라이브 레드 SM-R180 / kh   98410  등록일 2021.06.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
# 1564                삼성 갤럭시 버즈라이브 R180 오른쪽 유닛 낱개 블루투스이어폰   59000  등록일 2021.04.
# 1591                              서머너버즈 Live X3 블루투스이어폰   55000  등록일 2019.07.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1516     10  False
# 1530     10  False
# 1547     10  False
# 1564      9  False
# 1591      9  False
#
# [158 rows x 5 columns]
#                                                      제목      가격           등록일  \
# 1            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 2            삼성전자 갤럭시 버즈 라이브 블루투스 이어폰 SM-R180 ANC 무선이어폰  129000  등록일 2020.08.
# 3         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 브론즈  129900  등록일 2020.08.
# 4          삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 블랙  129900  등록일 2020.08.
# 5         삼성전자 갤럭시버즈 라이브 스페셜 액세서리 패키지  SM-R180  미스틱 화이트  129900  등록일 2020.08.
# ...                                                 ...     ...           ...
# 1499                    삼성정품 갤럭시 버즈 라이브 레드 SM-R180 / kh   98410  등록일 2021.06.
# 1516  갤럭시 버즈라이브 화이트 - [삼성전자] 갤럭시버즈 라이브 SM R180 블랙 화이...  110720  등록일 2021.03.
# 1530                    삼성정품 갤럭시 버즈 라이브 레드 SM-R180 / kh   98410  등록일 2021.06.
# 1547                                 삼성 버즈 라이브 SM-R180N  159100  등록일 2020.08.
# 1591                              서머너버즈 Live X3 블루투스이어폰   55000  등록일 2019.07.
#
#         리뷰수     필터
# 1     10435  False
# 2     10435  False
# 3      8728  False
# 4      8728  False
# 5      8728  False
# ...     ...    ...
# 1499     10  False
# 1516     10  False
# 1530     10  False
# 1547     10  False
# 1591      9  False
#
# [157 rows x 5 columns]

# %%
#shaomi3 샤오미워치
sha3 = shaomi3.copy()
sha3 = sha3[sha3.가격>20000]
sha3_filt = ["케이스", "충전기", "시계줄", "스트랩", "필름"]
for i in sha3_filt:
    sha3["필터"] = pd.DataFrame(sha3['제목'].str.contains(i))
    sha3 = sha3[sha3["필터"]==False]
    print(sha3)
# Out:
#                                                     제목      가격           등록일  \
# 1    COLMI P8 플러스 1.69 인치 2021 스마트 워치 남성 풀 터치 피트니스 ...   28214  등록일 2021.03.
# 2         샤오미 미밴드4 미밴드3 미밴드2 스마트워치 모음전 공식판매처 정식수입 AS가능   37440  등록일 2015.09.
# 3                                             샤오미 미밴드3   22620  등록일 2019.07.
# 4                                    샤오미 미밴드3  블랙  단일품   20840  등록일 2021.05.
# 5    [정식한글판] 샤오미 미 밴드5 헬로우솔라 LS05 이미랩 KW66 스마트워치 스마트밴드   37900  등록일 2020.08.
# ..                                                 ...     ...           ...
# 635          샤오미 미밴드6  중국내수용  블랙  1개 - 2021년 신상 미밴드 워치   38900  등록일 2021.05.
# 636                         화미 스마트워치 어메이크핏미니 GTS 2 한글판   95000  등록일 2020.12.
# 637                                   샤오미 미브로 컬러 스마트워치   34890  등록일 2021.06.
# 638                           샤오미 미워치 글로벌버젼 네이비 (한글지원)   99650  등록일 2021.01.
# 639                       샤오미 미워치 컬러 스포츠 에디션 한글지원 국제버전  117510  등록일 2020.11.
#
#       리뷰수     필터
# 1    6134  False
# 2    4560  False
# 3    3722  False
# 4    3722  False
# 5    3692  False
# ..    ...    ...
# 635     8  False
# 636     8  False
# 637     8  False
# 638     8  False
# 639     8  False
#
# [557 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 1    COLMI P8 플러스 1.69 인치 2021 스마트 워치 남성 풀 터치 피트니스 ...   28214  등록일 2021.03.
# 2         샤오미 미밴드4 미밴드3 미밴드2 스마트워치 모음전 공식판매처 정식수입 AS가능   37440  등록일 2015.09.
# 3                                             샤오미 미밴드3   22620  등록일 2019.07.
# 4                                    샤오미 미밴드3  블랙  단일품   20840  등록일 2021.05.
# 5    [정식한글판] 샤오미 미 밴드5 헬로우솔라 LS05 이미랩 KW66 스마트워치 스마트밴드   37900  등록일 2020.08.
# ..                                                 ...     ...           ...
# 635          샤오미 미밴드6  중국내수용  블랙  1개 - 2021년 신상 미밴드 워치   38900  등록일 2021.05.
# 636                         화미 스마트워치 어메이크핏미니 GTS 2 한글판   95000  등록일 2020.12.
# 637                                   샤오미 미브로 컬러 스마트워치   34890  등록일 2021.06.
# 638                           샤오미 미워치 글로벌버젼 네이비 (한글지원)   99650  등록일 2021.01.
# 639                       샤오미 미워치 컬러 스포츠 에디션 한글지원 국제버전  117510  등록일 2020.11.
#
#       리뷰수     필터
# 1    6134  False
# 2    4560  False
# 3    3722  False
# 4    3722  False
# 5    3692  False
# ..    ...    ...
# 635     8  False
# 636     8  False
# 637     8  False
# 638     8  False
# 639     8  False
#
# [557 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 1    COLMI P8 플러스 1.69 인치 2021 스마트 워치 남성 풀 터치 피트니스 ...   28214  등록일 2021.03.
# 2         샤오미 미밴드4 미밴드3 미밴드2 스마트워치 모음전 공식판매처 정식수입 AS가능   37440  등록일 2015.09.
# 3                                             샤오미 미밴드3   22620  등록일 2019.07.
# 4                                    샤오미 미밴드3  블랙  단일품   20840  등록일 2021.05.
# 5    [정식한글판] 샤오미 미 밴드5 헬로우솔라 LS05 이미랩 KW66 스마트워치 스마트밴드   37900  등록일 2020.08.
# ..                                                 ...     ...           ...
# 635          샤오미 미밴드6  중국내수용  블랙  1개 - 2021년 신상 미밴드 워치   38900  등록일 2021.05.
# 636                         화미 스마트워치 어메이크핏미니 GTS 2 한글판   95000  등록일 2020.12.
# 637                                   샤오미 미브로 컬러 스마트워치   34890  등록일 2021.06.
# 638                           샤오미 미워치 글로벌버젼 네이비 (한글지원)   99650  등록일 2021.01.
# 639                       샤오미 미워치 컬러 스포츠 에디션 한글지원 국제버전  117510  등록일 2020.11.
#
#       리뷰수     필터
# 1    6134  False
# 2    4560  False
# 3    3722  False
# 4    3722  False
# 5    3692  False
# ..    ...    ...
# 635     8  False
# 636     8  False
# 637     8  False
# 638     8  False
# 639     8  False
#
# [557 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 1    COLMI P8 플러스 1.69 인치 2021 스마트 워치 남성 풀 터치 피트니스 ...   28214  등록일 2021.03.
# 2         샤오미 미밴드4 미밴드3 미밴드2 스마트워치 모음전 공식판매처 정식수입 AS가능   37440  등록일 2015.09.
# 3                                             샤오미 미밴드3   22620  등록일 2019.07.
# 4                                    샤오미 미밴드3  블랙  단일품   20840  등록일 2021.05.
# 5    [정식한글판] 샤오미 미 밴드5 헬로우솔라 LS05 이미랩 KW66 스마트워치 스마트밴드   37900  등록일 2020.08.
# ..                                                 ...     ...           ...
# 635          샤오미 미밴드6  중국내수용  블랙  1개 - 2021년 신상 미밴드 워치   38900  등록일 2021.05.
# 636                         화미 스마트워치 어메이크핏미니 GTS 2 한글판   95000  등록일 2020.12.
# 637                                   샤오미 미브로 컬러 스마트워치   34890  등록일 2021.06.
# 638                           샤오미 미워치 글로벌버젼 네이비 (한글지원)   99650  등록일 2021.01.
# 639                       샤오미 미워치 컬러 스포츠 에디션 한글지원 국제버전  117510  등록일 2020.11.
#
#       리뷰수     필터
# 1    6134  False
# 2    4560  False
# 3    3722  False
# 4    3722  False
# 5    3692  False
# ..    ...    ...
# 635     8  False
# 636     8  False
# 637     8  False
# 638     8  False
# 639     8  False
#
# [551 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 1    COLMI P8 플러스 1.69 인치 2021 스마트 워치 남성 풀 터치 피트니스 ...   28214  등록일 2021.03.
# 2         샤오미 미밴드4 미밴드3 미밴드2 스마트워치 모음전 공식판매처 정식수입 AS가능   37440  등록일 2015.09.
# 3                                             샤오미 미밴드3   22620  등록일 2019.07.
# 4                                    샤오미 미밴드3  블랙  단일품   20840  등록일 2021.05.
# 5    [정식한글판] 샤오미 미 밴드5 헬로우솔라 LS05 이미랩 KW66 스마트워치 스마트밴드   37900  등록일 2020.08.
# ..                                                 ...     ...           ...
# 635          샤오미 미밴드6  중국내수용  블랙  1개 - 2021년 신상 미밴드 워치   38900  등록일 2021.05.
# 636                         화미 스마트워치 어메이크핏미니 GTS 2 한글판   95000  등록일 2020.12.
# 637                                   샤오미 미브로 컬러 스마트워치   34890  등록일 2021.06.
# 638                           샤오미 미워치 글로벌버젼 네이비 (한글지원)   99650  등록일 2021.01.
# 639                       샤오미 미워치 컬러 스포츠 에디션 한글지원 국제버전  117510  등록일 2020.11.
#
#       리뷰수     필터
# 1    6134  False
# 2    4560  False
# 3    3722  False
# 4    3722  False
# 5    3692  False
# ..    ...    ...
# 635     8  False
# 636     8  False
# 637     8  False
# 638     8  False
# 639     8  False
#
# [542 rows x 5 columns]

# %%
#shaomi4 어메이즈핏
sha4 = shaomi4.copy()
sha4 = sha4[sha4.가격>30000]
sha4_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sha4_filt:
    sha4["필터"] = pd.DataFrame(sha4['제목'].str.contains(i))
    sha4 = sha4[sha4["필터"]==False]
    print(sha4)
# Out:
#                                                     제목      가격           등록일  \
# 3                                        화미 어메이즈핏 GTR2  193430  등록일 2020.11.
# 4    Original Amazfit Stratos Smartwatch 스마트 워치 GPS...  111469  등록일 2021.01.
# 7                                      화미 어메이즈핏 GTR 2e  148000  등록일 2021.02.
# 9                                    화미 어메이즈핏 GTR 47mm  119000  등록일 2020.12.
# 10                       스마트워치 GTR2e 블랙 정식발매 한글판/전국망AS  148000  등록일 2021.02.
# ..                                                 ...     ...           ...
# 388             스마트워치 어메이즈핏 GTR 47mm 국내정식발매 한글판/국내AS지원  119000  등록일 2020.10.
# 391  글로벌 버전 Amazfit Stratos 3 스마트 워치 5ATM GPS 음악 듀얼...  218444  등록일 2021.04.
# 395                 스마트워치 어메이즈핏 GTS2 국내정식발매 한글판/국내AS지원  198000  등록일 2020.12.
# 396                       AMAZFIT VERGE 어메이즈핏 버지 글로벌버전  189030  등록일 2019.01.
# 398                    [화미] 어메이즈핏 GTS 스마트워치 [한글판] [블랙]  135000  등록일 2021.05.
#
#       리뷰수     필터
# 3    1318  False
# 4    1218  False
# 7     971  False
# 9     899  False
# 10    807  False
# ..    ...    ...
# 388     8  False
# 391     8  False
# 395     8  False
# 396     8  False
# 398     8  False
#
# [182 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 3                                        화미 어메이즈핏 GTR2  193430  등록일 2020.11.
# 4    Original Amazfit Stratos Smartwatch 스마트 워치 GPS...  111469  등록일 2021.01.
# 7                                      화미 어메이즈핏 GTR 2e  148000  등록일 2021.02.
# 9                                    화미 어메이즈핏 GTR 47mm  119000  등록일 2020.12.
# 10                       스마트워치 GTR2e 블랙 정식발매 한글판/전국망AS  148000  등록일 2021.02.
# ..                                                 ...     ...           ...
# 388             스마트워치 어메이즈핏 GTR 47mm 국내정식발매 한글판/국내AS지원  119000  등록일 2020.10.
# 391  글로벌 버전 Amazfit Stratos 3 스마트 워치 5ATM GPS 음악 듀얼...  218444  등록일 2021.04.
# 395                 스마트워치 어메이즈핏 GTS2 국내정식발매 한글판/국내AS지원  198000  등록일 2020.12.
# 396                       AMAZFIT VERGE 어메이즈핏 버지 글로벌버전  189030  등록일 2019.01.
# 398                    [화미] 어메이즈핏 GTS 스마트워치 [한글판] [블랙]  135000  등록일 2021.05.
#
#       리뷰수     필터
# 3    1318  False
# 4    1218  False
# 7     971  False
# 9     899  False
# 10    807  False
# ..    ...    ...
# 388     8  False
# 391     8  False
# 395     8  False
# 396     8  False
# 398     8  False
#
# [181 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 3                                        화미 어메이즈핏 GTR2  193430  등록일 2020.11.
# 4    Original Amazfit Stratos Smartwatch 스마트 워치 GPS...  111469  등록일 2021.01.
# 7                                      화미 어메이즈핏 GTR 2e  148000  등록일 2021.02.
# 9                                    화미 어메이즈핏 GTR 47mm  119000  등록일 2020.12.
# 10                       스마트워치 GTR2e 블랙 정식발매 한글판/전국망AS  148000  등록일 2021.02.
# ..                                                 ...     ...           ...
# 388             스마트워치 어메이즈핏 GTR 47mm 국내정식발매 한글판/국내AS지원  119000  등록일 2020.10.
# 391  글로벌 버전 Amazfit Stratos 3 스마트 워치 5ATM GPS 음악 듀얼...  218444  등록일 2021.04.
# 395                 스마트워치 어메이즈핏 GTS2 국내정식발매 한글판/국내AS지원  198000  등록일 2020.12.
# 396                       AMAZFIT VERGE 어메이즈핏 버지 글로벌버전  189030  등록일 2019.01.
# 398                    [화미] 어메이즈핏 GTS 스마트워치 [한글판] [블랙]  135000  등록일 2021.05.
#
#       리뷰수     필터
# 3    1318  False
# 4    1218  False
# 7     971  False
# 9     899  False
# 10    807  False
# ..    ...    ...
# 388     8  False
# 391     8  False
# 395     8  False
# 396     8  False
# 398     8  False
#
# [181 rows x 5 columns]
#                                                     제목      가격           등록일  \
# 3                                        화미 어메이즈핏 GTR2  193430  등록일 2020.11.
# 4    Original Amazfit Stratos Smartwatch 스마트 워치 GPS...  111469  등록일 2021.01.
# 7                                      화미 어메이즈핏 GTR 2e  148000  등록일 2021.02.
# 9                                    화미 어메이즈핏 GTR 47mm  119000  등록일 2020.12.
# 10                       스마트워치 GTR2e 블랙 정식발매 한글판/전국망AS  148000  등록일 2021.02.
# ..                                                 ...     ...           ...
# 388             스마트워치 어메이즈핏 GTR 47mm 국내정식발매 한글판/국내AS지원  119000  등록일 2020.10.
# 391  글로벌 버전 Amazfit Stratos 3 스마트 워치 5ATM GPS 음악 듀얼...  218444  등록일 2021.04.
# 395                 스마트워치 어메이즈핏 GTS2 국내정식발매 한글판/국내AS지원  198000  등록일 2020.12.
# 396                       AMAZFIT VERGE 어메이즈핏 버지 글로벌버전  189030  등록일 2019.01.
# 398                    [화미] 어메이즈핏 GTS 스마트워치 [한글판] [블랙]  135000  등록일 2021.05.
#
#       리뷰수     필터
# 3    1318  False
# 4    1218  False
# 7     971  False
# 9     899  False
# 10    807  False
# ..    ...    ...
# 388     8  False
# 391     8  False
# 395     8  False
# 396     8  False
# 398     8  False
#
# [181 rows x 5 columns]

# %%
#shaomi5 샤오미폰
sha5  shaomi5.opy()
sha5 = sha5[sha5.가격>100000]
sha5_filt = ["케이스", "충전기"]
for i in sha5_filt:
    sha5["필터"] = pd.DataFrame(sha5['제목'].str.contains(i))
    sha5 = sha5[sha5["필터"]==False]
    print(sha5)
# Out:
#   File "<ipython-input-174-4022c847d7e4>", line 2
#     sha5  shaomi5.opy()
#           ^
# SyntaxError: invalid syntax

# %%
#apple6 아이패드
sha6 = shaomi6.copy()
sha6 = sha6[sha6.가격>100000]
sha6_filt = ["케이스", "충전기", "이어팁", "낱개"]
for i in sha6_filt:
    sha6["필터"] = pd.DataFrame(sha6['제목'].str.contains(i))
    sha6 = sha6[sha6["필터"]==False]
    print(sha6)

# %%
#통합 후 중복 처리

# samsung1.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# samsung2.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# samsung3.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# samsung4.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# samsung5.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# samsung6.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')

# apple1.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# apple2.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# apple3.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# apple4.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# apple5.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# apple6.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')

# shaomi1.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# shaomi2.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# shaomi3.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# shaomi4.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# shaomi5.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# shaomi6.drop_duplicates(subset=['제목', '가격', '리뷰수'], keep='first')
# Out:
# 제목     0
# 가격     0
# 등록일    0
# 리뷰수    0
# dtype: int64
