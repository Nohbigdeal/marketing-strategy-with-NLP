# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import selenium
from urllib.parse import  urlparse
import time
import lxml
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd
import re
import pickle
from contextlib import suppress
import matplotlib.pyplot as plt
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, cross_validate, KFold
from tqdm import tqdm

from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
from xgboost import XGBClassifier
from konlpy.tag import Mecab

# %%
ds_star = pd.read_csv("C:/690009/TP2/final_project/Project/Data/DS_adj.csv", encoding='utf-8-sig')
ds_star

ds_star = pd.DataFrame(ds_star, columns = ["review", "star"])
ds_star.drop_duplicates(subset=['review', 'star'], inplace=True)
ds_star

ds_star["label"] = 0
ds_star
# Out:
#                                                   review  star  label
# 0      아니... 새제품 맞는거죠? 뜯자마자 버튼 옆에 약간 기스? 볼펜? 으로 끄어져있고...     3      0
# 1      아이패드는 괜찮은데 필름이랑 케이스가 많이 별로입니다.케이스랑 필름 세트로 4만원이...     3      0
# 2      개봉을 최근에 해서 살펴보다 보니 제조일은 9월인데 배터리 충전일 보고 괜히 찜찜 ...     3      0
# 3                                  많이 기다리긴 했지만 좋은 것 같아요.     3      0
# 4                                       아주아주 잘 사용하고 있답니다     3      0
# ...                                                  ...   ...    ...
# 22480              충전중이라 아직 사용전이지만  이쁘네요배송이 넘 늦어 별하나 뺐어요     4      0
# 22481                                         편하고 좋아요 ^^     5      0
# 22482  두근두근..... 드뎌 제손에 들어왔어요. 배송두 약속대루 빨리왔구요.. 뽁뽁이를 ...     5      0
# 22483  저는 두달 반 전에 갤럭시 버즈 프로를 구입하였는데 최근의 이상한 점을 발견하였습니...     4      0
# 22484                                            잘 받았어요~     5      0
#
# [22485 rows x 3 columns]

# %%
# ds_star.set_index("", inplace=True)
ds_star.loc[ds_star["star"] > 3, "label"] = 1
ds_star
# Out:
#                                                   review  star  label
# 0      아니... 새제품 맞는거죠? 뜯자마자 버튼 옆에 약간 기스? 볼펜? 으로 끄어져있고...     3      0
# 1      아이패드는 괜찮은데 필름이랑 케이스가 많이 별로입니다.케이스랑 필름 세트로 4만원이...     3      0
# 2      개봉을 최근에 해서 살펴보다 보니 제조일은 9월인데 배터리 충전일 보고 괜히 찜찜 ...     3      0
# 3                                  많이 기다리긴 했지만 좋은 것 같아요.     3      0
# 4                                       아주아주 잘 사용하고 있답니다     3      0
# ...                                                  ...   ...    ...
# 22480              충전중이라 아직 사용전이지만  이쁘네요배송이 넘 늦어 별하나 뺐어요     4      1
# 22481                                         편하고 좋아요 ^^     5      1
# 22482  두근두근..... 드뎌 제손에 들어왔어요. 배송두 약속대루 빨리왔구요.. 뽁뽁이를 ...     5      1
# 22483  저는 두달 반 전에 갤럭시 버즈 프로를 구입하였는데 최근의 이상한 점을 발견하였습니...     4      1
# 22484                                            잘 받았어요~     5      1
#
# [22485 rows x 3 columns]

# %%
ds_star["review"] = ds_star['review'].str.replace("\n","")
ds_star["review"] = ds_star["review"].str.replace("[^a-zA-Z가-힣0-9 ]", "")
# Out:
# <ipython-input-229-f66e274aceb6>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   ds_star["review"] = ds_star["review"].str.replace("[^a-zA-Z가-힣0-9 ]", "")

# %%
ds_star.groupby(['star']).count()
# Out:
#       review  label
# star
# 1       1869   1869
# 2       1160   1160
# 3       4456   4456
# 4       7154   7154
# 5       7846   7846

# %%
train_data, test_data = train_test_split(ds_star, test_size=0.20, random_state = 42)
print('훈련용 리뷰의 개수 :', len(train_data))
print('테스트용 리뷰의 개수 :', len(test_data))
# Out:
# 훈련용 리뷰의 개수 : 17988
# 테스트용 리뷰의 개수 : 4497

# %%
train_data.drop_duplicates(subset=["review", "star"], inplace=True)
test_data.drop_duplicates(subset=["review", "star"], inplace=True)
print(len(train_data))
print(len(test_data))
# Out:
# 17903
# 4490
# <ipython-input-232-6379017acd02>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.drop_duplicates(subset=["review", "star"], inplace=True)
# <ipython-input-232-6379017acd02>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop_duplicates(subset=["review", "star"], inplace=True)

# %%
train_data['label'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
print(train_data.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0   5950
# 1      1  11953

# %%
print(train_data.isnull().values.any())
# Out:
# False

# %%
print(train_data.isnull().sum())
# Out:
# review    0
# star      0
# label     0
# dtype: int64

# %%
train_data.loc[train_data.review.isnull()]
# Out:
# Empty DataFrame
# Columns: [review, star, label]
# Index: []

# %%
train_data = train_data.dropna(how = 'any')
print(train_data.isnull().values.any())
# Out:
# False

# %%
print(len(train_data))
# Out:
# 17903

# %%
train_data['review'] = train_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data[:5]
# Out:
# <ipython-input-240-9263ec25ae0b>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['review'] = train_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#                                                   review  star  label
# 13014         아이가 맘에 들어하네요세대 사려다가 사양이 이게 더나아서 선택했네요추천합니다     4      1
# 8574           인강용으로 좋구요 인터넷은 아이폰 이랑 비교해봤을때 살짝 느린감 없지않네요     5      1
# 15051               뒤에 예약 받은것 보다 배송을 늦게 해주는 정책은 이해가 안되네요     4      1
# 14969                            저렴한 가격 사은품 빠른 배송 감사 합니다     4      1
# 13766  불량이 많다길래 걱정하면서 주문했어요다행히 제조일자도  였고 충전도 빨간불이었는데 ...     5      1

# %%
test_data.drop_duplicates(subset = ['review'], inplace=True) # 중복 제거
test_data['review'] = test_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['review'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 4446
# <ipython-input-242-1f0ed5dc41ef>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['review'] = test_data['review'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행

# %%
train_data['review'] = train_data['review'].str.replace('^ +', "")
train_data['review'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# review    77
# star       0
# label      0
# dtype: int64
# <ipython-input-243-e5b57724600d>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['review'] = train_data['review'].str.replace('^ +', "")

# %%
train_data.loc[train_data.review.isnull()][:5]
# Out:
#       review  star  label
# 14797    NaN     5      1
# 12785    NaN     5      1
# 8727     NaN     5      1
# 10857    NaN     5      1
# 11904    NaN     4      1

# %%
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 17826

# %%
okt = Okt()
stopwords = ['가','게','고','과','네','는','다','도','들','듯','를','에','와','으로',
             '은','을','의','이','인','임','자','잘','좀','지','하다','한']

# %%
X_train = []
for sentence in train_data['review']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_train.append(temp_X)

# %%
print(X_train[:10])
# Out:
# [['아이', '맘', '들다', '세대', '사다', '사양', '덥다', '선택', '추천'], ['인강', '용', '좋다', '인터넷', '아이폰', '이랑', '비교', '해봤다', '때', '살짝', '느리다', '감', '없다', '않다'], ['뒤', '예약', '받다', '보다', '배송', '늦다', '해주다', '정책', '이해', '안되다'], ['저렴하다', '가격', '사은', '품', '빠르다', '배송', '감사'], ['불량', '많다', '걱정', '주문', '다행하다', '제', '조', '일', '자도', '이다', '충전', '빨갛다', '불다', '조금', '더', '하니', '초록불', '뜨다', '원래', '쓰다', '유선', '이어폰', '삼성', '에서', '제공', '이다', '무선', '이어폰', '이다', '정말', '너무', '만족하다', '사용', '하고', '있다', '이어폰', '이다', '통화', '품질', '때문', '새', '무선', '이어폰', '생각', '되어다', '에어팟', '이랑', '버즈', '중', '고민', '갤럭시', '폰', '사용', '하고', '있다', '이번', '버즈', '플러스', '저렴하다', '가격', '성능', '더', '좋아지다', '통화', '품질', '에어팟', '보다', '낫', '대', '서', '구매', '일단', '원래', '쓰다', '무선', '이어폰', '자성', '강하다', '케이스', '넣다', '바로', '자동', '들어가다', '이건', '그렇다', '않다', '당황', '또', '케이스', '전', '것', '비교', '꽉', '닫다', '않다', '불안하다', '이건', '관리', '수', '밖에', '없다', '그리고', '저', '에게', '있다', '치명', '적', '단점', '이어폰', '작', '동', '법', '이다', '전에껀', '버튼', '식', '되어다', '작동', '편리하다', '이어폰', '만지다', '오', '작동', '되다', '염려', '없다', '한번', '누르다', '재생', '일', '시', '정지', '왼쪽', '두', '번', '이전', '곡', '오른쪽', '두', '번', '다음', '곡', '조작', '편리하다', '그런데', '버즈', '플러스', '이다', '버드', '스치다', '해도', '혼자', '멈추다', '곡', '뛰어넘다', '자다', '만지다', '수가', '없다', '터치패드', '잠그다', '자다', '즉각', '적', '컨트롤', '안', '돼다', '불편하다', '음질', '듣다', '너무', '너무', '너무', '달라', '서', '심하다', '당황', '이건', '뭐', '버즈', '로', '듣다', '예전', '꺼', '들다', '답답하다', '소리', '나다', '버즈', '적응하다', '볼륨', '갤럭시', '웨어', '로', '컨트롤', '가능하다', '그래도', '예', '전', '거', '비', '볼륨', '약하다', '답답하다', '통화', '품질', '정말', '좋다', '디자인', '존예', '구', '요', '주변', '소리', '듣기', '기능', '정말', '좋다', '답답하다', '않다', '근데', '기본', '적', '그렇다', '같다', '설정', '안해', '들리다', '무', '틀다', '너무', '너무', '좋다', '뽑기', '기분', '좋다', '용'], ['착용', '감다', '좋다', '사용', '간편하다', '빠르다', '배송', '감사하다'], ['음질', '좋다', '페어', '링', '속도', '좋다', '아직', '까진', '만족하다', '사용', '배송', '빨르다', '핀', '충전', '이라는', '마침', '집', '놀다', '충전기', '있다', '별도', '충전', '공간', '마련', '요것', '쫌', '아쉽다'], ['기존', '쓰다', '에어팟', '잃어버리다', '새롭다', '구매', '너무나', '비싸다', '금액', '때문', '주저', '샤오미', '청춘', '팟', '지르다', '제', '막귀', '아니다', '혹시', '음질', '이나', '성능', '딸리다', '걱정', '가격', '대비', '훌륭하다', '정말', '역시', '샤오미', '라는', '말', '왜', '나오다', '알다', '친구', '꺼', '만원', '짜다', '무선', '이어폰', '들다', '보다', '비교', '해봤다', '청춘팟', '확실하다', '음질', '뛰어나다', '대륙', '실수', '감사하다'], ['갤럭시', '버즈', '플러스', '배송', '받다', '상품', '확인', '해보다', '왼쪽', '이어폰', '페어', '링', '안되다', '완전', '먹통', '이다', '삼성', '제품', '검수', '없이', '판매', '이렇다', '불량', '처음', '이네', '요', '고객', '센터', '통화', '안되다', '문의', '글', '반품', '신청', '답변', '늦다', '너무', '불편하다'], ['배송', '빠르다', '물건', '안전하다', '도착']]

# %%
X_test = []
for sentence in test_data['review']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_test.append(temp_X)
print(X_test[:10])
# Out:
# [['배송', '느리다', '제품', '한글', '잘나오다', '만족'], ['주위', '동료', '사용', '걸', '보고', '구매', '상당하다', '쓸다', '것', '같다', '특히', '사용', '전', '에는', '모르다', '수면', '패턴', '분석', '및', '수면', '수준', '알다', '것', '상당하다', '유용하다', '정보라', '생각', '되다', '사용', '크다', '불편', '없다', '만족하다', '이용', '하고', '있다'], ['배송', '진짜', '빠르다', '좋다'], ['저렴하다', '배송', '빨르다'], ['벼루', '벼루', '드디어', '구매', '망설이다', '배송', '만', '늦추다', '뿐', '배송', '하루', '만에', '바로', '너무', '좋다', '저렴하다', '가격', '사은', '품', '필름', '이랑', '공짜', '커피', '까지', '주다', '너무', '득템', '이렇게', '편리하다', '정말', '돈', '좋다', '꼭', '사다', '너무', '좋다'], ['잘쓰다', '있다', '아직', '제대로', '활용', '못', '만족하다'], ['아', '이렇다', '추가', '밴드', '샤오미', '처럼', '말랑말랑하다', '않다', '사용', '어렵다', '핸드폰', '이랑', '연결', '되다'], ['나름', '좋다', '태블릿', '좋다'], ['제', '귀가', '이상하다', '건지다', '에어팟', '프로', '자다', '빠지다', '세대', '안', '빠지다', '좋다'], ['양품', '이네', '요', '어머니', '께', '선물']]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'좋다': 1, '있다': 2, '배송': 3, '되다': 4, '보다': 5, '사용': 6, '같다': 7, '자다': 8, '받다': 9, '로': 10, '구매': 11, '없다': 12, '너무': 13, '제품': 14, '이다': 15, '것': 16, '않다': 17, '안': 18, '에서': 19, '빠르다': 20, '쓰다': 21, '오다': 22, '요': 23, '사다': 24, '들다': 25, '하고': 26, '가격': 27, '때': 28, '생각': 29, '만': 30, '만족하다': 31, '더': 32, '제': 33, '기능': 34, '저': 35, '아니다': 36, '되어다': 37, '버즈': 38, '폰': 39, '수': 40, '안되다': 41, '일': 42, '노트북': 43, '정말': 44, '주문': 45, '상품': 46, '많이': 47, '케이스': 48, '구입': 49, '가다': 50, '적': 51, '음질': 52, '이라': 53, '정도': 54, '써다': 55, '이어폰': 56, '중': 57, '갤럭시': 58, '그렇다': 59, '저렴하다': 60, '괜찮다': 61, '그냥': 62, '거': 63, '못': 64, '소리': 65, '선물': 66, '서': 67, '해보다': 68, '프로': 69, '문제': 70, '크다': 71, '고민': 72, '처음': 73, '다른': 74, '화면': 75, '충전': 76, '조금': 77, '성능': 78, '아쉽다': 79, '까지': 80, '비': 81, '에어팟': 82, '해주다': 83, '나': 84, '삼성': 85, '가성': 86, '바로': 87, '센터': 88, '디자인': 89, '분': 90, '없이': 91, '편하다': 92, '포장': 93, '쓸다': 94, '많다': 95, '이쁘다': 96, '색상': 97, '아주': 98, '시간': 99, '예쁘다': 100, '그리고': 101, '착용': 102, '면': 103, '모르다': 104, '인데': 105, '가볍다': 106, '그': 107, '감사하다': 108, '주다': 109, '월': 110, '점': 111, '라': 112, '알다': 113, '싶다': 114, '이나': 115, '불량': 116, '귀': 117, '불편하다': 118, '나오다': 119, '마음': 120, '서비스': 121, '하': 122, '밴드': 123, '연결': 124, '아직': 125, '드리다': 126, '맘': 127, '부분': 128, '보내다': 129, '돼다': 130, '통화': 131, '필름': 132, '일단': 133, '좋아하다': 134, '느리다': 135, '사은': 136, '하나': 137, '맞다': 138, '걸리다': 139, '터치': 140, '전': 141, '용': 142, '시': 143, '애플': 144, '택배': 145, '판매': 146, '느낌': 147, '넘다': 148, '진짜': 149, '교환': 150, '만족스럽다': 151, '추천': 152, '그래도': 153, '에는': 154, '들리다': 155, '배터리': 156, '확인': 157, '후': 158, '구': 159, '엄청': 160, '때문': 161, '작다': 162, '품': 163, '만족': 164, '사': 165, '도착': 166, '잘쓰다': 167, '년': 168, '핸드폰': 169, '노이즈': 170, '성': 171, '매우': 172, '이상': 173, '빨리': 174, '상태': 175, '날': 176, '늦다': 177, '하루': 178, '말': 179, '오래': 180, '물건': 181, '기다리다': 182, '바꾸다': 183, '보고': 184, '랑': 185, '싸다': 186, '전화': 187, '걱정': 188, '역시': 189, '캔': 190, '가능하다': 191, '근데': 192, '슬링': 193, '밉다': 194, '박스': 195, '다만': 196, '곳': 197, '펜': 198, '플러스': 199, '다음': 200, '빨르다': 201, '할인': 202, '다시': 203, '감': 204, '이번': 205, '개': 206, '걸': 207, '무선': 208, '추가': 209, '선택': 210, '빼다': 211, '대': 212, '최고': 213, '아이폰': 214, '대비': 215, '사람': 216, '만에': 217, '여기': 218, '기존': 219, '뭐': 220, '기': 221, '필요하다': 222, '기분': 223, '비싸다': 224, '만원': 225, '정품': 226, '두': 227, '등': 228, '아이': 229, '확실하다': 230, '나다': 231, '딱': 232, '라서': 233, '아이패드': 234, '같이': 235, '하지만': 236, '깔끔하다': 237, '또': 238, '이네': 239, '액정': 240, '이랑': 241, '건': 242, '주변': 243, '운동': 244, '아프다': 245, '후기': 246, '비교': 247, '에도': 248, '엔': 249, '링': 250, '사진': 251, '내': 252, '새': 253, '별로': 254, '주': 255, '보이다': 256, '완전': 257, '리뷰': 258, '페어': 259, '왜': 260, '지금': 261, '귀가': 262, '무게': 263, '부터': 264, '이렇다': 265, '문의': 266, '매': 267, '세대': 268, '자체': 269, '듣다': 270, '블루투스': 271, '니': 272, '형': 273, '느끼다': 274, '음악': 275, '품질': 276, '끼다': 277, '빠지다': 278, '문': 279, '북': 280, '한번': 281, '계속': 282, '끊기다': 283, '처럼': 284, '크기': 285, '워치': 286, '한쪽': 287, '줄': 288, '속도': 289, '살다': 290, '떨어지다': 291, '차다': 292, '삼': 293, '약간': 294, '단점': 295, '오늘': 296, '노트': 297, '원': 298, '함': 299, '경우': 300, '시키다': 301, '플렉스': 302, '충전기': 303, '소음': 304, '등록': 305, '번': 306, '자급': 307, '해': 308, '고객': 309, '이라고': 310, '그래서': 311, '안전하다': 312, '인지': 313, '라이브': 314, '왼쪽': 315, '설정': 316, '감다': 317, '이고': 318, '듭니': 319, '에게': 320, '샤오미': 321, '반품': 322, '보호': 323, '늘다': 324, '넣다': 325, '가장': 326, '달': 327, '비다': 328, '태블릿': 329, '설명': 330, '찾다': 331, '실버': 332, '알': 333, '작동': 334, '인터넷': 335, '화질': 336, '모델': 337, '키': 338, '편리하다': 339, '버리다': 340, '별': 341, '시계': 342, '인식': 343, '여': 344, '아': 345, '몇': 346, '다니다': 347, '라고': 348, '장점': 349, '말다': 350, '색': 351, '모두': 352, '건지다': 353, '따로': 354, '크게': 355, '블루': 356, '집': 357, '노캔': 358, '믿다': 359, '고장': 360, '앞': 361, '보기': 362, '앱': 363, '이에요': 364, '휴대폰': 365, '붙이다': 366, '거의': 367, '연락': 368, '기대': 369, '품다': 370, '해봤다': 371, '에서는': 372, '어 ...

# %%
threshold = 5
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 14057
# 등장 빈도가 4번 이하인 희귀 단어의 수: 9102
# 단어 집합에서 희귀 단어의 비율: 64.75065803514264
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 2.804216051666851

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 4956

# %%
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:3])
# Out:
# [[229, 127, 25, 268, 24, 529, 690, 210, 152], [728, 142, 1, 335, 214, 241, 247, 371, 28, 376, 135, 204, 12, 17], [786, 1075, 9, 5, 3, 177, 83, 2408, 847, 41]]

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]

# %%
# 빈 샘플들을 제거
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
print(len(X_train))
print(len(y_train))
# Out:
# 17819
# 17819
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 1440
# 리뷰의 평균 길이 : 28.597564397553175

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 60
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 60 이하인 샘플의 비율: 88.74235366743363

# %%
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X_test)
y_pred_ = []

for i in range(len(y_pred)):
    if y_pred[i][0] > 0.5:
        y_pred_.append(1)
    else:
        y_pred_.append(0)
y_pred_

confusion_matrix(y_test, y_pred_)
# Out:
# array([[ 629,  852],
#        [1171, 1794]], dtype=int64)

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=60, validation_split=0.2)
# Out:
# Epoch 1/15
# 238/238 [==============================] - 31s 123ms/step - loss: 0.5003 - acc: 0.7654 - val_loss: 0.5617 - val_acc: 0.7842
#
# Epoch 00001: val_acc improved from -inf to 0.78423, saving model to best_model.h5
# Epoch 2/15
# 238/238 [==============================] - 29s 123ms/step - loss: 0.4219 - acc: 0.8182 - val_loss: 0.4658 - val_acc: 0.7963
#
# Epoch 00002: val_acc improved from 0.78423 to 0.79630, saving model to best_model.h5
# Epoch 3/15
# 238/238 [==============================] - 30s 125ms/step - loss: 0.3968 - acc: 0.8284 - val_loss: 0.4690 - val_acc: 0.7994
#
# Epoch 00003: val_acc improved from 0.79630 to 0.79938, saving model to best_model.h5
# Epoch 4/15
# 238/238 [==============================] - 29s 123ms/step - loss: 0.3802 - acc: 0.8368 - val_loss: 0.4765 - val_acc: 0.7999
#
# Epoch 00004: val_acc improved from 0.79938 to 0.79994, saving model to best_model.h5
# Epoch 5/15
# 238/238 [==============================] - 30s 126ms/step - loss: 0.3618 - acc: 0.8436 - val_loss: 0.4884 - val_acc: 0.7884
#
# Epoch 00005: val_acc did not improve from 0.79994
# Epoch 6/15
# 238/238 [==============================] - 30s 125ms/step - loss: 0.3453 - acc: 0.8534 - val_loss: 0.4900 - val_acc: 0.7896
#
# Epoch 00006: val_acc did not improve from 0.79994
# Epoch 00006: early stopping

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 139/139 [==============================] - 5s 31ms/step - loss: 0.4650 - acc: 0.7969
#
#  테스트 정확도: 0.7969

# %%
def sentiment_predict(new_sentence):
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sam = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNsReview/data/PP/sam.csv")
sam
# Out:
#       Unnamed: 0                                                 내용  \
# 0              0  사람들이 불만이 많아 걱정 많이했습니다사고 난 1일7일 발열 느껴졌습니다하지만 이 ...
# 1              1   s10 5g에서 기변했는데 카페글에 발열 심하다는 얘기가 많아 불안했지만 카메라가...
# 2              2  s21울트라로 기변했습니다침수된 s20는 as비용만 8090만원이 나오는지라저렴하게...
# 3              3  안녕하세요4월 말에 구매해서 지금까지 울트라 잘 사용하고 있습니다s21시리즈 문제때...
# 4              4             사용기종 s21최대가 3435도고 카메라 사용시 36도까지 찍었네요
# ...          ...                                                ...
# 1877        1877  역시 1세대 기술이라서 기대 전혀 안했는데요생각보다 티가 많이나네요저는 좀 예민한 ...
# 1878        1878   폴드2 사용중입니다이번에 UDC 펜 지원 방수 된다고 한데다 리뷰 영상보고 눈돌아...
# 1879        1879                                        udc 쫌  이상함
# 1880        1880  폴드2랑 디자인은 별 차이가 없지만 UDC디스플레이는 좋네요근데 아쉬운점은 흰화면에...
# 1881        1881   UDC는 기대하지 마세요 쓰레기입니다옛날 게임 그래픽 깨진것처럼 그냥 바로 보여요...
#
#                     등록일
# 0     2021.08.12. 10:54
# 1     2021.08.12. 10:39
# 2     2021.08.10. 07:09
# 3     2021.08.09. 17:50
# 4     2021.08.09. 17:00
# ...                 ...
# 1877  2021.08.12. 13:07
# 1878  2021.08.12. 12:45
# 1879  2021.08.12. 12:43
# 1880  2021.08.12. 11:57
# 1881  2021.08.12. 10:40
#
# [1882 rows x 3 columns]

# %%
sam.drop_duplicates(subset = ['내용'], inplace=True) # 중복 제거
sam['내용'] = sam['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
sam['내용'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
sam = sam.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(sam))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 1422
# <ipython-input-108-195377d8e736>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   sam['내용'] = sam['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행

# %%
n = 0
for i in sam["내용"][:]:
    n += 1
    print(n)
    sentiment_predict(i)
# Out:
# 1
# 99.12% 확률로 긍정 리뷰입니다.
#
# 2
# 96.00% 확률로 긍정 리뷰입니다.
#
# 3
# 58.86% 확률로 긍정 리뷰입니다.
#
# 4
# 98.92% 확률로 긍정 리뷰입니다.
#
# 5
# 81.02% 확률로 긍정 리뷰입니다.
#
# 6
# 98.65% 확률로 긍정 리뷰입니다.
#
# 7
# 99.07% 확률로 긍정 리뷰입니다.
#
# 8
# 71.86% 확률로 긍정 리뷰입니다.
#
# 9
# 87.22% 확률로 긍정 리뷰입니다.
#
# 10
# 80.60% 확률로 긍정 리뷰입니다.
#
# 11
# 64.93% 확률로 부정 리뷰입니다.
#
# 12
# 84.31% 확률로 긍정 리뷰입니다.
#
# 13
# 97.93% 확률로 긍정 리뷰입니다.
#
# 14
# 89.29% 확률로 긍정 리뷰입니다.
#
# 15
# 61.81% 확률로 부정 리뷰입니다.
#
# 16
# 50.85% 확률로 부정 리뷰입니다.
#
# 17
# 84.88% 확률로 긍정 리뷰입니다.
#
# 18
# 72.38% 확률로 긍정 리뷰입니다.
#
# 19
# 96.25% 확률로 긍정 리뷰입니다.
#
# 20
# 59.97% 확률로 부정 리뷰입니다.
#
# 21
# 98.36% 확률로 긍정 리뷰입니다.
#
# 22
# 96.94% 확률로 긍정 리뷰입니다.
#
# 23
# 98.38% 확률로 긍정 리뷰입니다.
#
# 24
# 72.09% 확률로 부정 리뷰입니다.
#
# 25
# 98.78% 확률로 긍정 리뷰입니다.
#
# 26
# 98.90% 확률로 긍정 리뷰입니다.
#
# 27
# 89.93% 확률로 긍정 리뷰입니다.
#
# 28
# 99.05% 확률로 긍정 리뷰입니다.
#
# 29
# 99.16% 확률로 긍정 리뷰입니다.
#
# 30
# 91.77% 확률로 긍정 리뷰입니다.
#
# 31
# 97.66% 확률로 긍정 리뷰입니다.
#
# 32
# 74.14% 확률로 부정 리뷰입니다.
#
# 33
# 98.90% 확률로 긍정 리뷰입니다.
#
# 34
# 97.77% 확률로 긍정 리뷰입니다.
#
# 35
# 98.33% 확률로 긍정 리뷰입니다.
#
# 36
# 65.05% 확률로 긍정 리뷰입니다.
#
# 37
# 98.85% 확률로 긍정 리뷰입니다.
#
# 38
# 54.84% 확률로 긍정 리뷰입니다.
#
# 39
# 55.75% 확률로 부정 리뷰입니다.
#
# 40
# 98.51% 확률로 긍정 리뷰입니다.
#
# 41
# 57.64% 확률로 긍정 리뷰입니다.
#
# 42
# 97.34% 확률로 긍정 리뷰입니다.
#
# 43
# 98.92% 확률로 긍정 리뷰입니다.
#
# 44
# 98.02% 확률로 긍정 리뷰입니다.
#
# 45
# 99.21% 확률로 긍정 리뷰입니다.
#
# 46
# 68.87% 확률로 긍정 리뷰입니다.
#
# 47
# 69.35% 확률로 긍정 리뷰입니다.
#
# 48
# 98.53% 확률로 긍정 리뷰입니다.
#
# 49
# 72.44% 확률로 긍정 리뷰입니다.
#
# 50
# 74.55% 확률로 긍정 리뷰입니다.
#
# 51
# 97.28% 확률로 긍정 리뷰입니다.
#
# 52
# 88.93% 확률로 긍정 리뷰입니다.
#
# 53
# 97.38% 확률로 긍정 리뷰입니다.
#
# 54
# 68.12% 확률로 부정 리뷰입니다.
#
# 55
# 80.83% 확률로 긍정 리뷰입니다.
#
# 56
# 92.39% 확률로 긍정 리뷰입니다.
#
# 57
# 97.91% 확률로 긍정 리뷰입니다.
#
# 58
# 58.56% 확률로 부정 리뷰입니다.
#
# 59
# 98.63% 확률로 긍정 리뷰입니다.
#
# 60
# 92.93% 확률로 긍정 리뷰입니다.
#
# 61
# 98.77% 확률로 긍정 리뷰입니다.
#
# 62
# 98.52% 확률로 긍정 리뷰입니다.
#
# 63
# 65.16% 확률로 긍정 리뷰입니다.
#
# 64
# 97.62% 확률로 긍정 리뷰입니다.
#
# 65
# 99.20% 확률로 긍정 리뷰입니다.
#
# 66
# 98.64% 확률로 긍정 리뷰입니다.
#
# 67
# 98.15% 확률로 긍정 리뷰입니다.
#
# 68
# 98.28% 확률로 긍정 리뷰입니다.
#
# 69
# 98.64% 확률로 긍정 리뷰입니다.
#
# 70
# 96.66% 확률로 긍정 리뷰입니다.
#
# 71
# 93.80% 확률로 긍정 리뷰입니다.
#
# 72
# 98.66% 확률로 긍정 리뷰입니다.
#
# 73
# 98.40% 확률로 긍정 리뷰입니다.
#
# 74
# 98.82% 확률로 긍정 리뷰입니다.
#
# 75
# 98.84% 확률로 긍정 리뷰입니다.
#
# 76
# 66.34% 확률로 부정 리뷰입니다.
#
# 77
# 98.88% 확률로 긍정 리뷰입니다.
#
# 78
# 98.69% 확률로 긍정 리뷰입니다.
#
# 79
# 98.61% 확률로 긍정 리뷰입니다.
#
# 80
# 67.23% 확률로 긍정 리뷰입니다.
#
# 81
# 99.23% 확률로 긍정 리뷰입니다.
#
# 82
# 99.19% 확률로 긍정 리뷰입니다.
#
# 83
# 99.28% 확률로 긍정 리뷰입니다.
#
# 84
# 92.08% 확률로 긍정 리뷰입니다.
#
# 85
# 98.13% 확률로 긍정 리뷰입니다.
#
# 86
# 74.42% 확률로 긍정 리뷰입니다.
#
# 87
# 98.73% 확률로 긍정 리뷰입니다.
#
# 88
# 51.87% 확률로 부정 리뷰입니다.
#
# 89
# 97.14% 확률로 긍정 리뷰입니다.
#
# 90
# 83.61% 확률로 긍정 리뷰입니다.
#
# 91
# 99.14% 확률로 긍정 리뷰입니다.
#
# 92
# 96.89% 확률로 긍정 리뷰입니다.
#
# 93
# 99.01% 확률로 긍정 리뷰입니다.
#
# 94
# 89.49% 확률로 긍정 리뷰입니다.
#
# 95
# 99.32% 확률로 긍정 리뷰입니다.
#
# 96
# 59.85% 확률로 부정 리뷰입니다.
#
# 97
# 77.58% 확률로 긍정 리뷰입니다.
#
# 98
# 99.05% 확률로 긍정 리뷰입니다.
#
# 99
# 52.79% 확률로 긍정 리뷰입니다.
#
# 100
# 51.12% 확률로 긍정 리뷰입니다.
#
# 101
# 54.85% 확률로 부정 리뷰입니다.
#
# 102
# 55.60% 확률로 긍정 리뷰입니다.
#
# 103
# 98.07% 확률로 긍정 리뷰입니다.
#
# 104
# 98.14% 확률로 긍정 리뷰입니다.
#
# 105
# 98.75% 확률로 긍정 리뷰입니다.
#
# 106
# 97.82% 확률로 긍정 리뷰입니다.
#
# 107
# 68.45% 확률로 긍정 리뷰입니다.
#
# 108
# 55.88% 확률로 긍정 리뷰입니다.
#
# 109
# 89.95% 확률로 긍정 리뷰입니다.
#
# 110
# 98.30% 확률로 긍정 리뷰입니다.
#
# 111
# 80.00% 확률로 부정 리뷰입니다.
#
# 112
# 93.83% 확률로 긍정 리뷰입니다.
#
# 113
# 98.53% 확률로 긍정 리뷰입니다.
#
# 114
# 89.37% 확률로 긍정 리뷰입니다.
#
# 115
# 94.17% 확률로 긍정 리뷰입니다.
#
# 116
# 77.05% 확률로 긍정 리뷰입니다.
#
# 117
# 81.50% 확률로 긍정 리뷰입니다.
#
# 118
# 98.41% 확률로 긍정 리뷰입니다.
#
# 119
# 69.95% 확률로 긍정 리뷰입니다.
#
# 120
# 99.14% 확률로 긍정 리뷰입니다.
#
# 121
# 54.95% 확률로 긍정 리뷰입니다.
#
# 122
# 64.76% 확률로 긍정 리뷰입니다.
#
# 123
# 96.83% 확률로 긍정 리뷰입니다.
#
# 124
# 80.99% 확률로 긍정 리뷰입니다.
#
# 125
# 81.85% 확률로 긍정 리뷰입니다.
#
# 126
# 90.41% 확률로 긍정 리뷰입니다.
#
# 127
# 64.11% 확률로 부정 리뷰입니다.
#
# 128
# 98.93% 확률로 긍정 리뷰입니다.
#
# 129
# 73.11% 확률로 긍정 리뷰입니다.
#
# 130
# 98.07% 확률로 긍정 리뷰입니다.
#
# 131
# 98.05% 확률로 긍정 리뷰입니다.
#
# 132
# 50.21% 확률로 부정 리뷰입니다.
#
# 133
# 97.79% 확률로 긍정 리뷰입니다.
#
# 134
# 99.51% 확률로 긍정 리뷰입니다.
#
# 135
# 98.87% 확률로 긍정 리뷰입니다.
#
# 136
# 98.76% 확률로 긍정 리뷰입니다.
#
# 137
# 98.41% 확률로 긍정 리뷰입니다.
#
# 138
# 97.81% 확률로 긍정 리뷰입니다.
#
# 139
# 98.68% 확률로 긍정 리뷰입니다.
#
# 140
# 53.91% 확률로 긍정 리뷰입니다.
#
# 141
# 81.13% 확률로 긍정 리뷰입니다.
#
# 142
# 98.99% 확률로 긍정 리뷰입니다.
#
# 143
# 98.64% 확률로 긍정 리뷰입니다.
#
# 144
# 98.36% 확률로 긍정 리뷰입니다.
#
# 145
# 87.07% 확률로 긍정 리뷰입니다.
#
# 146
# 61.85% 확률로 긍정 리뷰입니다.
#
# 147
# 93.02% 확률로 긍정 리뷰입니다.
#
# 148
# 97.55% 확률로 긍정 리뷰입니다.
#
# 149
# 97.95% 확률로 긍정 리뷰입니다.
#
# 150
# 98.84% 확률로 긍정 리뷰입니다.
#
# 151
# 75.69% 확률로 긍정 리뷰입니다.
#
# 152
# 92.92% 확률로 긍정 리뷰입니다.
#
# 153
# 97.34% 확률로 긍정 리뷰입니다.
#
# 154
# 66.47% 확률로 부정 리뷰입니다.
#
# 155
# 97.87% 확률로 긍정 리뷰입니다.
#
# 156
# 59.68% 확률로 긍정 리뷰입니다.
#
# 157
# 98.76% 확률로 긍정 리뷰입니다.
#
# 158
# 97.99% 확률로 긍정 리뷰입니다.
#
# 159
# 96.60% 확률로 긍정 리뷰입니다.
#
# 160
# 56.99% 확률로 부정 리뷰입니다.
#
# 161
# 83.25% 확률로 긍정 리뷰입니다.
#
# 162
# 58.38% 확률로 긍정 리뷰입니다.
#
# 163
# 98.29% 확률로 긍정 리뷰입니다.
#
# 164
# 71.29% 확률로 부정 리뷰입니다.
#
# 165
# 98.68% 확률로 긍정 리뷰입니다.
#
# 166
# 96.98% 확률로 긍정 리뷰입니다.
#
# 167
# 90.98% 확률로 긍정 리뷰입니다.
#
# 168
# 95.95% 확률로 긍정 리뷰입니다.
#
# 169
# 95.34% 확률로 긍정 리뷰입니다.
#
# 170
# 98.73% 확률로 긍정 리뷰입니다.
#
# 171
# 74.15% 확률로 긍정 리뷰입니다.
#
# 172
# 97.79% 확률로 긍정 리뷰입니다.
#
# 173
# 98.41% 확률로 긍정 리뷰입니다.
#
# 174
# 87.88% 확률로 긍정 리뷰입니다.
#
# 175
# 98.98% 확률로 긍정 리뷰입니다.
#
# 176
# 63.62% 확률로 긍정 리뷰입니다.
#
# 177
# 99.36% 확률로 긍정 리뷰입니다.
#
# 178
# 97.80% 확률로 긍정 리뷰입니다.
#
# 179
# 99.28% 확률로 긍정 리뷰입니다.
#
# 180
# 97.28% 확률로 긍정 리뷰입니다.
#
# 181
# 72.94% 확률로 부정 리뷰입니다.
#
# 182
# 97.90% 확률로 긍정 리뷰입니다.
#
# 183
# 95.32% 확률로 긍정 리뷰입니다.
#
# 184
# 98.80% 확률로 긍정 리뷰입니다.
#
# 185
# 94.55% 확률로 긍정 리뷰입니다.
#
# 186
# 77.42% 확률로 부정 리뷰입니다.
#
# 187
# 99.31% 확률로 긍정 리뷰입니다.
#
# 188
# 99.26% 확률로 긍정 리뷰입니다.
#
# 189
# 98.18% 확률로 긍정 리뷰입니다.
#
# 190
# 98.70% 확률로 긍정 리뷰입니다.
#
# 191
# 98.25% 확률로 긍정 리뷰입니다.
#
# 192
# 91.14% 확률로 긍정 리뷰입니다.
#
# 193
# 96.29% 확률로 긍정 리뷰입니다.
#
# 194
# 83.11% 확률로 긍정 리뷰입니다.
#
# 195
# 91.20% 확률로 긍정 리뷰입니다.
#
# 196
# 80.52% 확률로 부정 리뷰입니다.
#
# 197
# 91.79% 확률로 긍정 리뷰입니다.
#
# 198
# 98.60% 확률로 긍정 리뷰입니다.
#
# 199
# 97.77% 확률로 긍정 리뷰입니다.
#
# 200
# 63.22% 확률로 부정 리뷰입니다.
#
# 201
# 98.60% 확률로 긍정 리뷰입니다.
#
# 202
# 98.60% 확률로 긍정 리뷰입니다.
#
# 203
# 98.11% 확률로 긍정 리뷰입니다.
#
# 204
# 99.44% 확률로 긍정 리뷰입니다.
#
# 205
# 98.88% 확률로 긍정 리뷰입니다.
#
# 206
# 99.23% 확률로 긍정 리뷰입니다.
#
# 207
# 96.37% 확률로 긍정 리뷰입니다.
#
# 208
# 98.69% 확률로 긍정 리뷰입니다.
#
# 209
# 96.82% 확률로 긍정 리뷰입니다.
#
# 210
# 98.60% 확률로 긍정 리뷰입니다.
#
# 211
# 98.59% 확률로 긍정 리뷰입니다.
#
# 212
# 99.11% 확률로 긍정 리뷰입니다.
#
# 213
# 98.92% 확률로 긍정 리뷰입니다.
#
# 214
# 99.21% 확률로 긍정 리뷰입니다.
#
# 215
# 98.56% 확률로 긍정 리뷰입니다.
#
# 216
# 98.02% 확률로 긍정 리뷰입니다.
#
# 217
# 78.06% 확률로 부정 리뷰입니다.
#
# 218
# 56.21% 확률로 긍정 리뷰입니다.
#
# 219
# 98.93% 확률로 긍정 리뷰입니다.
#
# 220
# 98.08% 확률로 긍정 리뷰입니다.
#
# 221
# 98.12% 확률로 긍정 리뷰입니다.
#
# 222
# 95.15% 확률로 긍정 리뷰입니다.
#
# 223
# 74.35% 확률로 긍정 리뷰입니다.
#
# 224
# 97.46% 확률로 긍정 리뷰입니다.
#
# 225
# 96.33% 확률로 긍정 리뷰입니다.
#
# 226
# 98.73% 확률로 긍정 리뷰입니다.
#
# 227
# 98.50% 확률로 긍정 리뷰입니다.
#
# 228
# 99.11% 확률로 긍정 리뷰입니다.
#
# 229
# 99.12% 확률로 긍정 리뷰입니다.
#
# 230
# 99.15% 확률로 긍정 리뷰입니다.
#
# 231
# 98.69% 확률로 긍정 리뷰입니다.
#
# 232
# 98.87% 확률로 긍정 리뷰입니다.
#
# 233
# 97.93% 확률로 긍정 리뷰입니다.
#
# 234
# 98.75% 확률로 긍정 리뷰입니다.
#
# 235
# 87.95% 확률로 긍정 리뷰입니다.
#
# 236
# 99.29% 확률로 긍정 리뷰입니다.
#
# 237
# 99.07% 확률로 긍정 리뷰입니다.
#
# 238
# 53.98% 확률로 부정 리뷰입니다.
#
# 239
# 54.28% 확률로 긍정 리뷰입니다.
#
# 240
# 89.04% 확률로 긍정 리뷰입니다.
#
# 241
# 50.95% 확률로 긍정 리뷰입니다.
#
# 242
# 89.47% 확률로 긍정 리뷰입니다.
#
# 243
# 98.59% 확률로 긍정 리뷰입니다.
#
# 244
# 99.40% 확률로 긍정 리뷰입니다.
#
# 245
# 97.83% 확률로 긍정 리뷰입니다.
#
# 246
# 98.52% 확률로 긍정 리뷰입니다.
#
# 247
# 82.16% 확률로 긍정 리뷰입니다.
#
# 248
# 98.06% 확률로 긍정 리뷰입니다.
#
# 249
# 93.79% 확률로 긍정 리뷰입니다.
#
# 250
# 97.45% 확률로 긍정 리뷰입니다.
#
# 251
# 96.10% 확률로 긍정 리뷰입니다.
#
# 252
# 99.55% 확률로 긍정 리뷰입니다.
#
# 253
# 59.56% 확률로 긍정 리뷰입니다.
#
# 254
# 68.85% 확률로 긍정 리뷰입니다.
#
# 255
# 99.29% 확률로 긍정 리뷰입니다.
#
# 256
# 98.65% 확률로 긍정 리뷰입니다.
#
# 257
# 91.76% 확률로 긍정 리뷰입니다.
#
# 258
# 98.78% 확률로 긍정 리뷰입니다.
#
# 259
# 91.46% 확률로 긍정 리뷰입니다.
#
# 260
# 96.65% 확률로 긍정 리뷰입니다.
#
# 261
# 99.17% 확률로 긍정 리뷰입니다.
#
# 262
# 70.54% 확률로 긍정 리뷰입니다.
#
# 263
# 99.24% 확률로 긍정 리뷰입니다.
#
# 264
# 56.23% 확률로 부정 리뷰입니다.
#
# 265
# 54.91% 확률로 긍정 리뷰입니다.
#
# 266
# 75.91% 확률로 긍정 리뷰입니다.
#
# 267
# 97.19% 확률로 긍정 리뷰입니다.
#
# 268
# 97.54% 확률로 긍정 리뷰입니다.
#
# 269
# 98.94% 확률로 긍정 리뷰입니다.
#
# 270
# 82.18% 확률로 부정 리뷰입니다.
#
# 271
# 96.96% 확률로 긍정 리뷰입니다.
#
# 272
# 63.85% 확률로 긍정 리뷰입니다.
#
# 273
# 55.92% 확률로 긍정 리뷰입니다.
#
# 274
# 95.59% 확률로 긍정 리뷰입니다.
#
# 275
# 60.34% 확률로 부정 리뷰입니다.
#
# 276
# 96.43% 확률로 긍정 리뷰입니다.
#
# 277
# 98.94% 확률로 긍정 리뷰입니다.
#
# 278
# 97.97% 확률로 긍정 리뷰입니다.
#
# 279
# 97.92% 확률로 긍정 리뷰입니다.
#
# 280
# 98.29% 확률로 긍정 리뷰입니다.
#
# 281
# 98.46% 확률로 긍정 리뷰입니다.
#
# 282
# 98.69% 확률로 긍정 리뷰입니다.
#
# 283
# 99.03% 확률로 긍정 리뷰입니다.
#
# 284
# 98.95% 확률로 긍정 리뷰입니다.
#
# 285
# 99.09% 확률로 긍정 리뷰입니다.
#
# 286
# 87.81% 확률로 긍정 리뷰입니다.
#
# 287
# 99.16% 확률로 긍정 리뷰입니다.
#
# 288
# 98.80% 확률로 긍정 리뷰입니다.
#
# 289
# 99.53% 확률로 긍정 리뷰입니다.
#
# 290
# 98.96% 확률로 긍정 리뷰입니다.
#
# 291
# 99.15% 확률로 긍정 리뷰입니다.
#
# 292
# 99.14% 확률로 긍정 리뷰입니다.
#
# 293
# 63.85% 확률로 긍정 리뷰입니다.
#
# 294
# 98.86% 확률로 긍정 리뷰입니다.
#
# 295
# 98.48% 확률로 긍정 리뷰입니다.
#
# 296
# 98.88% 확률로 긍정 리뷰입니다.
#
# 297
# 53.91% 확률로 긍정 리뷰입니다.
#
# 298
# 97.66% 확률로 긍정 리뷰입니다.
#
# 299
# 98.90% 확률로 긍정 리뷰입니다.
#
# 300
# 92.42% 확률로 긍정 리뷰입니다.
#
# 301
# 52.22% 확률로 긍정 리뷰입니다.
#
# 302
# 73.21% 확률로 긍정 리뷰입니다.
#
# 303
# 57.28% 확률로 부정 리뷰입니다.
#
# 304
# 98.46% 확률로 긍정 리뷰입니다.
#
# 305
# 98.73% 확률로 긍정 리뷰입니다.
#
# 306
# 98.98% 확률로 긍정 리뷰입니다.
#
# 307
# 86.81% 확률로 긍정 리뷰입니다.
#
# 308
# 99.38% 확률로 긍정 리뷰입니다.
#
# 309
# 99.38% 확률로 긍정 리뷰입니다.
#
# 310
# 98.95% 확률로 긍정 리뷰입니다.
#
# 311
# 98.65% 확률로 긍정 리뷰입니다.
#
# 312
# 98.19% 확률로 긍정 리뷰입니다.
#
# 313
# 94.72% 확률로 긍정 리뷰입니다.
#
# 314
# 96.16% 확률로 긍정 리뷰입니다.
#
# 315
# 97.55% 확률로 긍정 리뷰입니다.
#
# 316
# 73.62% 확률로 부정 리뷰입니다.
#
# 317
# 98.06% 확률로 긍정 리뷰입니다.
#
# 318
# 99.49% 확률로 긍정 리뷰입니다.
#
# 319
# 98.41% 확률로 긍정 리뷰입니다.
#
# 320
# 98.88% 확률로 긍정 리뷰입니다.
#
# 321
# 99.15% 확률로 긍정 리뷰입니다.
#
# 322
# 99.05% 확률로 긍정 리뷰입니다.
#
# 323
# 98.66% 확률로 긍정 리뷰입니다.
#
# 324
# 60.46% 확률로 부정 리뷰입니다.
#
# 325
# 99.37% 확률로 긍정 리뷰입니다.
#
# 326
# 98.87% 확률로 긍정 리뷰입니다.
#
# 327
# 98.74% 확률로 긍정 리뷰입니다.
#
# 328
# 86.25% 확률로 긍정 리뷰입니다.
#
# 329
# 92.77% 확률로 긍정 리뷰입니다.
#
# 330
# 97.65% 확률로 긍정 리뷰입니다.
#
# 331
# 98.91% 확률로 긍정 리뷰입니다.
#
# 332
# 99.22% 확률로 긍정 리뷰입니다.
#
# 333
# 99.26% 확률로 긍정 리뷰입니다.
#
# 334
# 97.92% 확률로 긍정 리뷰입니다.
#
# 335
# 99.26% 확률로 긍정 리뷰입니다.
#
# 336
# 75.70% 확률로 긍정 리뷰입니다.
#
# 337
# 98.72% 확률로 긍정 리뷰입니다.
#
# 338
# 55.53% 확률로 부정 리뷰입니다.
#
# 339
# 60.16% 확률로 긍정 리뷰입니다.
#
# 340
# 96.70% 확률로 긍정 리뷰입니다.
#
# 341
# 98.97% 확률로 긍정 리뷰입니다.
#
# 342
# 52.53% 확률로 긍정 리뷰입니다.
#
# 343
# 98.20% 확률로 긍정 리뷰입니다.
#
# 344
# 98.61% 확률로 긍정 리뷰입니다.
#
# 345
# 98.19% 확률로 긍정 리뷰입니다.
#
# 346
# 61.18% 확률로 긍정 리뷰입니다.
#
# 347
# 95.19% 확률로 긍정 리뷰입니다.
#
# 348
# 99.35% 확률로 긍정 리뷰입니다.
#
# 349
# 99.08% 확률로 긍정 리뷰입니다.
#
# 350
# 88.29% 확률로 긍정 리뷰입니다.
#
# 351
# 96.08% 확률로 긍정 리뷰입니다.
#
# 352
# 73.27% 확률로 긍정 리뷰입니다.
#
# 353
# 58.80% 확률로 긍정 리뷰입니다.
#
# 354
# 65.33% 확률로 부정 리뷰입니다.
#
# 355
# 98.86% 확률로 긍정 리뷰입니다.
#
# 356
# 90.29% 확률로 긍정 리뷰입니다.
#
# 357
# 95.44% 확률로 긍정 리뷰입니다.
#
# 358
# 72.86% 확률로 긍정 리뷰입니다.
#
# 359
# 63.88% 확률로 긍정 리뷰입니다.
#
# 360
# 99.20% 확률로 긍정 리뷰입니다.
#
# 361
# 98.96% 확률로 긍정 리뷰입니다.
#
# 362
# 73.41% 확률로 긍정 리뷰입니다.
#
# 363
# 98.42% 확률로 긍정 리뷰입니다.
#
# 364
# 98.25% 확률로 긍정 리뷰입니다.
#
# 365
# 93.81% 확률로 긍정 리뷰입니다.
#
# 366
# 98.83% 확률로 긍정 리뷰입니다.
#
# 367
# 57.35% 확률로 부정 리뷰입니다.
#
# 368
# 94.41% 확률로 긍정 리뷰입니다.
#
# 369
# 99.35% 확률로 긍정 리뷰입니다.
#
# 370
# 76.03% 확률로 긍정 리뷰입니다.
#
# 371
# 57.33% 확률로 부정 리뷰입니다.
#
# 372
# 98.17% 확률로 긍정 리뷰입니다.
#
# 373
# 77.81% 확률로 긍정 리뷰입니다.
#
# 374
# 82.74% 확률로 긍정 리뷰입니다.
#
# 375
# 61.16% 확률로 긍정 리뷰입니다.
#
# 376
# 94.41% 확률로 긍정 리뷰입니다.
#
# 377
# 98.96% 확률로 긍정 리뷰입니다.
#
# 378
# 98.53% 확률로 긍정 리뷰입니다.
#
# 379
# 72.54% 확률로 긍정 리뷰입니다.
#
# 380
# 93.32% 확률로 긍정 리뷰입니다.
#
# 381
# 98.71% 확률로 긍정 리뷰입니다.
#
# 382
# 90.09% 확률로 긍정 리뷰입니다.
#
# 383
# 73.84% 확률로 긍정 리뷰입니다.
#
# 384
# 96.01% 확률로 긍정 리뷰입니다.
#
# 385
# 95.19% 확률로 긍정 리뷰입니다.
#
# 386
# 98.78% 확률로 긍정 리뷰입니다.
#
# 387
# 64.04% 확률로 긍정 리뷰입니다.
#
# 388
# 98.59% 확률로 긍정 리뷰입니다.
#
# 389
# 98.98% 확률로 긍정 리뷰입니다.
#
# 390
# 61.77% 확률로 긍정 리뷰입니다.
#
# 391
# 99.12% 확률로 긍정 리뷰입니다.
#
# 392
# 98.63% 확률로 긍정 리뷰입니다.
#
# 393
# 65.14% 확률로 긍정 리뷰입니다.
#
# 394
# 55.17% 확률로 긍정 리뷰입니다.
#
# 395
# 98.33% 확률로 긍정 리뷰입니다.
#
# 396
# 98.03% 확률로 긍정 리뷰입니다.
#
# 397
# 99.21% 확률로 긍정 리뷰입니다.
#
# 398
# 98.78% 확률로 긍정 리뷰입니다.
#
# 399
# 98.01% 확률로 긍정 리뷰입니다.
#
# 400
# 94.99% 확률로 긍정 리뷰입니다.
#
# 401
# 99.00% 확률로 긍정 리뷰입니다.
#
# 402
# 60.76% 확률로 긍정 리뷰입니다.
#
# 403
# 98.86% 확률로 긍정 리뷰입니다.
#
# 404
# 97.49% 확률로 긍정 리뷰입니다.
#
# 405
# 50.55% 확률로 부정 리뷰입니다.
#
# 406
# 99.26% 확률로 긍정 리뷰입니다.
#
# 407
# 98.83% 확률로 긍정 리뷰입니다.
#
# 408
# 97.65% 확률로 긍정 리뷰입니다.
#
# 409
# 97.36% 확률로 긍정 리뷰입니다.
#
# 410
# 97.72% 확률로 긍정 리뷰입니다.
#
# 411
# 98.99% 확률로 긍정 리뷰입니다.
#
# 412
# 99.19% 확률로 긍정 리뷰입니다.
#
# 413
# 98.10% 확률로 긍정 리뷰입니다.
#
# 414
# 55.29% 확률로 긍정 리뷰입니다.
#
# 415
# 98.26% 확률로 긍정 리뷰입니다.
#
# 416
# 61.09% 확률로 긍정 리뷰입니다.
#
# 417
# 99.15% 확률로 긍정 리뷰입니다.
#
# 418
# 86.00% 확률로 긍정 리뷰입니다.
#
# 419
# 58.14% 확률로 부정 리뷰입니다.
#
# 420
# 80.54% 확률로 긍정 리뷰입니다.
#
# 421
# 99.40% 확률로 긍정 리뷰입니다.
#
# 422
# 71.72% 확률로 긍정 리뷰입니다.
#
# 423
# 98.39% 확률로 긍정 리뷰입니다.
#
# 424
# 93.59% 확률로 긍정 리뷰입니다.
#
# 425
# 98.90% 확률로 긍정 리뷰입니다.
#
# 426
# 97.16% 확률로 긍정 리뷰입니다.
#
# 427
# 98.49% 확률로 긍정 리뷰입니다.
#
# 428
# 98.54% 확률로 긍정 리뷰입니다.
#
# 429
# 95.94% 확률로 긍정 리뷰입니다.
#
# 430
# 96.56% 확률로 긍정 리뷰입니다.
#
# 431
# 69.46% 확률로 긍정 리뷰입니다.
#
# 432
# 88.92% 확률로 긍정 리뷰입니다.
#
# 433
# 98.27% 확률로 긍정 리뷰입니다.
#
# 434
# 98.83% 확률로 긍정 리뷰입니다.
#
# 435
# 97.97% 확률로 긍정 리뷰입니다.
#
# 436
# 53.01% 확률로 긍정 리뷰입니다.
#
# 437
# 64.45% 확률로 부정 리뷰입니다.
#
# 438
# 81.37% 확률로 긍정 리뷰입니다.
#
# 439
# 92.61% 확률로 부정 리뷰입니다.
#
# 440
# 98.09% 확률로 긍정 리뷰입니다.
#
# 441
# 62.34% 확률로 긍정 리뷰입니다.
#
# 442
# 98.71% 확률로 긍정 리뷰입니다.
#
# 443
# 98.14% 확률로 긍정 리뷰입니다.
#
# 444
# 57.67% 확률로 부정 리뷰입니다.
#
# 445
# 56.50% 확률로 긍정 리뷰입니다.
#
# 446
# 95.02% 확률로 긍정 리뷰입니다.
#
# 447
# 66.30% 확률로 부정 리뷰입니다.
#
# 448
# 98.19% 확률로 긍정 리뷰입니다.
#
# 449
# 90.57% 확률로 긍정 리뷰입니다.
#
# 450
# 97.71% 확률로 긍정 리뷰입니다.
#
# 451
# 98.41% 확률로 긍정 리뷰입니다.
#
# 452
# 99.29% 확률로 긍정 리뷰입니다.
#
# 453
# 71.72% 확률로 긍정 리뷰입니다.
#
# 454
# 97.17% 확률로 긍정 리뷰입니다.
#
# 455
# 62.85% 확률로 긍정 리뷰입니다.
#
# 456
# 60.31% 확률로 부정 리뷰입니다.
#
# 457
# 98.96% 확률로 긍정 리뷰입니다.
#
# 458
# 54.55% 확률로 긍정 리뷰입니다.
#
# 459
# 99.27% 확률로 긍정 리뷰입니다.
#
# 460
# 97.93% 확률로 긍정 리뷰입니다.
#
# 461
# 99.46% 확률로 긍정 리뷰입니다.
#
# 462
# 98.63% 확률로 긍정 리뷰입니다.
#
# 463
# 98.63% 확률로 긍정 리뷰입니다.
#
# 464
# 99.38% 확률로 긍정 리뷰입니다.
#
# 465
# 99.01% 확률로 긍정 리뷰입니다.
#
# 466
# 98.55% 확률로 긍정 리뷰입니다.
#
# 467
# 99.04% 확률로 긍정 리뷰입니다.
#
# 468
# 99.43% 확률로 긍정 리뷰입니다.
#
# 469
# 94.04% 확률로 긍정 리뷰입니다.
#
# 470
# 99.45% 확률로 긍정 리뷰입니다.
#
# 471
# 98.75% 확률로 긍정 리뷰입니다.
#
# 472
# 54.77% 확률로 긍정 리뷰입니다.
#
# 473
# 97.87% 확률로 긍정 리뷰입니다.
#
# 474
# 63.80% 확률로 부정 리뷰입니다.
#
# 475
# 83.05% 확률로 부정 리뷰입니다.
#
# 476
# 98.75% 확률로 긍정 리뷰입니다.
#
# 477
# 99.25% 확률로 긍정 리뷰입니다.
#
# 478
# 96.03% 확률로 긍정 리뷰입니다.
#
# 479
# 98.32% 확률로 긍정 리뷰입니다.
#
# 480
# 98.77% 확률로 긍정 리뷰입니다.
#
# 481
# 99.24% 확률로 긍정 리뷰입니다.
#
# 482
# 98.37% 확률로 긍정 리뷰입니다.
#
# 483
# 98.48% 확률로 긍정 리뷰입니다.
#
# 484
# 94.80% 확률로 긍정 리뷰입니다.
#
# 485
# 99.45% 확률로 긍정 리뷰입니다.
#
# 486
# 98.97% 확률로 긍정 리뷰입니다.
#
# 487
# 83.24% 확률로 긍정 리뷰입니다.
#
# 488
# 62.40% 확률로 긍정 리뷰입니다.
#
# 489
# 99.09% 확률로 긍정 리뷰입니다.
#
# 490
# 97.36% 확률로 긍정 리뷰입니다.
#
# 491
# 84.05% 확률로 부정 리뷰입니다.
#
# 492
# 99.01% 확률로 긍정 리뷰입니다.
#
# 493
# 98.62% 확률로 긍정 리뷰입니다.
#
# 494
# 91.51% 확률로 긍정 리뷰입니다.
#
# 495
# 98.64% 확률로 긍정 리뷰입니다.
#
# 496
# 98.96% 확률로 긍정 리뷰입니다.
#
# 497
# 98.02% 확률로 긍정 리뷰입니다.
#
# 498
# 99.47% 확률로 긍정 리뷰입니다.
#
# 499
# 99.37% 확률로 긍정 리뷰입니다.
#
# 500
# 74.38% 확률로 부정 리뷰입니다.
#
# 501
# 71.59% 확률로 부정 리뷰입니다.
#
# 502
# 96.25% 확률로 긍정 리뷰입니다.
#
# 503
# 98.85% 확률로 긍정 리뷰입니다.
#
# 504
# 98.68% 확률로 긍정 리뷰입니다.
#
# 505
# 83.02% 확률로 긍정 리뷰입니다.
#
# 506
# 95.10% 확률로 긍정 리뷰입니다.
#
# 507
# 82.95% 확률로 긍정 리뷰입니다.
#
# 508
# 98.22% 확률로 긍정 리뷰입니다.
#
# 509
# 97.14% 확률로 긍정 리뷰입니다.
#
# 510
# 50.22% 확률로 부정 리뷰입니다.
#
# 511
# 98.84% 확률로 긍정 리뷰입니다.
#
# 512
# 56.10% 확률로 부정 리뷰입니다.
#
# 513
# 89.31% 확률로 긍정 리뷰입니다.
#
# 514
# 98.90% 확률로 긍정 리뷰입니다.
#
# 515
# 82.23% 확률로 긍정 리뷰입니다.
#
# 516
# 52.70% 확률로 부정 리뷰입니다.
#
# 517
# 52.37% 확률로 긍정 리뷰입니다.
#
# 518
# 99.31% 확률로 긍정 리뷰입니다.
#
# 519
# 99.42% 확률로 긍정 리뷰입니다.
#
# 520
# 77.85% 확률로 긍정 리뷰입니다.
#
# 521
# 84.28% 확률로 긍정 리뷰입니다.
#
# 522
# 99.04% 확률로 긍정 리뷰입니다.
#
# 523
# 60.80% 확률로 긍정 리뷰입니다.
#
# 524
# 99.23% 확률로 긍정 리뷰입니다.
#
# 525
# 81.55% 확률로 긍정 리뷰입니다.
#
# 526
# 91.83% 확률로 긍정 리뷰입니다.
#
# 527
# 99.02% 확률로 긍정 리뷰입니다.
#
# 528
# 97.84% 확률로 긍정 리뷰입니다.
#
# 529
# 99.32% 확률로 긍정 리뷰입니다.
#
# 530
# 75.08% 확률로 긍정 리뷰입니다.
#
# 531
# 98.89% 확률로 긍정 리뷰입니다.
#
# 532
# 52.07% 확률로 부정 리뷰입니다.
#
# 533
# 98.28% 확률로 긍정 리뷰입니다.
#
# 534
# 97.99% 확률로 긍정 리뷰입니다.
#
# 535
# 66.00% 확률로 긍정 리뷰입니다.
#
# 536
# 64.39% 확률로 부정 리뷰입니다.
#
# 537
# 95.27% 확률로 긍정 리뷰입니다.
#
# 538
# 98.80% 확률로 긍정 리뷰입니다.
#
# 539
# 97.62% 확률로 긍정 리뷰입니다.
#
# 540
# 98.79% 확률로 긍정 리뷰입니다.
#
# 541
# 97.39% 확률로 긍정 리뷰입니다.
#
# 542
# 98.98% 확률로 긍정 리뷰입니다.
#
# 543
# 52.17% 확률로 긍정 리뷰입니다.
#
# 544
# 77.58% 확률로 긍정 리뷰입니다.
#
# 545
# 93.65% 확률로 긍정 리뷰입니다.
#
# 546
# 72.74% 확률로 긍정 리뷰입니다.
#
# 547
# 98.62% 확률로 긍정 리뷰입니다.
#
# 548
# 64.70% 확률로 긍정 리뷰입니다.
#
# 549
# 99.40% 확률로 긍정 리뷰입니다.
#
# 550
# 51.04% 확률로 긍정 리뷰입니다.
#
# 551
# 98.78% 확률로 긍정 리뷰입니다.
#
# 552
# 98.42% 확률로 긍정 리뷰입니다.
#
# 553
# 68.44% 확률로 긍정 리뷰입니다.
#
# 554
# 97.69% 확률로 긍정 리뷰입니다.
#
# 555
# 56.67% 확률로 긍정 리뷰입니다.
#
# 556
# 97.93% 확률로 긍정 리뷰입니다.
#
# 557
# 87.92% 확률로 긍정 리뷰입니다.
#
# 558
# 99.41% 확률로 긍정 리뷰입니다.
#
# 559
# 99.24% 확률로 긍정 리뷰입니다.
#
# 560
# 96.13% 확률로 긍정 리뷰입니다.
#
# 561
# 60.03% 확률로 긍정 리뷰입니다.
#
# 562
# 94.52% 확률로 긍정 리뷰입니다.
#
# 563
# 98.86% 확률로 긍정 리뷰입니다.
#
# 564
# 98.04% 확률로 긍정 리뷰입니다.
#
# 565
# 53.92% 확률로 긍정 리뷰입니다.
#
# 566
# 98.05% 확률로 긍정 리뷰입니다.
#
# 567
# 96.71% 확률로 긍정 리뷰입니다.
#
# 568
# 57.04% 확률로 부정 리뷰입니다.
#
# 569
# 98.77% 확률로 긍정 리뷰입니다.
#
# 570
# 99.11% 확률로 긍정 리뷰입니다.
#
# 571
# 98.96% 확률로 긍정 리뷰입니다.
#
# 572
# 81.98% 확률로 긍정 리뷰입니다.
#
# 573
# 65.20% 확률로 긍정 리뷰입니다.
#
# 574
# 98.42% 확률로 긍정 리뷰입니다.
#
# 575
# 51.60% 확률로 긍정 리뷰입니다.
#
# 576
# 98.82% 확률로 긍정 리뷰입니다.
#
# 577
# 98.77% 확률로 긍정 리뷰입니다.
#
# 578
# 78.95% 확률로 긍정 리뷰입니다.
#
# 579
# 62.93% 확률로 부정 리뷰입니다.
#
# 580
# 79.71% 확률로 부정 리뷰입니다.
#
# 581
# 98.36% 확률로 긍정 리뷰입니다.
#
# 582
# 60.88% 확률로 긍정 리뷰입니다.
#
# 583
# 72.65% 확률로 긍정 리뷰입니다.
#
# 584
# 98.96% 확률로 긍정 리뷰입니다.
#
# 585
# 97.30% 확률로 긍정 리뷰입니다.
#
# 586
# 99.09% 확률로 긍정 리뷰입니다.
#
# 587
# 99.51% 확률로 긍정 리뷰입니다.
#
# 588
# 99.47% 확률로 긍정 리뷰입니다.
#
# 589
# 98.83% 확률로 긍정 리뷰입니다.
#
# 590
# 75.18% 확률로 긍정 리뷰입니다.
#
# 591
# 55.75% 확률로 부정 리뷰입니다.
#
# 592
# 54.46% 확률로 긍정 리뷰입니다.
#
# 593
# 96.95% 확률로 긍정 리뷰입니다.
#
# 594
# 99.06% 확률로 긍정 리뷰입니다.
#
# 595
# 97.63% 확률로 긍정 리뷰입니다.
#
# 596
# 99.43% 확률로 긍정 리뷰입니다.
#
# 597
# 98.96% 확률로 긍정 리뷰입니다.
#
# 598
# 98.23% 확률로 긍정 리뷰입니다.
#
# 599
# 72.77% 확률로 긍정 리뷰입니다.
#
# 600
# 94.38% 확률로 긍정 리뷰입니다.
#
# 601
# 86.31% 확률로 긍정 리뷰입니다.
#
# 602
# 97.95% 확률로 긍정 리뷰입니다.
#
# 603
# 99.49% 확률로 긍정 리뷰입니다.
#
# 604
# 98.27% 확률로 긍정 리뷰입니다.
#
# 605
# 90.85% 확률로 긍정 리뷰입니다.
#
# 606
# 77.29% 확률로 긍정 리뷰입니다.
#
# 607
# 66.06% 확률로 긍정 리뷰입니다.
#
# 608
# 98.56% 확률로 긍정 리뷰입니다.
#
# 609
# 84.82% 확률로 긍정 리뷰입니다.
#
# 610
# 58.15% 확률로 부정 리뷰입니다.
#
# 611
# 51.15% 확률로 부정 리뷰입니다.
#
# 612
# 98.55% 확률로 긍정 리뷰입니다.
#
# 613
# 98.31% 확률로 긍정 리뷰입니다.
#
# 614
# 98.56% 확률로 긍정 리뷰입니다.
#
# 615
# 76.87% 확률로 긍정 리뷰입니다.
#
# 616
# 98.63% 확률로 긍정 리뷰입니다.
#
# 617
# 98.24% 확률로 긍정 리뷰입니다.
#
# 618
# 98.79% 확률로 긍정 리뷰입니다.
#
# 619
# 60.48% 확률로 부정 리뷰입니다.
#
# 620
# 62.00% 확률로 긍정 리뷰입니다.
#
# 621
# 99.14% 확률로 긍정 리뷰입니다.
#
# 622
# 97.90% 확률로 긍정 리뷰입니다.
#
# 623
# 51.21% 확률로 긍정 리뷰입니다.
#
# 624
# 73.51% 확률로 긍정 리뷰입니다.
#
# 625
# 98.37% 확률로 긍정 리뷰입니다.
#
# 626
# 99.39% 확률로 긍정 리뷰입니다.
#
# 627
# 98.44% 확률로 긍정 리뷰입니다.
#
# 628
# 68.49% 확률로 긍정 리뷰입니다.
#
# 629
# 91.09% 확률로 긍정 리뷰입니다.
#
# 630
# 98.47% 확률로 긍정 리뷰입니다.
#
# 631
# 55.26% 확률로 부정 리뷰입니다.
#
# 632
# 61.51% 확률로 긍정 리뷰입니다.
#
# 633
# 94.42% 확률로 긍정 리뷰입니다.
#
# 634
# 68.97% 확률로 부정 리뷰입니다.
#
# 635
# 65.24% 확률로 긍정 리뷰입니다.
#
# 636
# 98.41% 확률로 긍정 리뷰입니다.
# 637
# 99.40% 확률로 긍정 리뷰입니다.
#
# 638
# 98.03% 확률로 긍정 리뷰입니다.
#
# 639
# 57.32% 확률로 부정 리뷰입니다.
#
# 640
# 52.21% 확률로 긍정 리뷰입니다.
#
# 641
# 99.15% 확률로 긍정 리뷰입니다.
#
# 642
# 96.25% 확률로 긍정 리뷰입니다.
#
# 643
# 99.08% 확률로 긍정 리뷰입니다.
#
# 644
# 97.81% 확률로 긍정 리뷰입니다.
#
# 645
# 98.56% 확률로 긍정 리뷰입니다.
#
# 646
# 99.01% 확률로 긍정 리뷰입니다.
#
# 647
# 99.25% 확률로 긍정 리뷰입니다.
#
# 648
# 98.45% 확률로 긍정 리뷰입니다.
#
# 649
# 97.86% 확률로 긍정 리뷰입니다.
#
# 650
# 98.90% 확률로 긍정 리뷰입니다.
#
# 651
# 99.49% 확률로 긍정 리뷰입니다.
#
# 652
# 98.97% 확률로 긍정 리뷰입니다.
#
# 653
# 96.08% 확률로 긍정 리뷰입니다.
#
# 654
# 94.66% 확률로 긍정 리뷰입니다.
#
# 655
# 65.47% 확률로 긍정 리뷰입니다.
#
# 656
# 54.61% 확률로 부정 리뷰입니다.
#
# 657
# 72.18% 확률로 부정 리뷰입니다.
#
# 658
# 98.86% 확률로 긍정 리뷰입니다.
#
# 659
# 98.70% 확률로 긍정 리뷰입니다.
#
# 660
# 83.55% 확률로 긍정 리뷰입니다.
#
# 661
# 96.81% 확률로 긍정 리뷰입니다.
#
# 662
# 96.17% 확률로 긍정 리뷰입니다.
#
# 663
# 98.63% 확률로 긍정 리뷰입니다.
#
# 664
# 98.79% 확률로 긍정 리뷰입니다.
#
# 665
# 99.27% 확률로 긍정 리뷰입니다.
#
# 666
# 78.15% 확률로 부정 리뷰입니다.
#
# 667
# 98.31% 확률로 긍정 리뷰입니다.
#
# 668
# 75.13% 확률로 긍정 리뷰입니다.
#
# 669
# 97.71% 확률로 긍정 리뷰입니다.
#
# 670
# 99.26% 확률로 긍정 리뷰입니다.
#
# 671
# 98.48% 확률로 긍정 리뷰입니다.
#
# 672
# 98.84% 확률로 긍정 리뷰입니다.
#
# 673
# 98.70% 확률로 긍정 리뷰입니다.
#
# 674
# 94.18% 확률로 긍정 리뷰입니다.
#
# 675
# 99.24% 확률로 긍정 리뷰입니다.
#
# 676
# 51.98% 확률로 부정 리뷰입니다.
#
# 677
# 98.36% 확률로 긍정 리뷰입니다.
#
# 678
# 74.08% 확률로 긍정 리뷰입니다.
#
# 679
# 98.04% 확률로 긍정 리뷰입니다.
#
# 680
# 95.35% 확률로 긍정 리뷰입니다.
#
# 681
# 99.34% 확률로 긍정 리뷰입니다.
#
# 682
# 97.51% 확률로 긍정 리뷰입니다.
#
# 683
# 92.89% 확률로 긍정 리뷰입니다.
#
# 684
# 55.26% 확률로 긍정 리뷰입니다.
#
# 685
# 98.73% 확률로 긍정 리뷰입니다.
#
# 686
# 90.68% 확률로 긍정 리뷰입니다.
#
# 687
# 98.16% 확률로 긍정 리뷰입니다.
#
# 688
# 98.57% 확률로 긍정 리뷰입니다.
#
# 689
# 98.96% 확률로 긍정 리뷰입니다.
#
# 690
# 97.69% 확률로 긍정 리뷰입니다.
#
# 691
# 98.46% 확률로 긍정 리뷰입니다.
#
# 692
# 98.79% 확률로 긍정 리뷰입니다.
#
# 693
# 70.87% 확률로 긍정 리뷰입니다.
#
# 694
# 97.72% 확률로 긍정 리뷰입니다.
#
# 695
# 97.70% 확률로 긍정 리뷰입니다.
#
# 696
# 99.02% 확률로 긍정 리뷰입니다.
#
# 697
# 98.91% 확률로 긍정 리뷰입니다.
#
# 698
# 98.93% 확률로 긍정 리뷰입니다.
#
# 699
# 99.20% 확률로 긍정 리뷰입니다.
#
# 700
# 64.47% 확률로 긍정 리뷰입니다.
#
# 701
# 95.40% 확률로 긍정 리뷰입니다.
#
# 702
# 97.45% 확률로 긍정 리뷰입니다.
#
# 703
# 99.05% 확률로 긍정 리뷰입니다.
#
# 704
# 57.70% 확률로 긍정 리뷰입니다.
#
# 705
# 97.91% 확률로 긍정 리뷰입니다.
#
# 706
# 86.62% 확률로 부정 리뷰입니다.
#
# 707
# 97.98% 확률로 긍정 리뷰입니다.
#
# 708
# 81.05% 확률로 긍정 리뷰입니다.
#
# 709
# 75.22% 확률로 부정 리뷰입니다.
#
# 710
# 97.55% 확률로 긍정 리뷰입니다.
#
# 711
# 94.78% 확률로 긍정 리뷰입니다.
#
# 712
# 79.18% 확률로 긍정 리뷰입니다.
#
# 713
# 95.47% 확률로 긍정 리뷰입니다.
#
# 714
# 99.26% 확률로 긍정 리뷰입니다.
#
# 715
# 98.95% 확률로 긍정 리뷰입니다.
#
# 716
# 86.45% 확률로 긍정 리뷰입니다.
#
# 717
# 98.47% 확률로 긍정 리뷰입니다.
#
# 718
# 98.56% 확률로 긍정 리뷰입니다.
#
# 719
# 98.66% 확률로 긍정 리뷰입니다.
#
# 720
# 85.82% 확률로 긍정 리뷰입니다.
#
# 721
# 99.27% 확률로 긍정 리뷰입니다.
#
# 722
# 67.88% 확률로 부정 리뷰입니다.
#
# 723
# 78.87% 확률로 긍정 리뷰입니다.
#
# 724
# 58.96% 확률로 긍정 리뷰입니다.
#
# 725
# 97.61% 확률로 긍정 리뷰입니다.
#
# 726
# 67.09% 확률로 긍정 리뷰입니다.
#
# 727
# 99.05% 확률로 긍정 리뷰입니다.
#
# 728
# 96.26% 확률로 긍정 리뷰입니다.
#
# 729
# 97.45% 확률로 긍정 리뷰입니다.
#
# 730
# 98.44% 확률로 긍정 리뷰입니다.
#
# 731
# 95.80% 확률로 긍정 리뷰입니다.
#
# 732
# 98.84% 확률로 긍정 리뷰입니다.
#
# 733
# 96.21% 확률로 긍정 리뷰입니다.
#
# 734
# 98.53% 확률로 긍정 리뷰입니다.
#
# 735
# 98.33% 확률로 긍정 리뷰입니다.
#
# 736
# 90.08% 확률로 긍정 리뷰입니다.
#
# 737
# 98.78% 확률로 긍정 리뷰입니다.
#
# 738
# 98.08% 확률로 긍정 리뷰입니다.
#
# 739
# 56.92% 확률로 긍정 리뷰입니다.
#
# 740
# 99.50% 확률로 긍정 리뷰입니다.
#
# 741
# 81.50% 확률로 긍정 리뷰입니다.
#
# 742
# 51.83% 확률로 부정 리뷰입니다.
#
# 743
# 78.46% 확률로 긍정 리뷰입니다.
#
# 744
# 72.73% 확률로 부정 리뷰입니다.
#
# 745
# 99.28% 확률로 긍정 리뷰입니다.
#
# 746
# 98.68% 확률로 긍정 리뷰입니다.
#
# 747
# 99.24% 확률로 긍정 리뷰입니다.
#
# 748
# 98.65% 확률로 긍정 리뷰입니다.
#
# 749
# 98.43% 확률로 긍정 리뷰입니다.
#
# 750
# 98.59% 확률로 긍정 리뷰입니다.
#
# 751
# 88.97% 확률로 긍정 리뷰입니다.
#
# 752
# 99.31% 확률로 긍정 리뷰입니다.
#
# 753
# 98.55% 확률로 긍정 리뷰입니다.
#
# 754
# 98.22% 확률로 긍정 리뷰입니다.
#
# 755
# 81.38% 확률로 긍정 리뷰입니다.
#
# 756
# 97.71% 확률로 긍정 리뷰입니다.
#
# 757
# 59.71% 확률로 긍정 리뷰입니다.
#
# 758
# 70.71% 확률로 부정 리뷰입니다.
#
# 759
# 95.25% 확률로 긍정 리뷰입니다.
#
# 760
# 99.06% 확률로 긍정 리뷰입니다.
#
# 761
# 98.16% 확률로 긍정 리뷰입니다.
#
# 762
# 97.84% 확률로 긍정 리뷰입니다.
#
# 763
# 99.06% 확률로 긍정 리뷰입니다.
#
# 764
# 99.08% 확률로 긍정 리뷰입니다.
#
# 765
# 96.91% 확률로 긍정 리뷰입니다.
#
# 766
# 92.41% 확률로 긍정 리뷰입니다.
#
# 767
# 98.95% 확률로 긍정 리뷰입니다.
#
# 768
# 99.17% 확률로 긍정 리뷰입니다.
#
# 769
# 89.94% 확률로 긍정 리뷰입니다.
#
# 770
# 50.99% 확률로 긍정 리뷰입니다.
#
# 771
# 74.77% 확률로 긍정 리뷰입니다.
#
# 772
# 98.31% 확률로 긍정 리뷰입니다.
#
# 773
# 66.02% 확률로 부정 리뷰입니다.
#
# 774
# 96.63% 확률로 긍정 리뷰입니다.
#
# 775
# 68.93% 확률로 긍정 리뷰입니다.
#
# 776
# 98.76% 확률로 긍정 리뷰입니다.
#
# 777
# 98.19% 확률로 긍정 리뷰입니다.
#
# 778
# 56.12% 확률로 긍정 리뷰입니다.
#
# 779
# 98.46% 확률로 긍정 리뷰입니다.
#
# 780
# 97.28% 확률로 긍정 리뷰입니다.
#
# 781
# 85.77% 확률로 긍정 리뷰입니다.
#
# 782
# 83.91% 확률로 긍정 리뷰입니다.
#
# 783
# 97.06% 확률로 긍정 리뷰입니다.
#
# 784
# 91.16% 확률로 긍정 리뷰입니다.
#
# 785
# 96.55% 확률로 긍정 리뷰입니다.
#
# 786
# 95.40% 확률로 긍정 리뷰입니다.
#
# 787
# 69.72% 확률로 부정 리뷰입니다.
#
# 788
# 98.81% 확률로 긍정 리뷰입니다.
#
# 789
# 86.01% 확률로 부정 리뷰입니다.
#
# 790
# 96.46% 확률로 긍정 리뷰입니다.
#
# 791
# 99.17% 확률로 긍정 리뷰입니다.
#
# 792
# 77.19% 확률로 부정 리뷰입니다.
#
# 793
# 98.57% 확률로 긍정 리뷰입니다.
#
# 794
# 70.09% 확률로 긍정 리뷰입니다.
#
# 795
# 52.66% 확률로 부정 리뷰입니다.
#
# 796
# 98.48% 확률로 긍정 리뷰입니다.
#
# 797
# 63.23% 확률로 부정 리뷰입니다.
#
# 798
# 92.42% 확률로 긍정 리뷰입니다.
#
# 799
# 97.14% 확률로 긍정 리뷰입니다.
#
# 800
# 99.11% 확률로 긍정 리뷰입니다.
#
# 801
# 99.09% 확률로 긍정 리뷰입니다.
#
# 802
# 52.99% 확률로 부정 리뷰입니다.
#
# 803
# 96.74% 확률로 긍정 리뷰입니다.
#
# 804
# 96.15% 확률로 긍정 리뷰입니다.
#
# 805
# 99.06% 확률로 긍정 리뷰입니다.
#
# 806
# 81.52% 확률로 긍정 리뷰입니다.
#
# 807
# 98.33% 확률로 긍정 리뷰입니다.
#
# 808
# 90.98% 확률로 긍정 리뷰입니다.
#
# 809
# 61.98% 확률로 긍정 리뷰입니다.
#
# 810
# 98.10% 확률로 긍정 리뷰입니다.
#
# 811
# 97.71% 확률로 긍정 리뷰입니다.
#
# 812
# 95.13% 확률로 긍정 리뷰입니다.
#
# 813
# 98.94% 확률로 긍정 리뷰입니다.
#
# 814
# 58.18% 확률로 부정 리뷰입니다.
#
# 815
# 67.31% 확률로 긍정 리뷰입니다.
#
# 816
# 99.07% 확률로 긍정 리뷰입니다.
#
# 817
# 98.56% 확률로 긍정 리뷰입니다.
#
# 818
# 98.87% 확률로 긍정 리뷰입니다.
#
# 819
# 98.48% 확률로 긍정 리뷰입니다.
#
# 820
# 58.70% 확률로 긍정 리뷰입니다.
#
# 821
# 81.82% 확률로 긍정 리뷰입니다.
#
# 822
# 92.96% 확률로 긍정 리뷰입니다.
#
# 823
# 97.36% 확률로 긍정 리뷰입니다.
#
# 824
# 96.52% 확률로 긍정 리뷰입니다.
#
# 825
# 99.17% 확률로 긍정 리뷰입니다.
#
# 826
# 80.16% 확률로 긍정 리뷰입니다.
#
# 827
# 99.07% 확률로 긍정 리뷰입니다.
#
# 828
# 75.64% 확률로 긍정 리뷰입니다.
#
# 829
# 98.53% 확률로 긍정 리뷰입니다.
#
# 830
# 52.36% 확률로 긍정 리뷰입니다.
#
# 831
# 74.23% 확률로 부정 리뷰입니다.
#
# 832
# 67.23% 확률로 긍정 리뷰입니다.
#
# 833
# 96.83% 확률로 긍정 리뷰입니다.
#
# 834
# 98.19% 확률로 긍정 리뷰입니다.
#
# 835
# 81.04% 확률로 긍정 리뷰입니다.
#
# 836
# 89.98% 확률로 긍정 리뷰입니다.
#
# 837
# 98.90% 확률로 긍정 리뷰입니다.
#
# 838
# 98.26% 확률로 긍정 리뷰입니다.
#
# 839
# 87.87% 확률로 긍정 리뷰입니다.
#
# 840
# 99.14% 확률로 긍정 리뷰입니다.
#
# 841
# 56.56% 확률로 긍정 리뷰입니다.
#
# 842
# 98.83% 확률로 긍정 리뷰입니다.
#
# 843
# 61.94% 확률로 긍정 리뷰입니다.
#
# 844
# 98.86% 확률로 긍정 리뷰입니다.
#
# 845
# 99.07% 확률로 긍정 리뷰입니다.
#
# 846
# 88.16% 확률로 긍정 리뷰입니다.
#
# 847
# 64.46% 확률로 긍정 리뷰입니다.
#
# 848
# 98.23% 확률로 긍정 리뷰입니다.
#
# 849
# 98.93% 확률로 긍정 리뷰입니다.
#
# 850
# 99.41% 확률로 긍정 리뷰입니다.
#
# 851
# 98.34% 확률로 긍정 리뷰입니다.
#
# 852
# 98.74% 확률로 긍정 리뷰입니다.
#
# 853
# 87.00% 확률로 긍정 리뷰입니다.
#
# 854
# 98.65% 확률로 긍정 리뷰입니다.
#
# 855
# 98.88% 확률로 긍정 리뷰입니다.
#
# 856
# 85.82% 확률로 긍정 리뷰입니다.
#
# 857
# 95.90% 확률로 긍정 리뷰입니다.
#
# 858
# 96.85% 확률로 긍정 리뷰입니다.
#
# 859
# 98.19% 확률로 긍정 리뷰입니다.
#
# 860
# 98.60% 확률로 긍정 리뷰입니다.
#
# 861
# 99.02% 확률로 긍정 리뷰입니다.
#
# 862
# 98.37% 확률로 긍정 리뷰입니다.
#
# 863
# 98.97% 확률로 긍정 리뷰입니다.
#
# 864
# 98.16% 확률로 긍정 리뷰입니다.
#
# 865
# 95.61% 확률로 긍정 리뷰입니다.
#
# 866
# 85.63% 확률로 긍정 리뷰입니다.
#
# 867
# 99.42% 확률로 긍정 리뷰입니다.
#
# 868
# 69.63% 확률로 긍정 리뷰입니다.
#
# 869
# 74.01% 확률로 긍정 리뷰입니다.
#
# 870
# 90.97% 확률로 긍정 리뷰입니다.
#
# 871
# 97.08% 확률로 긍정 리뷰입니다.
#
# 872
# 96.05% 확률로 긍정 리뷰입니다.
#
# 873
# 84.33% 확률로 긍정 리뷰입니다.
#
# 874
# 75.62% 확률로 긍정 리뷰입니다.
#
# 875
# 83.81% 확률로 긍정 리뷰입니다.
#
# 876
# 98.93% 확률로 긍정 리뷰입니다.
#
# 877
# 97.60% 확률로 긍정 리뷰입니다.
#
# 878
# 98.87% 확률로 긍정 리뷰입니다.
#
# 879
# 89.65% 확률로 긍정 리뷰입니다.
#
# 880
# 98.41% 확률로 긍정 리뷰입니다.
#
# 881
# 88.17% 확률로 부정 리뷰입니다.
#
# 882
# 89.52% 확률로 긍정 리뷰입니다.
#
# 883
# 98.46% 확률로 긍정 리뷰입니다.
#
# 884
# 98.29% 확률로 긍정 리뷰입니다.
#
# 885
# 98.91% 확률로 긍정 리뷰입니다.
#
# 886
# 98.31% 확률로 긍정 리뷰입니다.
#
# 887
# 98.99% 확률로 긍정 리뷰입니다.
#
# 888
# 98.47% 확률로 긍정 리뷰입니다.
#
# 889
# 98.50% 확률로 긍정 리뷰입니다.
#
# 890
# 98.44% 확률로 긍정 리뷰입니다.
#
# 891
# 99.23% 확률로 긍정 리뷰입니다.
#
# 892
# 95.13% 확률로 긍정 리뷰입니다.
#
# 893
# 97.17% 확률로 긍정 리뷰입니다.
#
# 894
# 98.41% 확률로 긍정 리뷰입니다.
#
# 895
# 98.18% 확률로 긍정 리뷰입니다.
#
# 896
# 98.53% 확률로 긍정 리뷰입니다.
#
# 897
# 91.38% 확률로 긍정 리뷰입니다.
#
# 898
# 98.94% 확률로 긍정 리뷰입니다.
#
# 899
# 83.26% 확률로 긍정 리뷰입니다.
#
# 900
# 95.29% 확률로 긍정 리뷰입니다.
#
# 901
# 79.53% 확률로 긍정 리뷰입니다.
#
# 902
# 98.24% 확률로 긍정 리뷰입니다.
#
# 903
# 51.35% 확률로 부정 리뷰입니다.
#
# 904
# 64.71% 확률로 긍정 리뷰입니다.
#
# 905
# 98.96% 확률로 긍정 리뷰입니다.
#
# 906
# 98.70% 확률로 긍정 리뷰입니다.
#
# 907
# 98.25% 확률로 긍정 리뷰입니다.
#
# 908
# 98.61% 확률로 긍정 리뷰입니다.
#
# 909
# 98.67% 확률로 긍정 리뷰입니다.
#
# 910
# 98.03% 확률로 긍정 리뷰입니다.
#
# 911
# 98.90% 확률로 긍정 리뷰입니다.
#
# 912
# 98.41% 확률로 긍정 리뷰입니다.
#
# 913
# 98.39% 확률로 긍정 리뷰입니다.
#
# 914
# 98.90% 확률로 긍정 리뷰입니다.
#
# 915
# 98.40% 확률로 긍정 리뷰입니다.
#
# 916
# 65.80% 확률로 긍정 리뷰입니다.
#
# 917
# 99.01% 확률로 긍정 리뷰입니다.
#
# 918
# 99.21% 확률로 긍정 리뷰입니다.
#
# 919
# 98.59% 확률로 긍정 리뷰입니다.
#
# 920
# 98.80% 확률로 긍정 리뷰입니다.
#
# 921
# 99.45% 확률로 긍정 리뷰입니다.
#
# 922
# 99.60% 확률로 긍정 리뷰입니다.
#
# 923
# 98.91% 확률로 긍정 리뷰입니다.
#
# 924
# 56.21% 확률로 긍정 리뷰입니다.
#
# 925
# 99.24% 확률로 긍정 리뷰입니다.
#
# 926
# 98.73% 확률로 긍정 리뷰입니다.
#
# 927
# 98.19% 확률로 긍정 리뷰입니다.
#
# 928
# 98.48% 확률로 긍정 리뷰입니다.
#
# 929
# 99.34% 확률로 긍정 리뷰입니다.
#
# 930
# 88.80% 확률로 긍정 리뷰입니다.
#
# 931
# 99.16% 확률로 긍정 리뷰입니다.
#
# 932
# 80.25% 확률로 긍정 리뷰입니다.
#
# 933
# 99.03% 확률로 긍정 리뷰입니다.
#
# 934
# 95.19% 확률로 긍정 리뷰입니다.
#
# 935
# 98.45% 확률로 긍정 리뷰입니다.
#
# 936
# 98.89% 확률로 긍정 리뷰입니다.
#
# 937
# 97.88% 확률로 긍정 리뷰입니다.
#
# 938
# 98.85% 확률로 긍정 리뷰입니다.
#
# 939
# 99.05% 확률로 긍정 리뷰입니다.
#
# 940
# 98.07% 확률로 긍정 리뷰입니다.
#
# 941
# 98.35% 확률로 긍정 리뷰입니다.
#
# 942
# 99.42% 확률로 긍정 리뷰입니다.
#
# 943
# 98.04% 확률로 긍정 리뷰입니다.
#
# 944
# 98.33% 확률로 긍정 리뷰입니다.
#
# 945
# 96.48% 확률로 긍정 리뷰입니다.
#
# 946
# 97.93% 확률로 긍정 리뷰입니다.
#
# 947
# 98.72% 확률로 긍정 리뷰입니다.
#
# 948
# 98.61% 확률로 긍정 리뷰입니다.
#
# 949
# 99.36% 확률로 긍정 리뷰입니다.
#
# 950
# 99.04% 확률로 긍정 리뷰입니다.
#
# 951
# 70.42% 확률로 긍정 리뷰입니다.
#
# 952
# 98.80% 확률로 긍정 리뷰입니다.
#
# 953
# 97.34% 확률로 긍정 리뷰입니다.
#
# 954
# 98.44% 확률로 긍정 리뷰입니다.
#
# 955
# 99.11% 확률로 긍정 리뷰입니다.
#
# 956
# 88.35% 확률로 긍정 리뷰입니다.
#
# 957
# 98.31% 확률로 긍정 리뷰입니다.
#
# 958
# 99.02% 확률로 긍정 리뷰입니다.
#
# 959
# 98.42% 확률로 긍정 리뷰입니다.
#
# 960
# 98.88% 확률로 긍정 리뷰입니다.
#
# 961
# 94.52% 확률로 긍정 리뷰입니다.
#
# 962
# 99.34% 확률로 긍정 리뷰입니다.
#
# 963
# 95.30% 확률로 긍정 리뷰입니다.
#
# 964
# 98.20% 확률로 긍정 리뷰입니다.
#
# 965
# 98.38% 확률로 긍정 리뷰입니다.
#
# 966
# 99.28% 확률로 긍정 리뷰입니다.
#
# 967
# 94.90% 확률로 긍정 리뷰입니다.
#
# 968
# 99.05% 확률로 긍정 리뷰입니다.
#
# 969
# 98.00% 확률로 긍정 리뷰입니다.
#
# 970
# 98.43% 확률로 긍정 리뷰입니다.
#
# 971
# 98.31% 확률로 긍정 리뷰입니다.
#
# 972
# 97.67% 확률로 긍정 리뷰입니다.
#
# 973
# 99.28% 확률로 긍정 리뷰입니다.
#
# 974
# 90.61% 확률로 긍정 리뷰입니다.
#
# 975
# 98.08% 확률로 긍정 리뷰입니다.
#
# 976
# 98.90% 확률로 긍정 리뷰입니다.
#
# 977
# 99.33% 확률로 긍정 리뷰입니다.
#
# 978
# 98.29% 확률로 긍정 리뷰입니다.
#
# 979
# 99.29% 확률로 긍정 리뷰입니다.
#
# 980
# 81.07% 확률로 긍정 리뷰입니다.
#
# 981
# 97.97% 확률로 긍정 리뷰입니다.
#
# 982
# 64.99% 확률로 부정 리뷰입니다.
#
# 983
# 98.88% 확률로 긍정 리뷰입니다.
#
# 984
# 99.13% 확률로 긍정 리뷰입니다.
#
# 985
# 99.38% 확률로 긍정 리뷰입니다.
#
# 986
# 81.01% 확률로 긍정 리뷰입니다.
#
# 987
# 98.25% 확률로 긍정 리뷰입니다.
#
# 988
# 98.73% 확률로 긍정 리뷰입니다.
#
# 989
# 99.45% 확률로 긍정 리뷰입니다.
#
# 990
# 96.29% 확률로 긍정 리뷰입니다.
#
# 991
# 99.50% 확률로 긍정 리뷰입니다.
#
# 992
# 99.21% 확률로 긍정 리뷰입니다.
#
# 993
# 99.30% 확률로 긍정 리뷰입니다.
#
# 994
# 98.85% 확률로 긍정 리뷰입니다.
#
# 995
# 98.49% 확률로 긍정 리뷰입니다.
#
# 996
# 72.26% 확률로 긍정 리뷰입니다.
#
# 997
# 99.15% 확률로 긍정 리뷰입니다.
#
# 998
# 85.04% 확률로 긍정 리뷰입니다.
#
# 999
# 98.81% 확률로 긍정 리뷰입니다.
#
# 1000
# 98.52% 확률로 긍정 리뷰입니다.
#
# 1001
# 99.00% 확률로 긍정 리뷰입니다.
#
# 1002
# 98.99% 확률로 긍정 리뷰입니다.
#
# 1003
# 99.41% 확률로 긍정 리뷰입니다.
#
# 1004
# 98.66% 확률로 긍정 리뷰입니다.
#
# 1005
# 98.54% 확률로 긍정 리뷰입니다.
#
# 1006
# 55.84% 확률로 긍정 리뷰입니다.
#
# 1007
# 98.75% 확률로 긍정 리뷰입니다.
#
# 1008
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1009
# 99.35% 확률로 긍정 리뷰입니다.
#
# 1010
# 75.50% 확률로 부정 리뷰입니다.
#
# 1011
# 99.26% 확률로 긍정 리뷰입니다.
#
# 1012
# 96.07% 확률로 긍정 리뷰입니다.
#
# 1013
# 98.95% 확률로 긍정 리뷰입니다.
#
# 1014
# 98.80% 확률로 긍정 리뷰입니다.
#
# 1015
# 98.65% 확률로 긍정 리뷰입니다.
#
# 1016
# 59.50% 확률로 긍정 리뷰입니다.
#
# 1017
# 99.07% 확률로 긍정 리뷰입니다.
#
# 1018
# 94.24% 확률로 긍정 리뷰입니다.
#
# 1019
# 71.32% 확률로 부정 리뷰입니다.
#
# 1020
# 97.72% 확률로 긍정 리뷰입니다.
#
# 1021
# 99.02% 확률로 긍정 리뷰입니다.
#
# 1022
# 98.43% 확률로 긍정 리뷰입니다.
#
# 1023
# 84.24% 확률로 긍정 리뷰입니다.
#
# 1024
# 73.63% 확률로 긍정 리뷰입니다.
#
# 1025
# 96.18% 확률로 긍정 리뷰입니다.
#
# 1026
# 98.91% 확률로 긍정 리뷰입니다.
#
# 1027
# 98.72% 확률로 긍정 리뷰입니다.
#
# 1028
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1029
# 98.65% 확률로 긍정 리뷰입니다.
#
# 1030
# 99.15% 확률로 긍정 리뷰입니다.
#
# 1031
# 98.47% 확률로 긍정 리뷰입니다.
#
# 1032
# 65.68% 확률로 긍정 리뷰입니다.
#
# 1033
# 98.94% 확률로 긍정 리뷰입니다.
#
# 1034
# 97.91% 확률로 긍정 리뷰입니다.
#
# 1035
# 98.40% 확률로 긍정 리뷰입니다.
#
# 1036
# 99.30% 확률로 긍정 리뷰입니다.
#
# 1037
# 89.53% 확률로 긍정 리뷰입니다.
#
# 1038
# 98.98% 확률로 긍정 리뷰입니다.
#
# 1039
# 87.76% 확률로 긍정 리뷰입니다.
#
# 1040
# 56.47% 확률로 긍정 리뷰입니다.
#
# 1041
# 98.86% 확률로 긍정 리뷰입니다.
#
# 1042
# 98.46% 확률로 긍정 리뷰입니다.
#
# 1043
# 98.78% 확률로 긍정 리뷰입니다.
#
# 1044
# 98.50% 확률로 긍정 리뷰입니다.
#
# 1045
# 96.45% 확률로 긍정 리뷰입니다.
#
# 1046
# 98.42% 확률로 긍정 리뷰입니다.
#
# 1047
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1048
# 97.78% 확률로 긍정 리뷰입니다.
#
# 1049
# 53.18% 확률로 부정 리뷰입니다.
#
# 1050
# 98.59% 확률로 긍정 리뷰입니다.
#
# 1051
# 99.32% 확률로 긍정 리뷰입니다.
#
# 1052
# 98.90% 확률로 긍정 리뷰입니다.
#
# 1053
# 98.91% 확률로 긍정 리뷰입니다.
#
# 1054
# 99.35% 확률로 긍정 리뷰입니다.
#
# 1055
# 99.31% 확률로 긍정 리뷰입니다.
#
# 1056
# 74.41% 확률로 부정 리뷰입니다.
#
# 1057
# 54.93% 확률로 부정 리뷰입니다.
#
# 1058
# 98.51% 확률로 긍정 리뷰입니다.
#
# 1059
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1060
# 67.72% 확률로 부정 리뷰입니다.
#
# 1061
# 97.40% 확률로 긍정 리뷰입니다.
#
# 1062
# 82.39% 확률로 부정 리뷰입니다.
#
# 1063
# 75.10% 확률로 긍정 리뷰입니다.
#
# 1064
# 57.48% 확률로 부정 리뷰입니다.
#
# 1065
# 97.70% 확률로 긍정 리뷰입니다.
#
# 1066
# 99.42% 확률로 긍정 리뷰입니다.
#
# 1067
# 99.05% 확률로 긍정 리뷰입니다.
#
# 1068
# 98.97% 확률로 긍정 리뷰입니다.
#
# 1069
# 96.34% 확률로 긍정 리뷰입니다.
#
# 1070
# 97.80% 확률로 긍정 리뷰입니다.
#
# 1071
# 90.91% 확률로 긍정 리뷰입니다.
#
# 1072
# 66.40% 확률로 긍정 리뷰입니다.
#
# 1073
# 99.06% 확률로 긍정 리뷰입니다.
#
# 1074
# 98.74% 확률로 긍정 리뷰입니다.
#
# 1075
# 98.39% 확률로 긍정 리뷰입니다.
#
# 1076
# 89.51% 확률로 긍정 리뷰입니다.
#
# 1077
# 59.81% 확률로 긍정 리뷰입니다.
#
# 1078
# 97.38% 확률로 긍정 리뷰입니다.
#
# 1079
# 99.13% 확률로 긍정 리뷰입니다.
#
# 1080
# 99.43% 확률로 긍정 리뷰입니다.
#
# 1081
# 98.20% 확률로 긍정 리뷰입니다.
#
# 1082
# 99.27% 확률로 긍정 리뷰입니다.
#
# 1083
# 98.44% 확률로 긍정 리뷰입니다.
#
# 1084
# 98.84% 확률로 긍정 리뷰입니다.
#
# 1085
# 99.23% 확률로 긍정 리뷰입니다.
#
# 1086
# 84.64% 확률로 부정 리뷰입니다.
#
# 1087
# 73.39% 확률로 긍정 리뷰입니다.
#
# 1088
# 98.59% 확률로 긍정 리뷰입니다.
#
# 1089
# 98.41% 확률로 긍정 리뷰입니다.
#
# 1090
# 98.61% 확률로 긍정 리뷰입니다.
#
# 1091
# 55.61% 확률로 긍정 리뷰입니다.
#
# 1092
# 70.86% 확률로 부정 리뷰입니다.
#
# 1093
# 57.14% 확률로 긍정 리뷰입니다.
#
# 1094
# 99.47% 확률로 긍정 리뷰입니다.
#
# 1095
# 98.85% 확률로 긍정 리뷰입니다.
#
# 1096
# 67.79% 확률로 긍정 리뷰입니다.
#
# 1097
# 89.11% 확률로 긍정 리뷰입니다.
#
# 1098
# 89.86% 확률로 부정 리뷰입니다.
#
# 1099
# 92.82% 확률로 긍정 리뷰입니다.
#
# 1100
# 78.40% 확률로 긍정 리뷰입니다.
#
# 1101
# 58.46% 확률로 부정 리뷰입니다.
#
# 1102
# 98.39% 확률로 긍정 리뷰입니다.
#
# 1103
# 77.23% 확률로 긍정 리뷰입니다.
#
# 1104
# 87.08% 확률로 긍정 리뷰입니다.
#
# 1105
# 61.54% 확률로 긍정 리뷰입니다.
#
# 1106
# 57.11% 확률로 긍정 리뷰입니다.
#
# 1107
# 53.66% 확률로 긍정 리뷰입니다.
#
# 1108
# 97.24% 확률로 긍정 리뷰입니다.
#
# 1109
# 70.15% 확률로 부정 리뷰입니다.
#
# 1110
# 88.17% 확률로 긍정 리뷰입니다.
#
# 1111
# 99.28% 확률로 긍정 리뷰입니다.
#
# 1112
# 98.94% 확률로 긍정 리뷰입니다.
#
# 1113
# 70.40% 확률로 긍정 리뷰입니다.
#
# 1114
# 97.74% 확률로 긍정 리뷰입니다.
#
# 1115
# 99.48% 확률로 긍정 리뷰입니다.
#
# 1116
# 56.63% 확률로 부정 리뷰입니다.
#
# 1117
# 98.15% 확률로 긍정 리뷰입니다.
#
# 1118
# 98.51% 확률로 긍정 리뷰입니다.
#
# 1119
# 98.32% 확률로 긍정 리뷰입니다.
#
# 1120
# 65.36% 확률로 긍정 리뷰입니다.
#
# 1121
# 96.60% 확률로 긍정 리뷰입니다.
#
# 1122
# 98.25% 확률로 긍정 리뷰입니다.
#
# 1123
# 68.82% 확률로 긍정 리뷰입니다.
#
# 1124
# 70.58% 확률로 부정 리뷰입니다.
#
# 1125
# 97.81% 확률로 긍정 리뷰입니다.
#
# 1126
# 98.67% 확률로 긍정 리뷰입니다.
#
# 1127
# 98.48% 확률로 긍정 리뷰입니다.
#
# 1128
# 97.04% 확률로 긍정 리뷰입니다.
#
# 1129
# 98.73% 확률로 긍정 리뷰입니다.
#
# 1130
# 66.27% 확률로 부정 리뷰입니다.
#
# 1131
# 98.65% 확률로 긍정 리뷰입니다.
#
# 1132
# 95.81% 확률로 긍정 리뷰입니다.
#
# 1133
# 96.54% 확률로 긍정 리뷰입니다.
#
# 1134
# 63.37% 확률로 긍정 리뷰입니다.
#
# 1135
# 74.92% 확률로 긍정 리뷰입니다.
#
# 1136
# 98.98% 확률로 긍정 리뷰입니다.
#
# 1137
# 66.89% 확률로 긍정 리뷰입니다.
#
# 1138
# 53.34% 확률로 부정 리뷰입니다.
#
# 1139
# 98.58% 확률로 긍정 리뷰입니다.
#
# 1140
# 98.58% 확률로 긍정 리뷰입니다.
#
# 1141
# 82.23% 확률로 긍정 리뷰입니다.
#
# 1142
# 93.44% 확률로 긍정 리뷰입니다.
#
# 1143
# 99.25% 확률로 긍정 리뷰입니다.
#
# 1144
# 94.75% 확률로 긍정 리뷰입니다.
#
# 1145
# 99.01% 확률로 긍정 리뷰입니다.
#
# 1146
# 96.96% 확률로 긍정 리뷰입니다.
#
# 1147
# 98.18% 확률로 긍정 리뷰입니다.
#
# 1148
# 98.15% 확률로 긍정 리뷰입니다.
#
# 1149
# 94.53% 확률로 긍정 리뷰입니다.
#
# 1150
# 98.45% 확률로 긍정 리뷰입니다.
#
# 1151
# 67.64% 확률로 부정 리뷰입니다.
#
# 1152
# 66.48% 확률로 긍정 리뷰입니다.
#
# 1153
# 79.57% 확률로 긍정 리뷰입니다.
#
# 1154
# 99.34% 확률로 긍정 리뷰입니다.
#
# 1155
# 98.43% 확률로 긍정 리뷰입니다.
#
# 1156
# 61.69% 확률로 긍정 리뷰입니다.
#
# 1157
# 98.08% 확률로 긍정 리뷰입니다.
#
# 1158
# 98.89% 확률로 긍정 리뷰입니다.
#
# 1159
# 98.04% 확률로 긍정 리뷰입니다.
#
# 1160
# 95.56% 확률로 긍정 리뷰입니다.
#
# 1161
# 98.83% 확률로 긍정 리뷰입니다.
#
# 1162
# 73.06% 확률로 부정 리뷰입니다.
#
# 1163
# 71.52% 확률로 긍정 리뷰입니다.
#
# 1164
# 77.66% 확률로 긍정 리뷰입니다.
#
# 1165
# 98.93% 확률로 긍정 리뷰입니다.
#
# 1166
# 98.62% 확률로 긍정 리뷰입니다.
#
# 1167
# 97.85% 확률로 긍정 리뷰입니다.
#
# 1168
# 97.98% 확률로 긍정 리뷰입니다.
#
# 1169
# 91.27% 확률로 긍정 리뷰입니다.
#
# 1170
# 99.60% 확률로 긍정 리뷰입니다.
#
# 1171
# 74.90% 확률로 부정 리뷰입니다.
#
# 1172
# 66.02% 확률로 긍정 리뷰입니다.
#
# 1173
# 99.01% 확률로 긍정 리뷰입니다.
#
# 1174
# 98.80% 확률로 긍정 리뷰입니다.
#
# 1175
# 99.36% 확률로 긍정 리뷰입니다.
#
# 1176
# 97.66% 확률로 긍정 리뷰입니다.
#
# 1177
# 98.47% 확률로 긍정 리뷰입니다.
#
# 1178
# 98.03% 확률로 긍정 리뷰입니다.
#
# 1179
# 98.18% 확률로 긍정 리뷰입니다.
#
# 1180
# 98.17% 확률로 긍정 리뷰입니다.
#
# 1181
# 99.01% 확률로 긍정 리뷰입니다.
#
# 1182
# 98.27% 확률로 긍정 리뷰입니다.
#
# 1183
# 98.13% 확률로 긍정 리뷰입니다.
#
# 1184
# 88.74% 확률로 부정 리뷰입니다.
#
# 1185
# 99.21% 확률로 긍정 리뷰입니다.
#
# 1186
# 98.88% 확률로 긍정 리뷰입니다.
#
# 1187
# 97.93% 확률로 긍정 리뷰입니다.
#
# 1188
# 98.04% 확률로 긍정 리뷰입니다.
#
# 1189
# 98.98% 확률로 긍정 리뷰입니다.
#
# 1190
# 99.02% 확률로 긍정 리뷰입니다.
#
# 1191
# 71.34% 확률로 긍정 리뷰입니다.
#
# 1192
# 62.24% 확률로 긍정 리뷰입니다.
#
# 1193
# 98.89% 확률로 긍정 리뷰입니다.
#
# 1194
# 97.89% 확률로 긍정 리뷰입니다.
#
# 1195
# 98.45% 확률로 긍정 리뷰입니다.
#
# 1196
# 98.05% 확률로 긍정 리뷰입니다.
#
# 1197
# 98.02% 확률로 긍정 리뷰입니다.
#
# 1198
# 98.50% 확률로 긍정 리뷰입니다.
#
# 1199
# 98.18% 확률로 긍정 리뷰입니다.
#
# 1200
# 73.14% 확률로 긍정 리뷰입니다.
#
# 1201
# 68.69% 확률로 긍정 리뷰입니다.
#
# 1202
# 59.63% 확률로 긍정 리뷰입니다.
#
# 1203
# 64.11% 확률로 부정 리뷰입니다.
#
# 1204
# 97.44% 확률로 긍정 리뷰입니다.
#
# 1205
# 96.02% 확률로 긍정 리뷰입니다.
#
# 1206
# 82.13% 확률로 긍정 리뷰입니다.
#
# 1207
# 53.13% 확률로 긍정 리뷰입니다.
#
# 1208
# 98.95% 확률로 긍정 리뷰입니다.
#
# 1209
# 99.08% 확률로 긍정 리뷰입니다.
#
# 1210
# 84.47% 확률로 긍정 리뷰입니다.
#
# 1211
# 98.74% 확률로 긍정 리뷰입니다.
#
# 1212
# 97.17% 확률로 긍정 리뷰입니다.
#
# 1213
# 98.28% 확률로 긍정 리뷰입니다.
#
# 1214
# 93.70% 확률로 긍정 리뷰입니다.
#
# 1215
# 96.77% 확률로 긍정 리뷰입니다.
#
# 1216
# 98.72% 확률로 긍정 리뷰입니다.
#
# 1217
# 98.99% 확률로 긍정 리뷰입니다.
#
# 1218
# 76.39% 확률로 부정 리뷰입니다.
#
# 1219
# 51.26% 확률로 긍정 리뷰입니다.
#
# 1220
# 98.16% 확률로 긍정 리뷰입니다.
#
# 1221
# 97.47% 확률로 긍정 리뷰입니다.
#
# 1222
# 98.50% 확률로 긍정 리뷰입니다.
#
# 1223
# 96.71% 확률로 긍정 리뷰입니다.
#
# 1224
# 99.11% 확률로 긍정 리뷰입니다.
#
# 1225
# 82.22% 확률로 긍정 리뷰입니다.
#
# 1226
# 77.54% 확률로 부정 리뷰입니다.
#
# 1227
# 97.59% 확률로 긍정 리뷰입니다.
#
# 1228
# 71.31% 확률로 부정 리뷰입니다.
#
# 1229
# 72.63% 확률로 긍정 리뷰입니다.
#
# 1230
# 98.69% 확률로 긍정 리뷰입니다.
#
# 1231
# 98.93% 확률로 긍정 리뷰입니다.
#
# 1232
# 99.08% 확률로 긍정 리뷰입니다.
#
# 1233
# 54.16% 확률로 긍정 리뷰입니다.
#
# 1234
# 53.42% 확률로 긍정 리뷰입니다.
#
# 1235
# 98.25% 확률로 긍정 리뷰입니다.
#
# 1236
# 65.41% 확률로 부정 리뷰입니다.
#
# 1237
# 99.13% 확률로 긍정 리뷰입니다.
#
# 1238
# 99.40% 확률로 긍정 리뷰입니다.
#
# 1239
# 67.50% 확률로 부정 리뷰입니다.
#
# 1240
# 57.10% 확률로 긍정 리뷰입니다.
#
# 1241
# 51.73% 확률로 부정 리뷰입니다.
#
# 1242
# 72.27% 확률로 부정 리뷰입니다.
#
# 1243
# 97.74% 확률로 긍정 리뷰입니다.
#
# 1244
# 98.82% 확률로 긍정 리뷰입니다.
#
# 1245
# 97.61% 확률로 긍정 리뷰입니다.
#
# 1246
# 99.24% 확률로 긍정 리뷰입니다.
#
# 1247
# 80.20% 확률로 긍정 리뷰입니다.
#
# 1248
# 98.35% 확률로 긍정 리뷰입니다.
#
# 1249
# 99.13% 확률로 긍정 리뷰입니다.
#
# 1250
# 99.54% 확률로 긍정 리뷰입니다.
#
# 1251
# 98.84% 확률로 긍정 리뷰입니다.
#
# 1252
# 94.61% 확률로 긍정 리뷰입니다.
#
# 1253
# 96.58% 확률로 긍정 리뷰입니다.
#
# 1254
# 98.43% 확률로 긍정 리뷰입니다.
#
# 1255
# 98.63% 확률로 긍정 리뷰입니다.
#
# 1256
# 59.31% 확률로 부정 리뷰입니다.
#
# 1257
# 93.56% 확률로 긍정 리뷰입니다.
#
# 1258
# 97.70% 확률로 긍정 리뷰입니다.
#
# 1259
# 97.12% 확률로 긍정 리뷰입니다.
#
# 1260
# 98.01% 확률로 긍정 리뷰입니다.
#
# 1261
# 98.56% 확률로 긍정 리뷰입니다.
#
# 1262
# 98.50% 확률로 긍정 리뷰입니다.
#
# 1263
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1264
# 98.47% 확률로 긍정 리뷰입니다.
#
# 1265
# 81.01% 확률로 긍정 리뷰입니다.
#
# 1266
# 61.77% 확률로 긍정 리뷰입니다.
#
# 1267
# 75.95% 확률로 긍정 리뷰입니다.
#
# 1268
# 99.09% 확률로 긍정 리뷰입니다.
#
# 1269
# 63.56% 확률로 긍정 리뷰입니다.
#
# 1270
# 62.54% 확률로 부정 리뷰입니다.
#
# 1271
# 99.05% 확률로 긍정 리뷰입니다.
#
# 1272
# 98.36% 확률로 긍정 리뷰입니다.
#
# 1273
# 98.78% 확률로 긍정 리뷰입니다.
#
# 1274
# 98.68% 확률로 긍정 리뷰입니다.
#
# 1275
# 60.95% 확률로 긍정 리뷰입니다.
#
# 1276
# 92.28% 확률로 긍정 리뷰입니다.
#
# 1277
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1278
# 97.73% 확률로 긍정 리뷰입니다.
#
# 1279
# 98.51% 확률로 긍정 리뷰입니다.
#
# 1280
# 77.10% 확률로 긍정 리뷰입니다.
#
# 1281
# 99.15% 확률로 긍정 리뷰입니다.
#
# 1282
# 85.18% 확률로 긍정 리뷰입니다.
#
# 1283
# 91.81% 확률로 긍정 리뷰입니다.
#
# 1284
# 98.52% 확률로 긍정 리뷰입니다.
#
# 1285
# 97.80% 확률로 긍정 리뷰입니다.
#
# 1286
# 98.39% 확률로 긍정 리뷰입니다.
#
# 1287
# 98.70% 확률로 긍정 리뷰입니다.
#
# 1288
# 98.34% 확률로 긍정 리뷰입니다.
#
# 1289
# 97.30% 확률로 긍정 리뷰입니다.
#
# 1290
# 97.23% 확률로 긍정 리뷰입니다.
#
# 1291
# 81.83% 확률로 긍정 리뷰입니다.
#
# 1292
# 98.82% 확률로 긍정 리뷰입니다.
#
# 1293
# 84.82% 확률로 긍정 리뷰입니다.
#
# 1294
# 98.75% 확률로 긍정 리뷰입니다.
#
# 1295
# 92.41% 확률로 긍정 리뷰입니다.
#
# 1296
# 99.15% 확률로 긍정 리뷰입니다.
#
# 1297
# 98.63% 확률로 긍정 리뷰입니다.
#
# 1298
# 97.87% 확률로 긍정 리뷰입니다.
#
# 1299
# 61.95% 확률로 부정 리뷰입니다.
#
# 1300
# 97.65% 확률로 긍정 리뷰입니다.
#
# 1301
# 75.42% 확률로 긍정 리뷰입니다.
#
# 1302
# 91.34% 확률로 긍정 리뷰입니다.
#
# 1303
# 98.80% 확률로 긍정 리뷰입니다.
#
# 1304
# 98.79% 확률로 긍정 리뷰입니다.
#
# 1305
# 54.02% 확률로 부정 리뷰입니다.
#
# 1306
# 98.86% 확률로 긍정 리뷰입니다.
#
# 1307
# 99.28% 확률로 긍정 리뷰입니다.
#
# 1308
# 97.27% 확률로 긍정 리뷰입니다.
#
# 1309
# 98.14% 확률로 긍정 리뷰입니다.
#
# 1310
# 96.67% 확률로 긍정 리뷰입니다.
#
# 1311
# 98.16% 확률로 긍정 리뷰입니다.
#
# 1312
# 98.28% 확률로 긍정 리뷰입니다.
#
# 1313
# 75.42% 확률로 부정 리뷰입니다.
#
# 1314
# 98.05% 확률로 긍정 리뷰입니다.
#
# 1315
# 59.28% 확률로 긍정 리뷰입니다.
#
# 1316
# 99.24% 확률로 긍정 리뷰입니다.
#
# 1317
# 76.27% 확률로 부정 리뷰입니다.
#
# 1318
# 99.04% 확률로 긍정 리뷰입니다.
#
# 1319
# 98.46% 확률로 긍정 리뷰입니다.
#
# 1320
# 99.15% 확률로 긍정 리뷰입니다.
#
# 1321
# 98.95% 확률로 긍정 리뷰입니다.
#
# 1322
# 52.32% 확률로 부정 리뷰입니다.
#
# 1323
# 98.93% 확률로 긍정 리뷰입니다.
#
# 1324
# 91.79% 확률로 긍정 리뷰입니다.
#
# 1325
# 54.91% 확률로 부정 리뷰입니다.
#
# 1326
# 98.42% 확률로 긍정 리뷰입니다.
#
# 1327
# 98.64% 확률로 긍정 리뷰입니다.
#
# 1328
# 95.86% 확률로 긍정 리뷰입니다.
#
# 1329
# 98.47% 확률로 긍정 리뷰입니다.
#
# 1330
# 98.96% 확률로 긍정 리뷰입니다.
#
# 1331
# 98.95% 확률로 긍정 리뷰입니다.
#
# 1332
# 99.37% 확률로 긍정 리뷰입니다.
#
# 1333
# 95.92% 확률로 긍정 리뷰입니다.
#
# 1334
# 69.26% 확률로 부정 리뷰입니다.
#
# 1335
# 59.16% 확률로 부정 리뷰입니다.
#
# 1336
# 98.89% 확률로 긍정 리뷰입니다.
#
# 1337
# 99.07% 확률로 긍정 리뷰입니다.
#
# 1338
# 97.92% 확률로 긍정 리뷰입니다.
#
# 1339
# 96.54% 확률로 긍정 리뷰입니다.
#
# 1340
# 62.50% 확률로 부정 리뷰입니다.
#
# 1341
# 95.05% 확률로 긍정 리뷰입니다.
#
# 1342
# 98.06% 확률로 긍정 리뷰입니다.
#
# 1343
# 72.82% 확률로 긍정 리뷰입니다.
#
# 1344
# 99.40% 확률로 긍정 리뷰입니다.
#
# 1345
# 99.00% 확률로 긍정 리뷰입니다.
#
# 1346
# 98.52% 확률로 긍정 리뷰입니다.
#
# 1347
# 55.49% 확률로 긍정 리뷰입니다.
#
# 1348
# 50.78% 확률로 부정 리뷰입니다.
#
# 1349
# 85.53% 확률로 긍정 리뷰입니다.
#
# 1350
# 99.15% 확률로 긍정 리뷰입니다.
#
# 1351
# 96.43% 확률로 긍정 리뷰입니다.
#
# 1352
# 99.00% 확률로 긍정 리뷰입니다.
#
# 1353
# 92.47% 확률로 긍정 리뷰입니다.
#
# 1354
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1355
# 91.08% 확률로 긍정 리뷰입니다.
#
# 1356
# 98.85% 확률로 긍정 리뷰입니다.
#
# 1357
# 98.59% 확률로 긍정 리뷰입니다.
#
# 1358
# 98.92% 확률로 긍정 리뷰입니다.
#
# 1359
# 96.66% 확률로 긍정 리뷰입니다.
#
# 1360
# 95.83% 확률로 긍정 리뷰입니다.
#
# 1361
# 98.63% 확률로 긍정 리뷰입니다.
#
# 1362
# 98.43% 확률로 긍정 리뷰입니다.
#
# 1363
# 95.83% 확률로 긍정 리뷰입니다.
#
# 1364
# 98.03% 확률로 긍정 리뷰입니다.
#
# 1365
# 98.99% 확률로 긍정 리뷰입니다.
#
# 1366
# 60.14% 확률로 부정 리뷰입니다.
#
# 1367
# 51.41% 확률로 긍정 리뷰입니다.
#
# 1368
# 91.09% 확률로 긍정 리뷰입니다.
#
# 1369
# 98.59% 확률로 긍정 리뷰입니다.
#
# 1370
# 98.63% 확률로 긍정 리뷰입니다.
#
# 1371
# 96.25% 확률로 긍정 리뷰입니다.
#
# 1372
# 99.09% 확률로 긍정 리뷰입니다.
#
# 1373
# 98.32% 확률로 긍정 리뷰입니다.
#
# 1374
# 97.68% 확률로 긍정 리뷰입니다.
#
# 1375
# 99.18% 확률로 긍정 리뷰입니다.
#
# 1376
# 84.49% 확률로 부정 리뷰입니다.
#
# 1377
# 98.52% 확률로 긍정 리뷰입니다.
#
# 1378
# 71.71% 확률로 긍정 리뷰입니다.
#
# 1379
# 89.29% 확률로 긍정 리뷰입니다.
#
# 1380
# 98.52% 확률로 긍정 리뷰입니다.
#
# 1381
# 59.64% 확률로 긍정 리뷰입니다.
#
# 1382
# 99.20% 확률로 긍정 리뷰입니다.
#
# 1383
# 98.46% 확률로 긍정 리뷰입니다.
#
# 1384
# 99.33% 확률로 긍정 리뷰입니다.
#
# 1385
# 51.74% 확률로 부정 리뷰입니다.
#
# 1386
# 98.76% 확률로 긍정 리뷰입니다.
#
# 1387
# 61.97% 확률로 긍정 리뷰입니다.
#
# 1388
# 83.66% 확률로 긍정 리뷰입니다.
#
# 1389
# 95.30% 확률로 긍정 리뷰입니다.
#
# 1390
# 98.22% 확률로 긍정 리뷰입니다.
#
# 1391
# 56.14% 확률로 긍정 리뷰입니다.
#
# 1392
# 74.32% 확률로 긍정 리뷰입니다.
#
# 1393
# 98.58% 확률로 긍정 리뷰입니다.
#
# 1394
# 98.18% 확률로 긍정 리뷰입니다.
#
# 1395
# 68.78% 확률로 긍정 리뷰입니다.
#
# 1396
# 98.73% 확률로 긍정 리뷰입니다.
#
# 1397
# 92.72% 확률로 긍정 리뷰입니다.
#
# 1398
# 89.24% 확률로 긍정 리뷰입니다.
#
# 1399
# 98.63% 확률로 긍정 리뷰입니다.
#
# 1400
# 98.02% 확률로 긍정 리뷰입니다.
#
# 1401
# 90.13% 확률로 긍정 리뷰입니다.
#
# 1402
# 87.14% 확률로 긍정 리뷰입니다.
#
# 1403
# 99.16% 확률로 긍정 리뷰입니다.
#
# 1404
# 97.34% 확률로 긍정 리뷰입니다.
#
# 1405
# 99.07% 확률로 긍정 리뷰입니다.
#
# 1406
# 99.13% 확률로 긍정 리뷰입니다.
#
# 1407
# 67.69% 확률로 부정 리뷰입니다.
#
# 1408
# 98.47% 확률로 긍정 리뷰입니다.
#
# 1409
# 98.91% 확률로 긍정 리뷰입니다.
#
# 1410
# 97.98% 확률로 긍정 리뷰입니다.
#
# 1411
# 97.68% 확률로 긍정 리뷰입니다.
#
# 1412
# 97.65% 확률로 긍정 리뷰입니다.
#
# 1413
# 85.33% 확률로 긍정 리뷰입니다.
#
# 1414
# 98.40% 확률로 긍정 리뷰입니다.
#
# 1415
# 98.87% 확률로 긍정 리뷰입니다.
#
# 1416
# 99.01% 확률로 긍정 리뷰입니다.
#
# 1417
# 79.37% 확률로 긍정 리뷰입니다.
#
# 1418
# 77.88% 확률로 긍정 리뷰입니다.
#
# 1419
# 98.48% 확률로 긍정 리뷰입니다.
#
# 1420
# 64.54% 확률로 부정 리뷰입니다.
#
# 1421
# 80.69% 확률로 긍정 리뷰입니다.
#
# 1422
# 78.06% 확률로 긍정 리뷰입니다.
