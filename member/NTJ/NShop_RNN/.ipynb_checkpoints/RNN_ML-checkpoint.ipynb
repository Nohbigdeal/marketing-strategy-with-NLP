# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import selenium
from urllib.parse import  urlparse
import time
import lxml
from urllib.request import urlopen
from selenium.webdriver.common.keys import Keys
import numpy as np
import pandas as pd
import re
import pickle
from contextlib import suppress
import matplotlib.pyplot as plt
from konlpy.tag import Okt
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV, cross_validate, KFold

from tensorflow.keras.layers import Embedding, Dense, LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
xia = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNSstar/data/PP/xia.csv")
xia

xia.drop_duplicates(subset=['내용'], inplace=True)
xia

xia["label"] = 0
xia
# Out:
#       Unnamed: 0                                                 내용  별점  label
# 0              0  쓰던 삼성폰이 갑자기 먹통이 되서 구입하게 되었습니다. 왜 안되는지 알수가 없다네요...   5      0
# 1              1  자급제폰으로 검색을 하던중에 아무리 둘러봐도 홍미노트7만한 녀석이 없더군요..해외직...   5      0
# 2              2  홍미노트6 쓰다가 7을 사 봤습니다.작아진 후면 카메라 부분, 화질은 더욱 좋아졌고...   5      0
# 3              3  솔직히 말해서 포인트 받을려고 쓰는 거 보다 제품이 너무 좋아서 쓰는 것도 있지만 ...   5      0
# 4              4  배송도 빠르고 알뜰폰 사용중이라 공기계만 필요했는데 가성비도 좋고 폰도 이쁘고 너무...   5      0
# ...          ...                                                ...  ..    ...
# 6966        6966  쓰기편한데 고무라서 그런지 얼마 안가 다시 사야할거같은 느낌적인느낌이들고 그래도 잘...   1      0
# 6967        6967  상품평을 많은 기대를 갖고서 구입했으나 전화 수신시 알려만주고 번호는 나타나지 않으...   1      0
# 6968        6968        금액대비 아주 좋습니다 여러모로 편리하네요 감사합니다 저렴하게 잘 산것 같아요   1      0
# 6969        6969                                             일주일 걸림   1      0
# 6970        6970  좋아요 포장도 잘 되어있고 가격도 그리 비싸진 않지만 충전기가 좀 비싼편이네염 절대...   1      0
#
# [6133 rows x 4 columns]

# %%
# xia.set_index("Unnamed: 0", inplace=True)
xia.loc[xia["별점"] > 3.5, "label"] = 1
xia
# Out:
#       Unnamed: 0                                                 내용  별점  label
# 0              0  쓰던 삼성폰이 갑자기 먹통이 되서 구입하게 되었습니다. 왜 안되는지 알수가 없다네요...   5      1
# 1              1  자급제폰으로 검색을 하던중에 아무리 둘러봐도 홍미노트7만한 녀석이 없더군요..해외직...   5      1
# 2              2  홍미노트6 쓰다가 7을 사 봤습니다.작아진 후면 카메라 부분, 화질은 더욱 좋아졌고...   5      1
# 3              3  솔직히 말해서 포인트 받을려고 쓰는 거 보다 제품이 너무 좋아서 쓰는 것도 있지만 ...   5      1
# 4              4  배송도 빠르고 알뜰폰 사용중이라 공기계만 필요했는데 가성비도 좋고 폰도 이쁘고 너무...   5      1
# ...          ...                                                ...  ..    ...
# 6966        6966  쓰기편한데 고무라서 그런지 얼마 안가 다시 사야할거같은 느낌적인느낌이들고 그래도 잘...   1      0
# 6967        6967  상품평을 많은 기대를 갖고서 구입했으나 전화 수신시 알려만주고 번호는 나타나지 않으...   1      0
# 6968        6968        금액대비 아주 좋습니다 여러모로 편리하네요 감사합니다 저렴하게 잘 산것 같아요   1      0
# 6969        6969                                             일주일 걸림   1      0
# 6970        6970  좋아요 포장도 잘 되어있고 가격도 그리 비싸진 않지만 충전기가 좀 비싼편이네염 절대...   1      0
#
# [6133 rows x 4 columns]

# %%
train_data, test_data = train_test_split(xia, test_size=0.25, random_state = 42)
print('훈련용 리뷰의 개수 :', len(train_data))
print('테스트용 리뷰의 개수 :', len(test_data))
# Out:
# 훈련용 리뷰의 개수 : 4599
# 테스트용 리뷰의 개수 : 1534

# %%
train_data.drop_duplicates(subset=["내용"], inplace=True)
test_data.drop_duplicates(subset=["내용"], inplace=True)
len(train_data)
len(test_data)
# Out:
# <ipython-input-15-42510afe55bb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data.drop_duplicates(subset=["내용"], inplace=True)
# <ipython-input-15-42510afe55bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop_duplicates(subset=["내용"], inplace=True)
# 1534

# %%
train_data['label'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
print(train_data.groupby('label').size().reset_index(name = 'count'))
# Out:
#    label  count
# 0      0   1026
# 1      1   3573

# %%
print(train_data.isnull().values.any())
# Out:
# False

# %%
print(train_data.isnull().sum())
# Out:
# Unnamed: 0    0
# 내용            0
# 별점            0
# label         0
# dtype: int64

# %%
train_data.loc[train_data.내용.isnull()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, 내용, 별점, label]
# Index: []

# %%
train_data = train_data.dropna(how = 'any')
print(train_data.isnull().values.any())
# Out:
# False

# %%
print(len(train_data))
# Out:
# 4599

# %%
train_data['내용'] = train_data['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
train_data[:5]
# Out:
# <ipython-input-22-388f03bd8969>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['내용'] = train_data['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
#       Unnamed: 0                                                 내용  별점  label
# 5376        5376  나름만족 음 친구가 쓰는걸 보고 전에 쓰던 블루투스 이어폰이 망가져서 한번 사봣는데...   3      0
# 5692        5692  너무 좋음 캐 좋음 가볍고 부담 없이 차고다닐 수 있고 수면관리에 만보기까지매일 얼...   5      1
# 5970        5970  미밴드  강추강추 원래 미밴드  유저였는데 시계기능 추가 보고바로 로 갈아탔어용  ...   5      1
# 5940        5940  정말 만족합니다 미 피트 어플과 연동해서 사용하는데 정말 만족합니다 주로 시계랑 만...   5      1
# 2998        2998                                         좋네요 추천합니다다   4      1

# %%
test_data.drop_duplicates(subset = ['내용'], inplace=True) # 중복 제거
test_data['내용'] = test_data['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
test_data['내용'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
test_data = test_data.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(test_data))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 1532
# <ipython-input-24-e2602a0e130a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop_duplicates(subset = ['내용'], inplace=True) # 중복 제거
# <ipython-input-24-e2602a0e130a>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   test_data['내용'] = test_data['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
# <ipython-input-24-e2602a0e130a>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['내용'] = test_data['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
train_data['내용'] = train_data['내용'].str.replace('^ +', "")
train_data['내용'].replace('', np.nan, inplace=True)
print(train_data.isnull().sum())
# Out:
# 내용       17
# 별점        0
# label     0
# dtype: int64
# <ipython-input-136-c691e3f2cf46>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   train_data['내용'] = train_data['내용'].str.replace('^ +', "")
# <ipython-input-136-c691e3f2cf46>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_data['내용'] = train_data['내용'].str.replace('^ +', "")
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py:4509: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(

# %%
train_data.loc[train_data.내용.isnull()][:5]
# Out:
# Empty DataFrame
# Columns: [내용, 별점, label]
# Index: []

# %%
train_data = train_data.dropna(how = 'any')
print(len(train_data))
# Out:
# 6115

# %%
okt = Okt()
stopwords = ['가','게','고','과','네','는','다','도','들','듯','를','에','와','으로',
             '은','을','의','이','인','임','자','잘','좀','지','하다','한']

# %%
X_train = []
for sentence in train_data['내용']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_train.append(temp_X)

# %%
print(X_train[:3])
# Out:
# [['나름', '만족', '음', '친구', '쓰다', '보고', '전', '쓰다', '블루투스', '이어폰', '망가지다', '한번', '사', '봣', '늘다', '괜찮다', '것', '같다', '귀', '한쪽', '끼다', '익숙', '치가', '않다', '불편하다', '데', '택배', '오다', '끄다', '보다', '사용', '법도', '쉬다', '나름', '만족', '많이', '파다'], ['너무', '좋다', '캐', '좋다', '가볍다', '부담', '없이', '차고', '다니다', '수', '있다', '수면', '관리', '만', '보기', '까지', '매일', '얼마나', '걸다', '확인', '가능하다', '간편하다', '시간', '확인', '수', '있다', '어제', '자다', '자다', '수면', '체크', '수', '있다', '특히', '수면', '관리', '깊다', '잠', '조금씩', '길어지다', '있다', '걸', '확인', '것', '차다', '좋다'], ['밉다', '밴드', '강', '추강', '추', '원래', '밉다', '밴드', '유저', '이다', '시계', '기능', '추가', '보고', '바로', '로', '갈아타다', '뭐', '심박', '기능', '이런', '것', '차다', '혁신', '적', '이지만', '일단', '시계', '맘', '들다', '가격', '나름', '저렴하다', '자다', '사다', '같다', '해외', '에서', '사오다', '건가', '무', '틀다', '늦어지다', '같다', '친히', '전화', '엄청', '친절', '그냥', '늦다', '오다', '잊다', '먹다', '있다', '생각', '보다', '더', '빨리', '보내다', '차다', '감사하다', '지금', '아주', '자다', '쓰다', '있다', '밴드', '세대', '보다', '밴드', '재질', '좋다', '그냥', '요', '거', '로만', '써다']]

# %%
X_test = []
for sentence in test_data['내용']:
    temp_X = okt.morphs(sentence, stem=True) # 토큰화
    temp_X = [word for word in temp_X if not word in stopwords] # 불용어 제거
    X_test.append(temp_X)
print(X_test[:3])
# Out:
# [['좋다', '가볍다', '예쁘다', '요귀', '밀착', '딱'], ['밉다', '밴드', '쓰다', '있다', '기능', '매우', '많이', '추가', '돼다', '우선', '디스플레이', '표시', '되다', '마음', '들다', '시계', '대용', '이나', '문', '자전', '화', '오다', '때', '진동', '알다', '되게', '좋다', '다만', '스마트', '밴드', '특성', '상', '아주', '크게', '유의', '미하', '쓸모', '많다', '않다'], ['가격', '만족도', '성능', '사용', '편의', '성', '등', '가격', '적정하다', '성능', '대체로', '괜찮다', '사용', '스마트폰', '연결', '오래', '걸리다', '문제', '빼다', '연', '결후', '엔', '스마트폰', '연동', '이니', '편리하다', '상태', '상태', '모두', '만족', '이다', '그', '외', '도움', '되다', '만', '사용', '후기', '로그', '인하다', '때', '로그인오류', '로', '조금', '오래', '걸리다', '연결', '되다', '전화', '알림', '문자', '알림', '시계', '발걸음', '수', '그리고', '심박수', '체크', '까지', '다른', '제품', '하고', '비교', '많이', '해', '서', '밉다', '밴드', '로', '구매', '가격', '대비', '비슷하다', '여자라서', '크다', '제품', '보다는', '작다', '걸', '로', '구매', '같다', '손목', '딱', '맞다', '이쁘다', '사업', '번창', '옥션', '안드로이드', '앱', '작성']]

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
print(tokenizer.word_index)
# Out:
# {'좋다': 1, '있다': 2, '되다': 3, '사용': 4, '자다': 5, '보다': 6, '같다': 7, '가격': 8, '없다': 9, '밴드': 10, '가성': 11, '로': 12, '비': 13, '이다': 14, '제품': 15, '구매': 16, '않다': 17, '쓰다': 18, '배송': 19, '받다': 20, '요': 21, '것': 22, '너무': 23, '빠르다': 24, '안': 25, '만': 26, '기능': 27, '폰': 28, '사다': 29, '만족하다': 30, '밉다': 31, '때': 32, '에서': 33, '하고': 34, '생각': 35, '괜찮다': 36, '수': 37, '들다': 38, '오다': 39, '더': 40, '음질': 41, '샤오미': 42, '충전': 43, '안되다': 44, '저렴하다': 45, '대비': 46, '정도': 47, '가다': 48, '저': 49, '성능': 50, '써다': 51, '중': 52, '많이': 53, '적': 54, '일': 55, '못': 56, '거': 57, '되어다': 58, '쓸다': 59, '제': 60, '전화': 61, '디자인': 62, '아니다': 63, '정말': 64, '그냥': 65, '구입': 66, '아주': 67, '조금': 68, '서': 69, '필름': 70, '주문': 71, '이어폰': 72, '시간': 73, '시계': 74, '상품': 75, '해보다': 76, '처음': 77, '이라': 78, '연결': 79, '배터리': 80, '운동': 81, '많다': 82, '그렇다': 83, '불편하다': 84, '편하다': 85, '하나': 86, '알다': 87, '나오다': 88, '수면': 89, '나': 90, '체크': 91, '설정': 92, '아쉽다': 93, '해주다': 94, '만족': 95, '다른': 96, '크다': 97, '문제': 98, '분': 99, '가볍다': 100, '통화': 101, '모르다': 102, '오래': 103, '선물': 104, '없이': 105, '이나': 106, '추천': 107, '아직': 108, '최고': 109, '확인': 110, '바로': 111, '화면': 112, '인데': 113, '까지': 114, '핸드폰': 115, '이쁘다': 116, '착용': 117, '알림': 118, '보기': 119, '개': 120, '면': 121, '작다': 122, '그': 123, '링': 124, '페어': 125, '마음': 126, '감사하다': 127, '한글': 128, '사': 129, '대': 130, '일단': 131, '앱': 132, '싸다': 133, '만족스럽다': 134, '라': 135, '택배': 136, '좋아하다': 137, '액정': 138, '이상': 139, '시': 140, '다시': 141, '매우': 142, '에는': 143, '걸리다': 144, '싶다': 145, '하': 146, '하루': 147, '그리고': 148, '블루투스': 149, '점': 150, '잘쓰다': 151, '추가': 152, '진동': 153, '랑': 154, '부분': 155, '드리다': 156, '귀': 157, '용': 158, '후': 159, '품질': 160, '역시': 161, '보고': 162, '터치': 163, '두': 164, '전': 165, '구': 166, '돼다': 167, '들리다': 168, '넘다': 169, '맘': 170, '느낌': 171, '맞다': 172, '느리다': 173, '주다': 174, '다만': 175, '스트랩': 176, '케이스': 177, '깔끔하다': 178, '소리': 179, '물건': 180, '끊기다': 181, '빨리': 182, '예쁘다': 183, '측정': 184, '그래도': 185, '필요하다': 186, '보호': 187, '보내다': 188, '빼다': 189, '딱': 190, '설명': 191, '알람': 192, '심박수': 193, '진짜': 194, '비다': 195, '엄청': 196, '사진': 197, '미노트': 198, '때문': 199, '이랑': 200, '보이다': 201, '바꾸다': 202, '차다': 203, '등': 204, '걸음': 205, '한번': 206, '홍': 207, '사람': 208, '문자': 209, '걸': 210, '늦다': 211, 'ㅎㅎ': 212, '떨어지다': 213, '뭐': 214, '기': 215, '손목': 216, '같이': 217, '상태': 218, '별로': 219, '어플': 220, '만원': 221, '근데': 222, '엔': 223, '가능하다': 224, '고민': 225, '판매': 226, '또': 227, '크기': 228, '완전': 229, '말': 230, '비싸다': 231, '해': 232, '아이': 233, '하지만': 234, '짱': 235, '이네': 236, '내': 237, '빨르다': 238, '기본': 239, '라서': 240, '시키다': 241, '워치': 242, '카톡': 243, '카메라': 244, '고장': 245, '걱정': 246, '아이폰': 247, '버리다': 248, '불량': 249, '도착': 250, '감': 251, '계속': 252, '굿': 253, '찾다': 254, '만에': 255, '정확하다': 256, '한쪽': 257, '나다': 258, '음악': 259, '나쁘다': 260, '포코': 261, '이번': 262, '단점': 263, '이렇다': 264, '갤럭시': 265, '몇': 266, '날': 267, '주': 268, '색상': 269, '포장': 270, '속도': 271, '건': 272, '파다': 273, '무선': 274, '편리하다': 275, '작동': 276, '에도': 277, '인식': 278, '뜨다': 279, '유심': 280, '교환': 281, '다음': 282, '알': 283, '빠지다': 284, '중국': 285, '니': 286, '특히': 287, '지금': 288, '자주': 289, '쓰기': 290, '이고': 291, '번': 292, '기존': 293, '연동': 294, '휴대폰': 295, '느끼다': 296, '성비': 297, '부터': 298, '줄': 299, '인지': 300, '여': 301, '약간': 302, '이에요': 303, '자체': 304, '넣다': 305, '확실하다': 306, '기다리다': 307, '늘다': 308, '쉬다': 309, '왼쪽': 310, '성': 311, '말다': 312, '다니다': 313, '비교': 314, '정발': 315, '경우': 316, '후기': 317, '노트': 318, '해봤다': 319, '선택': 320, '박스': 321, '두다': 322, '스마트': 323, '그래서': 324, '달': 325, '차고': 326, '가끔': 327, '국내': 328, '매': 329, '초기': 330, '크게': 331, '유용하다': 332, '원': 333, '기기': 334, '일주일': 335, '삼성': 336, '무엇': 337, '붙이다': 338, '잃어버리다': 339, '듣다': 340, '아': 341, '적당하다': 342, '다양하다': 343, '깔다': 344, '다르다': 345, '원래': 346, '손': 347, '게임': 348, '별': 349, '충전기': 350, '거의': 351, '년': 352, '재다': 353, '차이': 354, '심플': 355, '살다': 356, '부담': 357, '서다': 358, '따로': 359, '보': 360, '끼다': 361, '왜': 362, '가지': 363, '제일': 364, '문': 365, '방수': 366, '어렵다': 367, '하이마트': 368, '듭니': 369, 'ㅋㅋ': 370, '니까': 371, ...

# %%
threshold = 3
total_cnt = len(tokenizer.word_index) # 단어의 수
rare_cnt = 0 # 등장 빈도수가 threshold보다 작은 단어의 개수를 카운트
total_freq = 0 # 훈련 데이터의 전체 단어 빈도수 총 합
rare_freq = 0 # 등장 빈도수가 threshold보다 작은 단어의 등장 빈도수의 총 합

# 단어와 빈도수의 쌍(pair)을 key와 value로 받는다.
for key, value in tokenizer.word_counts.items():
    total_freq = total_freq + value

    # 단어의 등장 빈도수가 threshold보다 작으면
    if(value < threshold):
        rare_cnt = rare_cnt + 1
        rare_freq = rare_freq + value

print('단어 집합(vocabulary)의 크기 :',total_cnt)
print('등장 빈도가 %s번 이하인 희귀 단어의 수: %s'%(threshold - 1, rare_cnt))
print("단어 집합에서 희귀 단어의 비율:", (rare_cnt / total_cnt)*100)
print("전체 등장 빈도에서 희귀 단어 등장 빈도 비율:", (rare_freq / total_freq)*100)
# Out:
# 단어 집합(vocabulary)의 크기 : 6716
# 등장 빈도가 2번 이하인 희귀 단어의 수: 3807
# 단어 집합에서 희귀 단어의 비율: 56.68552709946396
# 전체 등장 빈도에서 희귀 단어 등장 빈도 비율: 4.662566982381904

# %%
# 전체 단어 개수 중 빈도수 2이하인 단어는 제거.
# 0번 패딩 토큰을 고려하여 + 1
vocab_size = total_cnt - rare_cnt + 1
print('단어 집합의 크기 :',vocab_size)
# Out:
# 단어 집합의 크기 : 2910

# %%
tokenizer = Tokenizer(vocab_size) 
tokenizer.fit_on_texts(X_train)
X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)

# %%
print(X_train[:3])
# Out:
# [[533, 95, 591, 460, 18, 162, 165, 18, 149, 72, 1183, 206, 129, 308, 36, 22, 7, 157, 257, 361, 1532, 17, 84, 562, 136, 39, 378, 6, 4, 1259, 309, 533, 95, 53, 273], [23, 1, 2416, 1, 100, 357, 105, 326, 313, 37, 2, 89, 518, 26, 119, 114, 697, 686, 373, 110, 224, 563, 73, 110, 37, 2, 965, 5, 5, 89, 91, 37, 2, 287, 89, 518, 1131, 923, 1688, 2106, 2, 210, 110, 22, 203, 1], [31, 10, 716, 346, 31, 10, 2107, 14, 74, 27, 152, 162, 111, 12, 888, 214, 741, 27, 889, 22, 203, 54, 575, 131, 74, 170, 38, 8, 533, 45, 5, 29, 7, 534, 33, 2417, 1260, 854, 966, 1261, 7, 61, 196, 65, 211, 39, 1533, 470, 2, 35, 6, 40, 182, 188, 203, 127, 288, 67, 5, 18, 2, 10, 1024, 6, 10, 855, 1, 65, 21, 57, 1534, 51]]

# %%
y_train = np.array(train_data['label'])
y_test = np.array(test_data['label'])

# %%
drop_train = [index for index, sentence in enumerate(X_train) if len(sentence) < 1]

# %%
# 빈 샘플들을 제거
X_train = np.delete(X_train, drop_train, axis=0)
y_train = np.delete(y_train, drop_train, axis=0)
print(len(X_train))
print(len(y_train))
# Out:
# 4576
# 4576
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
print('리뷰의 최대 길이 :',max(len(l) for l in X_train))
print('리뷰의 평균 길이 :',sum(map(len, X_train))/len(X_train))
plt.hist([len(s) for s in X_train], bins=50)
plt.xlabel('length of samples')
plt.ylabel('number of samples')
plt.show()
# Out:
# 리뷰의 최대 길이 : 305
# 리뷰의 평균 길이 : 21.07298951048951

# %%
def below_threshold_len(max_len, nested_list):
  cnt = 0
  for s in nested_list:
    if(len(s) <= max_len):
        cnt = cnt + 1
  print('전체 샘플 중 길이가 %s 이하인 샘플의 비율: %s'%(max_len, (cnt / len(nested_list))*100))

# %%
max_len = 50
below_threshold_len(max_len, X_train)
# Out:
# 전체 샘플 중 길이가 50 이하인 샘플의 비율: 90.42832167832168

# %%
X_train = pad_sequences(X_train, maxlen = max_len)
X_test = pad_sequences(X_test, maxlen = max_len)

# %%
model = Sequential()
model.add(Embedding(vocab_size, 100))
model.add(LSTM(128))
model.add(Dense(1, activation='sigmoid'))

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
mc = ModelCheckpoint('best_model.h5', monitor='val_acc', mode='max', verbose=1, save_best_only=True)

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['acc'])
history = model.fit(X_train, y_train, epochs=15, callbacks=[es, mc], batch_size=60, validation_split=0.2)
# Out:
# Epoch 1/15
# 61/61 [==============================] - 9s 113ms/step - loss: 0.1823 - acc: 0.9437 - val_loss: 0.6068 - val_acc: 0.8199
#
# Epoch 00001: val_acc did not improve from 0.84389
# Epoch 2/15
# 61/61 [==============================] - 7s 123ms/step - loss: 0.1167 - acc: 0.9544 - val_loss: 0.6611 - val_acc: 0.8231
#
# Epoch 00002: val_acc did not improve from 0.84389
# Epoch 3/15
# 61/61 [==============================] - 6s 100ms/step - loss: 0.1105 - acc: 0.9582 - val_loss: 0.7098 - val_acc: 0.8024
#
# Epoch 00003: val_acc did not improve from 0.84389
# Epoch 4/15
# 61/61 [==============================] - 6s 100ms/step - loss: 0.1026 - acc: 0.9631 - val_loss: 0.7233 - val_acc: 0.8057
#
# Epoch 00004: val_acc did not improve from 0.84389
# Epoch 5/15
# 61/61 [==============================] - 7s 117ms/step - loss: 0.1429 - acc: 0.9546 - val_loss: 0.7044 - val_acc: 0.8046
#
# Epoch 00005: val_acc did not improve from 0.84389
# Epoch 00005: early stopping

# %%
loaded_model = load_model('best_model.h5')
print("\n 테스트 정확도: %.4f" % (loaded_model.evaluate(X_test, y_test)[1]))
# Out:
# 48/48 [==============================] - 2s 23ms/step - loss: 0.4539 - acc: 0.8120
#
#  테스트 정확도: 0.8120

# %%
def sentiment_predict(new_sentence):
  new_sentence = okt.morphs(new_sentence, stem=True) # 토큰화
  new_sentence = [word for word in new_sentence if not word in stopwords] # 불용어 제거
  encoded = tokenizer.texts_to_sequences([new_sentence]) # 정수 인코딩
  pad_new = pad_sequences(encoded, maxlen = max_len) # 패딩
  score = float(loaded_model.predict(pad_new)) # 예측
  if(score > 0.5):
    print("{:.2f}% 확률로 긍정 리뷰입니다.\n".format(score * 100))
  else:
    print("{:.2f}% 확률로 부정 리뷰입니다.\n".format((1 - score) * 100))

# %%
sam = pd.read_csv("C:/690009/TP2/final_project/member/NTJ/crawlerNsReview/data/PP/sam.csv")
sam
# Out:
#       Unnamed: 0                                                 내용  \
# 0              0  사람들이 불만이 많아 걱정 많이했습니다사고 난 1일7일 발열 느껴졌습니다하지만 이 ...
# 1              1   s10 5g에서 기변했는데 카페글에 발열 심하다는 얘기가 많아 불안했지만 카메라가...
# 2              2  s21울트라로 기변했습니다침수된 s20는 as비용만 8090만원이 나오는지라저렴하게...
# 3              3  안녕하세요4월 말에 구매해서 지금까지 울트라 잘 사용하고 있습니다s21시리즈 문제때...
# 4              4             사용기종 s21최대가 3435도고 카메라 사용시 36도까지 찍었네요
# ...          ...                                                ...
# 1877        1877  역시 1세대 기술이라서 기대 전혀 안했는데요생각보다 티가 많이나네요저는 좀 예민한 ...
# 1878        1878   폴드2 사용중입니다이번에 UDC 펜 지원 방수 된다고 한데다 리뷰 영상보고 눈돌아...
# 1879        1879                                        udc 쫌  이상함
# 1880        1880  폴드2랑 디자인은 별 차이가 없지만 UDC디스플레이는 좋네요근데 아쉬운점은 흰화면에...
# 1881        1881   UDC는 기대하지 마세요 쓰레기입니다옛날 게임 그래픽 깨진것처럼 그냥 바로 보여요...
#
#                     등록일
# 0     2021.08.12. 10:54
# 1     2021.08.12. 10:39
# 2     2021.08.10. 07:09
# 3     2021.08.09. 17:50
# 4     2021.08.09. 17:00
# ...                 ...
# 1877  2021.08.12. 13:07
# 1878  2021.08.12. 12:45
# 1879  2021.08.12. 12:43
# 1880  2021.08.12. 11:57
# 1881  2021.08.12. 10:40
#
# [1882 rows x 3 columns]

# %%
sam.drop_duplicates(subset = ['내용'], inplace=True) # 중복 제거
sam['내용'] = sam['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행
sam['내용'].replace('', np.nan, inplace=True) # 공백은 Null 값으로 변경
sam = sam.dropna(how='any') # Null 값 제거
print('전처리 후 테스트용 샘플의 개수 :',len(sam))
# Out:
# 전처리 후 테스트용 샘플의 개수 : 1422
# <ipython-input-82-195377d8e736>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   sam['내용'] = sam['내용'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","") # 정규 표현식 수행

# %%
n = 0
for i in sam["내용"][:]:
    n += 1
    print(n)
    sentiment_predict(i)
# Out:
# 1
# 98.41% 확률로 긍정 리뷰입니다.
#
# 2
# 80.17% 확률로 긍정 리뷰입니다.
#
# 3
# 84.59% 확률로 긍정 리뷰입니다.
#
# 4
# 99.31% 확률로 긍정 리뷰입니다.
#
# 5
# 89.05% 확률로 긍정 리뷰입니다.
#
# 6
# 96.11% 확률로 긍정 리뷰입니다.
#
# 7
# 92.32% 확률로 긍정 리뷰입니다.
#
# 8
# 89.04% 확률로 긍정 리뷰입니다.
#
# 9
# 78.12% 확률로 긍정 리뷰입니다.
#
# 10
# 89.97% 확률로 긍정 리뷰입니다.
#
# 11
# 62.48% 확률로 긍정 리뷰입니다.
#
# 12
# 85.64% 확률로 긍정 리뷰입니다.
#
# 13
# 97.55% 확률로 긍정 리뷰입니다.
#
# 14
# 93.35% 확률로 긍정 리뷰입니다.
#
# 15
# 56.16% 확률로 부정 리뷰입니다.
#
# 16
# 76.24% 확률로 긍정 리뷰입니다.
#
# 17
# 87.58% 확률로 긍정 리뷰입니다.
#
# 18
# 90.44% 확률로 긍정 리뷰입니다.
#
# 19
# 95.09% 확률로 긍정 리뷰입니다.
#
# 20
# 61.19% 확률로 부정 리뷰입니다.
#
# 21
# 97.23% 확률로 긍정 리뷰입니다.
#
# 22
# 93.71% 확률로 긍정 리뷰입니다.
#
# 23
# 96.44% 확률로 긍정 리뷰입니다.
#
# 24
# 71.97% 확률로 부정 리뷰입니다.
#
# 25
# 76.69% 확률로 긍정 리뷰입니다.
#
# 26
# 94.47% 확률로 긍정 리뷰입니다.
#
# 27
# 84.96% 확률로 긍정 리뷰입니다.
#
# 28
# 99.26% 확률로 긍정 리뷰입니다.
#
# 29
# 99.23% 확률로 긍정 리뷰입니다.
#
# 30
# 82.05% 확률로 긍정 리뷰입니다.
#
# 31
# 96.67% 확률로 긍정 리뷰입니다.
#
# 32
# 63.30% 확률로 부정 리뷰입니다.
#
# 33
# 84.49% 확률로 긍정 리뷰입니다.
#
# 34
# 95.17% 확률로 긍정 리뷰입니다.
#
# 35
# 96.08% 확률로 긍정 리뷰입니다.
#
# 36
# 75.75% 확률로 긍정 리뷰입니다.
#
# 37
# 96.31% 확률로 긍정 리뷰입니다.
#
# 38
# 81.40% 확률로 부정 리뷰입니다.
#
# 39
# 76.59% 확률로 긍정 리뷰입니다.
#
# 40
# 97.87% 확률로 긍정 리뷰입니다.
#
# 41
# 95.68% 확률로 긍정 리뷰입니다.
#
# 42
# 50.31% 확률로 긍정 리뷰입니다.
#
# 43
# 98.85% 확률로 긍정 리뷰입니다.
#
# 44
# 97.05% 확률로 긍정 리뷰입니다.
#
# 45
# 98.77% 확률로 긍정 리뷰입니다.
#
# 46
# 83.87% 확률로 부정 리뷰입니다.
#
# 47
# 52.38% 확률로 긍정 리뷰입니다.
#
# 48
# 98.81% 확률로 긍정 리뷰입니다.
#
# 49
# 67.18% 확률로 부정 리뷰입니다.
#
# 50
# 64.45% 확률로 긍정 리뷰입니다.
#
# 51
# 93.13% 확률로 긍정 리뷰입니다.
#
# 52
# 54.54% 확률로 부정 리뷰입니다.
#
# 53
# 97.27% 확률로 긍정 리뷰입니다.
#
# 54
# 52.57% 확률로 긍정 리뷰입니다.
#
# 55
# 56.40% 확률로 부정 리뷰입니다.
#
# 56
# 95.02% 확률로 긍정 리뷰입니다.
#
# 57
# 92.82% 확률로 긍정 리뷰입니다.
#
# 58
# 50.26% 확률로 긍정 리뷰입니다.
#
# 59
# 98.99% 확률로 긍정 리뷰입니다.
#
# 60
# 55.89% 확률로 긍정 리뷰입니다.
#
# 61
# 97.86% 확률로 긍정 리뷰입니다.
#
# 62
# 96.55% 확률로 긍정 리뷰입니다.
#
# 63
# 53.94% 확률로 긍정 리뷰입니다.
#
# 64
# 94.82% 확률로 긍정 리뷰입니다.
#
# 65
# 97.96% 확률로 긍정 리뷰입니다.
#
# 66
# 59.22% 확률로 긍정 리뷰입니다.
#
# 67
# 94.41% 확률로 긍정 리뷰입니다.
#
# 68
# 96.36% 확률로 긍정 리뷰입니다.
#
# 69
# 98.12% 확률로 긍정 리뷰입니다.
#
# 70
# 92.75% 확률로 긍정 리뷰입니다.
#
# 71
# 96.27% 확률로 긍정 리뷰입니다.
#
# 72
# 95.40% 확률로 긍정 리뷰입니다.
#
# 73
# 97.24% 확률로 긍정 리뷰입니다.
#
# 74
# 98.80% 확률로 긍정 리뷰입니다.
#
# 75
# 99.18% 확률로 긍정 리뷰입니다.
#
# 76
# 51.36% 확률로 부정 리뷰입니다.
#
# 77
# 97.92% 확률로 긍정 리뷰입니다.
#
# 78
# 98.70% 확률로 긍정 리뷰입니다.
#
# 79
# 97.49% 확률로 긍정 리뷰입니다.
#
# 80
# 55.17% 확률로 부정 리뷰입니다.
#
# 81
# 98.37% 확률로 긍정 리뷰입니다.
#
# 82
# 99.43% 확률로 긍정 리뷰입니다.
#
# 83
# 98.99% 확률로 긍정 리뷰입니다.
#
# 84
# 86.00% 확률로 긍정 리뷰입니다.
#
# 85
# 55.24% 확률로 긍정 리뷰입니다.
#
# 86
# 87.38% 확률로 긍정 리뷰입니다.
#
# 87
# 83.97% 확률로 긍정 리뷰입니다.
#
# 88
# 57.87% 확률로 긍정 리뷰입니다.
#
# 89
# 88.31% 확률로 긍정 리뷰입니다.
#
# 90
# 83.31% 확률로 부정 리뷰입니다.
#
# 91
# 97.22% 확률로 긍정 리뷰입니다.
#
# 92
# 71.25% 확률로 긍정 리뷰입니다.
#
# 93
# 98.72% 확률로 긍정 리뷰입니다.
#
# 94
# 96.52% 확률로 긍정 리뷰입니다.
#
# 95
# 97.93% 확률로 긍정 리뷰입니다.
#
# 96
# 58.67% 확률로 긍정 리뷰입니다.
#
# 97
# 94.19% 확률로 긍정 리뷰입니다.
#
# 98
# 90.89% 확률로 긍정 리뷰입니다.
#
# 99
# 70.48% 확률로 긍정 리뷰입니다.
#
# 100
# 59.39% 확률로 부정 리뷰입니다.
#
# 101
# 72.13% 확률로 긍정 리뷰입니다.
#
# 102
# 76.54% 확률로 긍정 리뷰입니다.
#
# 103
# 89.63% 확률로 긍정 리뷰입니다.
#
# 104
# 92.91% 확률로 긍정 리뷰입니다.
#
# 105
# 95.23% 확률로 긍정 리뷰입니다.
#
# 106
# 97.60% 확률로 긍정 리뷰입니다.
#
# 107
# 82.75% 확률로 긍정 리뷰입니다.
#
# 108
# 55.09% 확률로 긍정 리뷰입니다.
#
# 109
# 78.88% 확률로 긍정 리뷰입니다.
#
# 110
# 84.52% 확률로 긍정 리뷰입니다.
#
# 111
# 70.07% 확률로 부정 리뷰입니다.
#
# 112
# 62.10% 확률로 긍정 리뷰입니다.
#
# 113
# 74.67% 확률로 긍정 리뷰입니다.
#
# 114
# 74.24% 확률로 긍정 리뷰입니다.
#
# 115
# 67.59% 확률로 긍정 리뷰입니다.
#
# 116
# 71.19% 확률로 긍정 리뷰입니다.
#
# 117
# 90.62% 확률로 긍정 리뷰입니다.
#
# 118
# 94.34% 확률로 긍정 리뷰입니다.
#
# 119
# 67.66% 확률로 긍정 리뷰입니다.
#
# 120
# 99.53% 확률로 긍정 리뷰입니다.
#
# 121
# 50.59% 확률로 긍정 리뷰입니다.
#
# 122
# 51.08% 확률로 긍정 리뷰입니다.
#
# 123
# 98.52% 확률로 긍정 리뷰입니다.
#
# 124
# 77.53% 확률로 긍정 리뷰입니다.
#
# 125
# 86.41% 확률로 긍정 리뷰입니다.
#
# 126
# 88.77% 확률로 긍정 리뷰입니다.
#
# 127
# 51.94% 확률로 부정 리뷰입니다.
#
# 128
# 98.28% 확률로 긍정 리뷰입니다.
#
# 129
# 60.55% 확률로 부정 리뷰입니다.
#
# 130
# 94.22% 확률로 긍정 리뷰입니다.
#
# 131
# 96.47% 확률로 긍정 리뷰입니다.
#
# 132
# 76.93% 확률로 긍정 리뷰입니다.
#
# 133
# 96.57% 확률로 긍정 리뷰입니다.
#
# 134
# 98.68% 확률로 긍정 리뷰입니다.
#
# 135
# 96.55% 확률로 긍정 리뷰입니다.
#
# 136
# 94.24% 확률로 긍정 리뷰입니다.
#
# 137
# 93.73% 확률로 긍정 리뷰입니다.
#
# 138
# 93.38% 확률로 긍정 리뷰입니다.
#
# 139
# 94.70% 확률로 긍정 리뷰입니다.
#
# 140
# 66.11% 확률로 긍정 리뷰입니다.
#
# 141
# 73.13% 확률로 긍정 리뷰입니다.
#
# 142
# 94.87% 확률로 긍정 리뷰입니다.
#
# 143
# 97.28% 확률로 긍정 리뷰입니다.
#
# 144
# 98.55% 확률로 긍정 리뷰입니다.
#
# 145
# 73.66% 확률로 긍정 리뷰입니다.
#
# 146
# 95.47% 확률로 긍정 리뷰입니다.
#
# 147
# 89.49% 확률로 긍정 리뷰입니다.
#
# 148
# 94.54% 확률로 긍정 리뷰입니다.
#
# 149
# 98.26% 확률로 긍정 리뷰입니다.
#
# 150
# 98.27% 확률로 긍정 리뷰입니다.
#
# 151
# 94.22% 확률로 긍정 리뷰입니다.
#
# 152
# 83.19% 확률로 긍정 리뷰입니다.
#
# 153
# 95.04% 확률로 긍정 리뷰입니다.
#
# 154
# 56.77% 확률로 부정 리뷰입니다.
#
# 155
# 95.99% 확률로 긍정 리뷰입니다.
#
# 156
# 52.26% 확률로 부정 리뷰입니다.
#
# 157
# 98.41% 확률로 긍정 리뷰입니다.
#
# 158
# 72.13% 확률로 긍정 리뷰입니다.
#
# 159
# 83.15% 확률로 긍정 리뷰입니다.
#
# 160
# 59.49% 확률로 긍정 리뷰입니다.
#
# 161
# 86.30% 확률로 긍정 리뷰입니다.
#
# 162
# 83.84% 확률로 긍정 리뷰입니다.
#
# 163
# 95.38% 확률로 긍정 리뷰입니다.
#
# 164
# 50.39% 확률로 긍정 리뷰입니다.
#
# 165
# 96.74% 확률로 긍정 리뷰입니다.
#
# 166
# 55.05% 확률로 긍정 리뷰입니다.
#
# 167
# 96.08% 확률로 긍정 리뷰입니다.
#
# 168
# 65.73% 확률로 긍정 리뷰입니다.
#
# 169
# 91.19% 확률로 긍정 리뷰입니다.
#
# 170
# 98.63% 확률로 긍정 리뷰입니다.
#
# 171
# 78.68% 확률로 긍정 리뷰입니다.
#
# 172
# 95.61% 확률로 긍정 리뷰입니다.
#
# 173
# 96.76% 확률로 긍정 리뷰입니다.
#
# 174
# 62.62% 확률로 긍정 리뷰입니다.
#
# 175
# 99.37% 확률로 긍정 리뷰입니다.
#
# 176
# 86.14% 확률로 긍정 리뷰입니다.
#
# 177
# 99.17% 확률로 긍정 리뷰입니다.
#
# 178
# 92.84% 확률로 긍정 리뷰입니다.
#
# 179
# 98.67% 확률로 긍정 리뷰입니다.
#
# 180
# 79.67% 확률로 긍정 리뷰입니다.
#
# 181
# 62.30% 확률로 부정 리뷰입니다.
#
# 182
# 73.76% 확률로 긍정 리뷰입니다.
#
# 183
# 96.62% 확률로 긍정 리뷰입니다.
#
# 184
# 84.17% 확률로 긍정 리뷰입니다.
#
# 185
# 82.50% 확률로 긍정 리뷰입니다.
#
# 186
# 58.68% 확률로 긍정 리뷰입니다.
#
# 187
# 98.88% 확률로 긍정 리뷰입니다.
#
# 188
# 99.71% 확률로 긍정 리뷰입니다.
#
# 189
# 96.26% 확률로 긍정 리뷰입니다.
#
# 190
# 98.02% 확률로 긍정 리뷰입니다.
#
# 191
# 98.70% 확률로 긍정 리뷰입니다.
#
# 192
# 88.77% 확률로 긍정 리뷰입니다.
#
# 193
# 53.02% 확률로 긍정 리뷰입니다.
#
# 194
# 99.05% 확률로 긍정 리뷰입니다.
#
# 195
# 93.43% 확률로 긍정 리뷰입니다.
#
# 196
# 74.95% 확률로 부정 리뷰입니다.
#
# 197
# 64.03% 확률로 부정 리뷰입니다.
#
# 198
# 91.25% 확률로 긍정 리뷰입니다.
#
# 199
# 74.30% 확률로 긍정 리뷰입니다.
#
# 200
# 61.42% 확률로 긍정 리뷰입니다.
#
# 201
# 89.36% 확률로 긍정 리뷰입니다.
#
# 202
# 98.41% 확률로 긍정 리뷰입니다.
#
# 203
# 95.16% 확률로 긍정 리뷰입니다.
#
# 204
# 99.48% 확률로 긍정 리뷰입니다.
#
# 205
# 99.03% 확률로 긍정 리뷰입니다.
#
# 206
# 98.95% 확률로 긍정 리뷰입니다.
#
# 207
# 98.09% 확률로 긍정 리뷰입니다.
#
# 208
# 87.72% 확률로 긍정 리뷰입니다.
#
# 209
# 77.42% 확률로 긍정 리뷰입니다.
#
# 210
# 96.67% 확률로 긍정 리뷰입니다.
#
# 211
# 98.32% 확률로 긍정 리뷰입니다.
#
# 212
# 99.40% 확률로 긍정 리뷰입니다.
#
# 213
# 96.71% 확률로 긍정 리뷰입니다.
#
# 214
# 96.98% 확률로 긍정 리뷰입니다.
#
# 215
# 97.46% 확률로 긍정 리뷰입니다.
#
# 216
# 99.22% 확률로 긍정 리뷰입니다.
#
# 217
# 92.74% 확률로 부정 리뷰입니다.
#
# 218
# 80.09% 확률로 긍정 리뷰입니다.
#
# 219
# 94.21% 확률로 긍정 리뷰입니다.
#
# 220
# 98.04% 확률로 긍정 리뷰입니다.
#
# 221
# 82.91% 확률로 긍정 리뷰입니다.
#
# 222
# 97.01% 확률로 긍정 리뷰입니다.
#
# 223
# 72.30% 확률로 긍정 리뷰입니다.
#
# 224
# 96.17% 확률로 긍정 리뷰입니다.
#
# 225
# 59.82% 확률로 부정 리뷰입니다.
#
# 226
# 98.01% 확률로 긍정 리뷰입니다.
#
# 227
# 97.48% 확률로 긍정 리뷰입니다.
#
# 228
# 99.03% 확률로 긍정 리뷰입니다.
#
# 229
# 99.43% 확률로 긍정 리뷰입니다.
#
# 230
# 95.55% 확률로 긍정 리뷰입니다.
#
# 231
# 99.10% 확률로 긍정 리뷰입니다.
#
# 232
# 98.00% 확률로 긍정 리뷰입니다.
#
# 233
# 98.18% 확률로 긍정 리뷰입니다.
#
# 234
# 98.35% 확률로 긍정 리뷰입니다.
#
# 235
# 64.70% 확률로 긍정 리뷰입니다.
#
# 236
# 99.25% 확률로 긍정 리뷰입니다.
#
# 237
# 99.67% 확률로 긍정 리뷰입니다.
#
# 238
# 57.77% 확률로 긍정 리뷰입니다.
#
# 239
# 79.86% 확률로 긍정 리뷰입니다.
#
# 240
# 58.81% 확률로 부정 리뷰입니다.
#
# 241
# 52.95% 확률로 부정 리뷰입니다.
#
# 242
# 70.50% 확률로 긍정 리뷰입니다.
#
# 243
# 98.42% 확률로 긍정 리뷰입니다.
#
# 244
# 99.24% 확률로 긍정 리뷰입니다.
#
# 245
# 96.47% 확률로 긍정 리뷰입니다.
#
# 246
# 89.68% 확률로 긍정 리뷰입니다.
#
# 247
# 68.35% 확률로 긍정 리뷰입니다.
#
# 248
# 97.21% 확률로 긍정 리뷰입니다.
#
# 249
# 86.16% 확률로 긍정 리뷰입니다.
#
# 250
# 75.34% 확률로 긍정 리뷰입니다.
#
# 251
# 99.46% 확률로 긍정 리뷰입니다.
#
# 252
# 99.05% 확률로 긍정 리뷰입니다.
#
# 253
# 96.84% 확률로 긍정 리뷰입니다.
#
# 254
# 56.98% 확률로 부정 리뷰입니다.
#
# 255
# 98.24% 확률로 긍정 리뷰입니다.
#
# 256
# 91.75% 확률로 긍정 리뷰입니다.
#
# 257
# 73.69% 확률로 긍정 리뷰입니다.
#
# 258
# 97.71% 확률로 긍정 리뷰입니다.
#
# 259
# 79.40% 확률로 긍정 리뷰입니다.
#
# 260
# 95.27% 확률로 긍정 리뷰입니다.
#
# 261
# 98.96% 확률로 긍정 리뷰입니다.
#
# 262
# 85.91% 확률로 긍정 리뷰입니다.
#
# 263
# 98.42% 확률로 긍정 리뷰입니다.
#
# 264
# 59.87% 확률로 부정 리뷰입니다.
#
# 265
# 69.97% 확률로 긍정 리뷰입니다.
#
# 266
# 68.67% 확률로 부정 리뷰입니다.
#
# 267
# 95.57% 확률로 긍정 리뷰입니다.
#
# 268
# 98.28% 확률로 긍정 리뷰입니다.
#
# 269
# 97.56% 확률로 긍정 리뷰입니다.
#
# 270
# 80.92% 확률로 긍정 리뷰입니다.
#
# 271
# 91.18% 확률로 긍정 리뷰입니다.
#
# 272
# 65.34% 확률로 긍정 리뷰입니다.
#
# 273
# 62.50% 확률로 긍정 리뷰입니다.
#
# 274
# 69.46% 확률로 긍정 리뷰입니다.
#
# 275
# 56.08% 확률로 긍정 리뷰입니다.
#
# 276
# 90.03% 확률로 긍정 리뷰입니다.
#
# 277
# 97.81% 확률로 긍정 리뷰입니다.
#
# 278
# 97.69% 확률로 긍정 리뷰입니다.
#
# 279
# 97.42% 확률로 긍정 리뷰입니다.
#
# 280
# 95.32% 확률로 긍정 리뷰입니다.
#
# 281
# 97.07% 확률로 긍정 리뷰입니다.
#
# 282
# 99.24% 확률로 긍정 리뷰입니다.
#
# 283
# 95.53% 확률로 긍정 리뷰입니다.
#
# 284
# 98.75% 확률로 긍정 리뷰입니다.
#
# 285
# 96.25% 확률로 긍정 리뷰입니다.
#
# 286
# 85.88% 확률로 부정 리뷰입니다.
#
# 287
# 99.66% 확률로 긍정 리뷰입니다.
#
# 288
# 96.10% 확률로 긍정 리뷰입니다.
#
# 289
# 99.45% 확률로 긍정 리뷰입니다.
#
# 290
# 96.53% 확률로 긍정 리뷰입니다.
#
# 291
# 98.34% 확률로 긍정 리뷰입니다.
#
# 292
# 98.74% 확률로 긍정 리뷰입니다.
#
# 293
# 84.97% 확률로 부정 리뷰입니다.
#
# 294
# 96.91% 확률로 긍정 리뷰입니다.
#
# 295
# 95.60% 확률로 긍정 리뷰입니다.
#
# 296
# 90.05% 확률로 긍정 리뷰입니다.
#
# 297
# 72.73% 확률로 부정 리뷰입니다.
#
# 298
# 79.80% 확률로 긍정 리뷰입니다.
#
# 299
# 55.52% 확률로 긍정 리뷰입니다.
#
# 300
# 80.59% 확률로 부정 리뷰입니다.
#
# 301
# 96.35% 확률로 긍정 리뷰입니다.
#
# 302
# 67.38% 확률로 부정 리뷰입니다.
#
# 303
# 74.25% 확률로 긍정 리뷰입니다.
#
# 304
# 93.56% 확률로 긍정 리뷰입니다.
#
# 305
# 98.05% 확률로 긍정 리뷰입니다.
#
# 306
# 99.54% 확률로 긍정 리뷰입니다.
#
# 307
# 61.08% 확률로 긍정 리뷰입니다.
#
# 308
# 98.93% 확률로 긍정 리뷰입니다.
#
# 309
# 99.36% 확률로 긍정 리뷰입니다.
#
# 310
# 99.51% 확률로 긍정 리뷰입니다.
#
# 311
# 97.16% 확률로 긍정 리뷰입니다.
#
# 312
# 97.87% 확률로 긍정 리뷰입니다.
#
# 313
# 95.49% 확률로 긍정 리뷰입니다.
#
# 314
# 85.98% 확률로 긍정 리뷰입니다.
#
# 315
# 95.35% 확률로 긍정 리뷰입니다.
#
# 316
# 58.87% 확률로 부정 리뷰입니다.
#
# 317
# 96.64% 확률로 긍정 리뷰입니다.
#
# 318
# 99.56% 확률로 긍정 리뷰입니다.
#
# 319
# 97.51% 확률로 긍정 리뷰입니다.
#
# 320
# 93.60% 확률로 긍정 리뷰입니다.
#
# 321
# 99.05% 확률로 긍정 리뷰입니다.
#
# 322
# 99.50% 확률로 긍정 리뷰입니다.
#
# 323
# 98.95% 확률로 긍정 리뷰입니다.
#
# 324
# 90.52% 확률로 긍정 리뷰입니다.
#
# 325
# 99.25% 확률로 긍정 리뷰입니다.
#
# 326
# 88.88% 확률로 긍정 리뷰입니다.
#
# 327
# 89.90% 확률로 긍정 리뷰입니다.
#
# 328
# 96.34% 확률로 긍정 리뷰입니다.
#
# 329
# 59.19% 확률로 긍정 리뷰입니다.
#
# 330
# 77.70% 확률로 긍정 리뷰입니다.
#
# 331
# 97.94% 확률로 긍정 리뷰입니다.
#
# 332
# 99.01% 확률로 긍정 리뷰입니다.
#
# 333
# 96.83% 확률로 긍정 리뷰입니다.
#
# 334
# 93.78% 확률로 긍정 리뷰입니다.
#
# 335
# 99.18% 확률로 긍정 리뷰입니다.
#
# 336
# 83.15% 확률로 긍정 리뷰입니다.
#
# 337
# 87.98% 확률로 긍정 리뷰입니다.
#
# 338
# 60.06% 확률로 긍정 리뷰입니다.
#
# 339
# 94.71% 확률로 긍정 리뷰입니다.
#
# 340
# 98.77% 확률로 긍정 리뷰입니다.
#
# 341
# 93.65% 확률로 긍정 리뷰입니다.
#
# 342
# 56.85% 확률로 부정 리뷰입니다.
#
# 343
# 97.33% 확률로 긍정 리뷰입니다.
#
# 344
# 97.06% 확률로 긍정 리뷰입니다.
#
# 345
# 96.19% 확률로 긍정 리뷰입니다.
#
# 346
# 91.16% 확률로 긍정 리뷰입니다.
#
# 347
# 95.00% 확률로 긍정 리뷰입니다.
#
# 348
# 99.08% 확률로 긍정 리뷰입니다.
#
# 349
# 94.67% 확률로 긍정 리뷰입니다.
#
# 350
# 76.35% 확률로 긍정 리뷰입니다.
#
# 351
# 96.24% 확률로 긍정 리뷰입니다.
#
# 352
# 91.13% 확률로 긍정 리뷰입니다.
#
# 353
# 54.99% 확률로 부정 리뷰입니다.
#
# 354
# 77.49% 확률로 긍정 리뷰입니다.
#
# 355
# 86.37% 확률로 긍정 리뷰입니다.
#
# 356
# 77.93% 확률로 긍정 리뷰입니다.
#
# 357
# 76.29% 확률로 긍정 리뷰입니다.
#
# 358
# 58.84% 확률로 긍정 리뷰입니다.
#
# 359
# 50.69% 확률로 부정 리뷰입니다.
#
# 360
# 99.58% 확률로 긍정 리뷰입니다.
#
# 361
# 98.90% 확률로 긍정 리뷰입니다.
#
# 362
# 75.26% 확률로 긍정 리뷰입니다.
#
# 363
# 98.95% 확률로 긍정 리뷰입니다.
#
# 364
# 99.09% 확률로 긍정 리뷰입니다.
#
# 365
# 96.80% 확률로 긍정 리뷰입니다.
#
# 366
# 99.61% 확률로 긍정 리뷰입니다.
#
# 367
# 59.55% 확률로 긍정 리뷰입니다.
#
# 368
# 93.60% 확률로 긍정 리뷰입니다.
#
# 369
# 99.56% 확률로 긍정 리뷰입니다.
#
# 370
# 94.72% 확률로 긍정 리뷰입니다.
#
# 371
# 85.08% 확률로 긍정 리뷰입니다.
#
# 372
# 95.68% 확률로 긍정 리뷰입니다.
#
# 373
# 68.87% 확률로 긍정 리뷰입니다.
#
# 374
# 91.54% 확률로 긍정 리뷰입니다.
#
# 375
# 60.17% 확률로 부정 리뷰입니다.
#
# 376
# 60.17% 확률로 긍정 리뷰입니다.
#
# 377
# 98.71% 확률로 긍정 리뷰입니다.
#
# 378
# 95.85% 확률로 긍정 리뷰입니다.
#
# 379
# 89.70% 확률로 긍정 리뷰입니다.
#
# 380
# 97.32% 확률로 긍정 리뷰입니다.
#
# 381
# 96.96% 확률로 긍정 리뷰입니다.
#
# 382
# 93.66% 확률로 긍정 리뷰입니다.
#
# 383
# 97.28% 확률로 긍정 리뷰입니다.
#
# 384
# 96.51% 확률로 긍정 리뷰입니다.
#
# 385
# 82.62% 확률로 긍정 리뷰입니다.
#
# 386
# 98.61% 확률로 긍정 리뷰입니다.
#
# 387
# 62.52% 확률로 긍정 리뷰입니다.
#
# 388
# 98.81% 확률로 긍정 리뷰입니다.
#
# 389
# 99.26% 확률로 긍정 리뷰입니다.
#
# 390
# 89.71% 확률로 긍정 리뷰입니다.
#
# 391
# 99.50% 확률로 긍정 리뷰입니다.
#
# 392
# 95.44% 확률로 긍정 리뷰입니다.
#
# 393
# 84.25% 확률로 긍정 리뷰입니다.
#
# 394
# 81.94% 확률로 긍정 리뷰입니다.
#
# 395
# 98.06% 확률로 긍정 리뷰입니다.
#
# 396
# 97.82% 확률로 긍정 리뷰입니다.
#
# 397
# 98.16% 확률로 긍정 리뷰입니다.
#
# 398
# 99.52% 확률로 긍정 리뷰입니다.
#
# 399
# 95.84% 확률로 긍정 리뷰입니다.
#
# 400
# 69.25% 확률로 긍정 리뷰입니다.
#
# 401
# 99.26% 확률로 긍정 리뷰입니다.
#
# 402
# 81.66% 확률로 긍정 리뷰입니다.
#
# 403
# 93.17% 확률로 긍정 리뷰입니다.
#
# 404
# 97.84% 확률로 긍정 리뷰입니다.
#
# 405
# 63.67% 확률로 긍정 리뷰입니다.
#
# 406
# 95.96% 확률로 긍정 리뷰입니다.
#
# 407
# 97.67% 확률로 긍정 리뷰입니다.
#
# 408
# 61.50% 확률로 긍정 리뷰입니다.
#
# 409
# 64.88% 확률로 긍정 리뷰입니다.
#
# 410
# 98.03% 확률로 긍정 리뷰입니다.
#
# 411
# 96.79% 확률로 긍정 리뷰입니다.
#
# 412
# 98.69% 확률로 긍정 리뷰입니다.
#
# 413
# 98.49% 확률로 긍정 리뷰입니다.
#
# 414
# 85.07% 확률로 긍정 리뷰입니다.
#
# 415
# 98.73% 확률로 긍정 리뷰입니다.
#
# 416
# 75.82% 확률로 긍정 리뷰입니다.
#
# 417
# 98.86% 확률로 긍정 리뷰입니다.
#
# 418
# 87.11% 확률로 긍정 리뷰입니다.
#
# 419
# 55.89% 확률로 긍정 리뷰입니다.
#
# 420
# 79.10% 확률로 긍정 리뷰입니다.
#
# 421
# 99.06% 확률로 긍정 리뷰입니다.
#
# 422
# 83.81% 확률로 긍정 리뷰입니다.
#
# 423
# 89.35% 확률로 긍정 리뷰입니다.
#
# 424
# 74.89% 확률로 긍정 리뷰입니다.
#
# 425
# 96.30% 확률로 긍정 리뷰입니다.
#
# 426
# 91.76% 확률로 긍정 리뷰입니다.
#
# 427
# 97.32% 확률로 긍정 리뷰입니다.
#
# 428
# 93.26% 확률로 긍정 리뷰입니다.
#
# 429
# 91.24% 확률로 긍정 리뷰입니다.
#
# 430
# 75.82% 확률로 부정 리뷰입니다.
#
# 431
# 80.08% 확률로 긍정 리뷰입니다.
#
# 432
# 64.19% 확률로 긍정 리뷰입니다.
#
# 433
# 93.51% 확률로 긍정 리뷰입니다.
#
# 434
# 99.52% 확률로 긍정 리뷰입니다.
#
# 435
# 94.95% 확률로 긍정 리뷰입니다.
#
# 436
# 52.70% 확률로 긍정 리뷰입니다.
#
# 437
# 57.76% 확률로 부정 리뷰입니다.
#
# 438
# 89.81% 확률로 긍정 리뷰입니다.
#
# 439
# 89.07% 확률로 부정 리뷰입니다.
#
# 440
# 91.01% 확률로 긍정 리뷰입니다.
#
# 441
# 81.65% 확률로 긍정 리뷰입니다.
#
# 442
# 96.89% 확률로 긍정 리뷰입니다.
#
# 443
# 98.49% 확률로 긍정 리뷰입니다.
#
# 444
# 58.38% 확률로 부정 리뷰입니다.
#
# 445
# 71.41% 확률로 부정 리뷰입니다.
#
# 446
# 96.68% 확률로 긍정 리뷰입니다.
#
# 447
# 61.32% 확률로 부정 리뷰입니다.
#
# 448
# 88.20% 확률로 긍정 리뷰입니다.
#
# 449
# 92.58% 확률로 긍정 리뷰입니다.
#
# 450
# 98.22% 확률로 긍정 리뷰입니다.
#
# 451
# 98.82% 확률로 긍정 리뷰입니다.
#
# 452
# 99.65% 확률로 긍정 리뷰입니다.
#
# 453
# 57.28% 확률로 긍정 리뷰입니다.
#
# 454
# 86.73% 확률로 긍정 리뷰입니다.
#
# 455
# 66.47% 확률로 부정 리뷰입니다.
#
# 456
# 80.28% 확률로 부정 리뷰입니다.
#
# 457
# 93.33% 확률로 긍정 리뷰입니다.
#
# 458
# 85.82% 확률로 부정 리뷰입니다.
#
# 459
# 94.46% 확률로 긍정 리뷰입니다.
#
# 460
# 95.96% 확률로 긍정 리뷰입니다.
#
# 461
# 99.18% 확률로 긍정 리뷰입니다.
#
# 462
# 89.17% 확률로 긍정 리뷰입니다.
#
# 463
# 82.28% 확률로 긍정 리뷰입니다.
#
# 464
# 98.74% 확률로 긍정 리뷰입니다.
#
# 465
# 98.90% 확률로 긍정 리뷰입니다.
#
# 466
# 97.50% 확률로 긍정 리뷰입니다.
#
# 467
# 97.50% 확률로 긍정 리뷰입니다.
#
# 468
# 96.85% 확률로 긍정 리뷰입니다.
#
# 469
# 85.86% 확률로 긍정 리뷰입니다.
#
# 470
# 98.68% 확률로 긍정 리뷰입니다.
#
# 471
# 96.96% 확률로 긍정 리뷰입니다.
#
# 472
# 60.35% 확률로 긍정 리뷰입니다.
#
# 473
# 94.96% 확률로 긍정 리뷰입니다.
#
# 474
# 74.40% 확률로 긍정 리뷰입니다.
#
# 475
# 63.98% 확률로 부정 리뷰입니다.
#
# 476
# 97.25% 확률로 긍정 리뷰입니다.
#
# 477
# 98.64% 확률로 긍정 리뷰입니다.
#
# 478
# 98.05% 확률로 긍정 리뷰입니다.
#
# 479
# 73.96% 확률로 부정 리뷰입니다.
#
# 480
# 82.93% 확률로 긍정 리뷰입니다.
#
# 481
# 99.04% 확률로 긍정 리뷰입니다.
#
# 482
# 92.62% 확률로 긍정 리뷰입니다.
#
# 483
# 97.27% 확률로 긍정 리뷰입니다.
#
# 484
# 99.33% 확률로 긍정 리뷰입니다.
#
# 485
# 96.21% 확률로 긍정 리뷰입니다.
#
# 486
# 98.12% 확률로 긍정 리뷰입니다.
#
# 487
# 98.66% 확률로 긍정 리뷰입니다.
#
# 488
# 87.27% 확률로 긍정 리뷰입니다.
#
# 489
# 99.05% 확률로 긍정 리뷰입니다.
#
# 490
# 74.41% 확률로 긍정 리뷰입니다.
#
# 491
# 94.76% 확률로 부정 리뷰입니다.
#
# 492
# 98.19% 확률로 긍정 리뷰입니다.
#
# 493
# 98.23% 확률로 긍정 리뷰입니다.
#
# 494
# 56.50% 확률로 부정 리뷰입니다.
#
# 495
# 98.23% 확률로 긍정 리뷰입니다.
#
# 496
# 98.24% 확률로 긍정 리뷰입니다.
#
# 497
# 98.72% 확률로 긍정 리뷰입니다.
#
# 498
# 99.74% 확률로 긍정 리뷰입니다.
#
# 499
# 99.42% 확률로 긍정 리뷰입니다.
#
# 500
# 72.73% 확률로 부정 리뷰입니다.
#
# 501
# 51.55% 확률로 긍정 리뷰입니다.
#
# 502
# 79.62% 확률로 긍정 리뷰입니다.
#
# 503
# 97.48% 확률로 긍정 리뷰입니다.
#
# 504
# 97.91% 확률로 긍정 리뷰입니다.
#
# 505
# 97.64% 확률로 긍정 리뷰입니다.
#
# 506
# 75.12% 확률로 긍정 리뷰입니다.
#
# 507
# 79.36% 확률로 부정 리뷰입니다.
#
# 508
# 96.47% 확률로 긍정 리뷰입니다.
#
# 509
# 93.23% 확률로 긍정 리뷰입니다.
#
# 510
# 72.79% 확률로 긍정 리뷰입니다.
#
# 511
# 95.13% 확률로 긍정 리뷰입니다.
#
# 512
# 82.23% 확률로 긍정 리뷰입니다.
#
# 513
# 67.33% 확률로 긍정 리뷰입니다.
#
# 514
# 98.90% 확률로 긍정 리뷰입니다.
#
# 515
# 71.65% 확률로 부정 리뷰입니다.
#
# 516
# 54.72% 확률로 긍정 리뷰입니다.
#
# 517
# 51.00% 확률로 긍정 리뷰입니다.
#
# 518
# 99.54% 확률로 긍정 리뷰입니다.
#
# 519
# 98.01% 확률로 긍정 리뷰입니다.
#
# 520
# 86.09% 확률로 긍정 리뷰입니다.
#
# 521
# 91.60% 확률로 긍정 리뷰입니다.
#
# 522
# 99.27% 확률로 긍정 리뷰입니다.
#
# 523
# 66.75% 확률로 긍정 리뷰입니다.
#
# 524
# 99.08% 확률로 긍정 리뷰입니다.
#
# 525
# 68.48% 확률로 부정 리뷰입니다.
#
# 526
# 68.06% 확률로 긍정 리뷰입니다.
#
# 527
# 97.96% 확률로 긍정 리뷰입니다.
#
# 528
# 95.47% 확률로 긍정 리뷰입니다.
#
# 529
# 96.21% 확률로 긍정 리뷰입니다.
#
# 530
# 82.76% 확률로 긍정 리뷰입니다.
#
# 531
# 99.26% 확률로 긍정 리뷰입니다.
#
# 532
# 90.26% 확률로 긍정 리뷰입니다.
#
# 533
# 97.97% 확률로 긍정 리뷰입니다.
#
# 534
# 59.81% 확률로 부정 리뷰입니다.
#
# 535
# 58.23% 확률로 부정 리뷰입니다.
#
# 536
# 51.45% 확률로 부정 리뷰입니다.
#
# 537
# 96.45% 확률로 긍정 리뷰입니다.
#
# 538
# 95.10% 확률로 긍정 리뷰입니다.
#
# 539
# 96.45% 확률로 긍정 리뷰입니다.
#
# 540
# 95.00% 확률로 긍정 리뷰입니다.
#
# 541
# 53.08% 확률로 부정 리뷰입니다.
#
# 542
# 98.08% 확률로 긍정 리뷰입니다.
#
# 543
# 52.34% 확률로 부정 리뷰입니다.
#
# 544
# 75.77% 확률로 긍정 리뷰입니다.
#
# 545
# 87.25% 확률로 긍정 리뷰입니다.
#
# 546
# 71.96% 확률로 부정 리뷰입니다.
#
# 547
# 97.16% 확률로 긍정 리뷰입니다.
#
# 548
# 71.29% 확률로 긍정 리뷰입니다.
#
# 549
# 99.26% 확률로 긍정 리뷰입니다.
#
# 550
# 59.51% 확률로 부정 리뷰입니다.
#
# 551
# 97.53% 확률로 긍정 리뷰입니다.
#
# 552
# 73.20% 확률로 긍정 리뷰입니다.
#
# 553
# 66.84% 확률로 긍정 리뷰입니다.
#
# 554
# 88.13% 확률로 긍정 리뷰입니다.
#
# 555
# 68.54% 확률로 부정 리뷰입니다.
#
# 556
# 93.73% 확률로 긍정 리뷰입니다.
#
# 557
# 60.91% 확률로 긍정 리뷰입니다.
#
# 558
# 92.22% 확률로 긍정 리뷰입니다.
#
# 559
# 98.64% 확률로 긍정 리뷰입니다.
#
# 560
# 79.05% 확률로 부정 리뷰입니다.
#
# 561
# 82.52% 확률로 긍정 리뷰입니다.
#
# 562
# 66.32% 확률로 긍정 리뷰입니다.
#
# 563
# 95.71% 확률로 긍정 리뷰입니다.
#
# 564
# 96.30% 확률로 긍정 리뷰입니다.
#
# 565
# 63.37% 확률로 긍정 리뷰입니다.
#
# 566
# 96.35% 확률로 긍정 리뷰입니다.
#
# 567
# 93.98% 확률로 긍정 리뷰입니다.
#
# 568
# 55.26% 확률로 부정 리뷰입니다.
#
# 569
# 99.06% 확률로 긍정 리뷰입니다.
#
# 570
# 95.12% 확률로 긍정 리뷰입니다.
#
# 571
# 93.20% 확률로 긍정 리뷰입니다.
#
# 572
# 81.48% 확률로 긍정 리뷰입니다.
#
# 573
# 59.54% 확률로 부정 리뷰입니다.
#
# 574
# 98.06% 확률로 긍정 리뷰입니다.
#
# 575
# 70.48% 확률로 긍정 리뷰입니다.
#
# 576
# 96.27% 확률로 긍정 리뷰입니다.
#
# 577
# 98.66% 확률로 긍정 리뷰입니다.
#
# 578
# 81.19% 확률로 긍정 리뷰입니다.
#
# 579
# 51.94% 확률로 부정 리뷰입니다.
#
# 580
# 54.24% 확률로 긍정 리뷰입니다.
#
# 581
# 91.86% 확률로 긍정 리뷰입니다.
#
# 582
# 50.12% 확률로 부정 리뷰입니다.
#
# 583
# 89.41% 확률로 긍정 리뷰입니다.
#
# 584
# 98.26% 확률로 긍정 리뷰입니다.
#
# 585
# 95.87% 확률로 긍정 리뷰입니다.
#
# 586
# 95.87% 확률로 긍정 리뷰입니다.
#
# 587
# 99.60% 확률로 긍정 리뷰입니다.
#
# 588
# 96.62% 확률로 긍정 리뷰입니다.
#
# 589
# 99.35% 확률로 긍정 리뷰입니다.
#
# 590
# 74.28% 확률로 긍정 리뷰입니다.
#
# 591
# 88.12% 확률로 긍정 리뷰입니다.
#
# 592
# 62.24% 확률로 긍정 리뷰입니다.
#
# 593
# 84.39% 확률로 긍정 리뷰입니다.
#
# 594
# 82.79% 확률로 긍정 리뷰입니다.
#
# 595
# 59.79% 확률로 부정 리뷰입니다.
#
# 596
# 99.32% 확률로 긍정 리뷰입니다.
#
# 597
# 96.22% 확률로 긍정 리뷰입니다.
#
# 598
# 81.15% 확률로 긍정 리뷰입니다.
#
# 599
# 89.73% 확률로 긍정 리뷰입니다.
#
# 600
# 99.17% 확률로 긍정 리뷰입니다.
#
# 601
# 68.96% 확률로 부정 리뷰입니다.
#
# 602
# 97.01% 확률로 긍정 리뷰입니다.
#
# 603
# 99.31% 확률로 긍정 리뷰입니다.
#
# 604
# 95.11% 확률로 긍정 리뷰입니다.
#
# 605
# 77.56% 확률로 긍정 리뷰입니다.
#
# 606
# 57.99% 확률로 부정 리뷰입니다.
#
# 607
# 90.17% 확률로 긍정 리뷰입니다.
#
# 608
# 98.26% 확률로 긍정 리뷰입니다.
#
# 609
# 87.64% 확률로 긍정 리뷰입니다.
#
# 610
# 62.94% 확률로 긍정 리뷰입니다.
#
# 611
# 85.05% 확률로 긍정 리뷰입니다.
#
# 612
# 84.14% 확률로 긍정 리뷰입니다.
#
# 613
# 98.28% 확률로 긍정 리뷰입니다.
#
# 614
# 94.86% 확률로 긍정 리뷰입니다.
#
# 615
# 85.73% 확률로 긍정 리뷰입니다.
#
# 616
# 97.42% 확률로 긍정 리뷰입니다.
#
# 617
# 95.75% 확률로 긍정 리뷰입니다.
#
# 618
# 96.96% 확률로 긍정 리뷰입니다.
#
# 619
# 72.56% 확률로 긍정 리뷰입니다.
#
# 620
# 81.66% 확률로 부정 리뷰입니다.
#
# 621
# 99.24% 확률로 긍정 리뷰입니다.
#
# 622
# 96.79% 확률로 긍정 리뷰입니다.
#
# 623
# 53.81% 확률로 부정 리뷰입니다.
#
# 624
# 94.50% 확률로 긍정 리뷰입니다.
#
# 625
# 97.06% 확률로 긍정 리뷰입니다.
#
# 626
# 98.97% 확률로 긍정 리뷰입니다.
#
# 627
# 97.86% 확률로 긍정 리뷰입니다.
#
# 628
# 91.18% 확률로 긍정 리뷰입니다.
#
# 629
# 63.29% 확률로 부정 리뷰입니다.
#
# 630
# 85.44% 확률로 긍정 리뷰입니다.
#
# 631
# 58.63% 확률로 부정 리뷰입니다.
#
# 632
# 64.72% 확률로 긍정 리뷰입니다.
#
# 633
# 89.78% 확률로 긍정 리뷰입니다.
#
# 634
# 62.64% 확률로 부정 리뷰입니다.
#
# 635
# 87.94% 확률로 긍정 리뷰입니다.
#
# 636
# 71.91% 확률로 긍정 리뷰입니다.
#
# 637
# 93.97% 확률로 긍정 리뷰입니다.
#
# 638
# 97.92% 확률로 긍정 리뷰입니다.
#
# 639
# 51.10% 확률로 부정 리뷰입니다.
#
# 640
# 73.87% 확률로 긍정 리뷰입니다.
#
# 641
# 99.04% 확률로 긍정 리뷰입니다.
#
# 642
# 73.95% 확률로 긍정 리뷰입니다.
#
# 643
# 94.82% 확률로 긍정 리뷰입니다.
#
# 644
# 95.38% 확률로 긍정 리뷰입니다.
#
# 645
# 98.14% 확률로 긍정 리뷰입니다.
#
# 646
# 94.95% 확률로 긍정 리뷰입니다.
#
# 647
# 98.95% 확률로 긍정 리뷰입니다.
#
# 648
# 96.54% 확률로 긍정 리뷰입니다.
#
# 649
# 88.92% 확률로 긍정 리뷰입니다.
#
# 650
# 97.51% 확률로 긍정 리뷰입니다.
#
# 651
# 99.39% 확률로 긍정 리뷰입니다.
#
# 652
# 98.99% 확률로 긍정 리뷰입니다.
#
# 653
# 83.80% 확률로 긍정 리뷰입니다.
#
# 654
# 88.63% 확률로 부정 리뷰입니다.
#
# 655
# 67.01% 확률로 부정 리뷰입니다.
#
# 656
# 65.95% 확률로 긍정 리뷰입니다.
#
# 657
# 56.48% 확률로 긍정 리뷰입니다.
#
# 658
# 81.01% 확률로 긍정 리뷰입니다.
#
# 659
# 99.08% 확률로 긍정 리뷰입니다.
#
# 660
# 84.11% 확률로 긍정 리뷰입니다.
#
# 661
# 78.53% 확률로 긍정 리뷰입니다.
#
# 662
# 96.41% 확률로 긍정 리뷰입니다.
#
# 663
# 98.79% 확률로 긍정 리뷰입니다.
#
# 664
# 98.84% 확률로 긍정 리뷰입니다.
#
# 665
# 97.84% 확률로 긍정 리뷰입니다.
#
# 666
# 79.77% 확률로 부정 리뷰입니다.
#
# 667
# 89.78% 확률로 긍정 리뷰입니다.
#
# 668
# 85.90% 확률로 긍정 리뷰입니다.
#
# 669
# 94.88% 확률로 긍정 리뷰입니다.
#
# 670
# 97.06% 확률로 긍정 리뷰입니다.
#
# 671
# 94.29% 확률로 긍정 리뷰입니다.
#
# 672
# 96.74% 확률로 긍정 리뷰입니다.
#
# 673
# 97.46% 확률로 긍정 리뷰입니다.
#
# 674
# 93.54% 확률로 긍정 리뷰입니다.
#
# 675
# 98.67% 확률로 긍정 리뷰입니다.
#
# 676
# 73.07% 확률로 긍정 리뷰입니다.
#
# 677
# 94.22% 확률로 긍정 리뷰입니다.
#
# 678
# 50.46% 확률로 긍정 리뷰입니다.
#
# 679
# 99.29% 확률로 긍정 리뷰입니다.
#
# 680
# 88.79% 확률로 긍정 리뷰입니다.
#
# 681
# 94.32% 확률로 긍정 리뷰입니다.
#
# 682
# 59.70% 확률로 부정 리뷰입니다.
#
# 683
# 81.63% 확률로 긍정 리뷰입니다.
#
# 684
# 73.87% 확률로 긍정 리뷰입니다.
#
# 685
# 96.03% 확률로 긍정 리뷰입니다.
#
# 686
# 83.76% 확률로 긍정 리뷰입니다.
#
# 687
# 98.78% 확률로 긍정 리뷰입니다.
#
# 688
# 97.26% 확률로 긍정 리뷰입니다.
#
# 689
# 97.98% 확률로 긍정 리뷰입니다.
#
# 690
# 93.96% 확률로 긍정 리뷰입니다.
#
# 691
# 81.26% 확률로 긍정 리뷰입니다.
#
# 692
# 96.78% 확률로 긍정 리뷰입니다.
#
# 693
# 87.81% 확률로 긍정 리뷰입니다.
#
# 694
# 63.86% 확률로 긍정 리뷰입니다.
#
# 695
# 97.84% 확률로 긍정 리뷰입니다.
#
# 696
# 98.13% 확률로 긍정 리뷰입니다.
#
# 697
# 97.32% 확률로 긍정 리뷰입니다.
#
# 698
# 98.53% 확률로 긍정 리뷰입니다.
#
# 699
# 98.36% 확률로 긍정 리뷰입니다.
#
# 700
# 68.65% 확률로 긍정 리뷰입니다.
#
# 701
# 85.48% 확률로 긍정 리뷰입니다.
#
# 702
# 68.56% 확률로 긍정 리뷰입니다.
#
# 703
# 99.29% 확률로 긍정 리뷰입니다.
#
# 704
# 60.88% 확률로 부정 리뷰입니다.
#
# 705
# 98.02% 확률로 긍정 리뷰입니다.
#
# 706
# 83.80% 확률로 부정 리뷰입니다.
#
# 707
# 65.53% 확률로 긍정 리뷰입니다.
#
# 708
# 75.65% 확률로 긍정 리뷰입니다.
#
# 709
# 95.38% 확률로 긍정 리뷰입니다.
#
# 710
# 94.37% 확률로 긍정 리뷰입니다.
#
# 711
# 83.82% 확률로 긍정 리뷰입니다.
#
# 712
# 84.09% 확률로 부정 리뷰입니다.
#
# 713
# 70.30% 확률로 긍정 리뷰입니다.
#
# 714
# 99.45% 확률로 긍정 리뷰입니다.
#
# 715
# 99.47% 확률로 긍정 리뷰입니다.
#
# 716
# 51.14% 확률로 긍정 리뷰입니다.
#
# 717
# 85.35% 확률로 긍정 리뷰입니다.
#
# 718
# 95.70% 확률로 긍정 리뷰입니다.
#
# 719
# 95.63% 확률로 긍정 리뷰입니다.
#
# 720
# 76.47% 확률로 긍정 리뷰입니다.
#
# 721
# 80.46% 확률로 긍정 리뷰입니다.
#
# 722
# 70.17% 확률로 부정 리뷰입니다.
#
# 723
# 71.37% 확률로 긍정 리뷰입니다.
#
# 724
# 84.81% 확률로 긍정 리뷰입니다.
#
# 725
# 94.53% 확률로 긍정 리뷰입니다.
#
# 726
# 97.11% 확률로 긍정 리뷰입니다.
#
# 727
# 98.35% 확률로 긍정 리뷰입니다.
#
# 728
# 93.62% 확률로 긍정 리뷰입니다.
#
# 729
# 94.97% 확률로 긍정 리뷰입니다.
#
# 730
# 75.48% 확률로 긍정 리뷰입니다.
#
# 731
# 97.41% 확률로 긍정 리뷰입니다.
#
# 732
# 95.98% 확률로 긍정 리뷰입니다.
#
# 733
# 68.37% 확률로 긍정 리뷰입니다.
#
# 734
# 96.20% 확률로 긍정 리뷰입니다.
#
# 735
# 97.73% 확률로 긍정 리뷰입니다.
#
# 736
# 91.23% 확률로 긍정 리뷰입니다.
#
# 737
# 97.86% 확률로 긍정 리뷰입니다.
#
# 738
# 54.27% 확률로 부정 리뷰입니다.
#
# 739
# 84.23% 확률로 긍정 리뷰입니다.
#
# 740
# 98.58% 확률로 긍정 리뷰입니다.
#
# 741
# 63.48% 확률로 긍정 리뷰입니다.
#
# 742
# 50.45% 확률로 부정 리뷰입니다.
#
# 743
# 86.81% 확률로 긍정 리뷰입니다.
#
# 744
# 72.69% 확률로 부정 리뷰입니다.
#
# 745
# 76.15% 확률로 긍정 리뷰입니다.
#
# 746
# 97.80% 확률로 긍정 리뷰입니다.
#
# 747
# 99.13% 확률로 긍정 리뷰입니다.
#
# 748
# 79.99% 확률로 긍정 리뷰입니다.
#
# 749
# 95.23% 확률로 긍정 리뷰입니다.
#
# 750
# 87.77% 확률로 긍정 리뷰입니다.
#
# 751
# 53.21% 확률로 긍정 리뷰입니다.
#
# 752
# 80.96% 확률로 긍정 리뷰입니다.
#
# 753
# 97.49% 확률로 긍정 리뷰입니다.
#
# 754
# 93.16% 확률로 긍정 리뷰입니다.
#
# 755
# 97.30% 확률로 긍정 리뷰입니다.
#
# 756
# 92.62% 확률로 긍정 리뷰입니다.
#
# 757
# 85.91% 확률로 긍정 리뷰입니다.
#
# 758
# 62.99% 확률로 긍정 리뷰입니다.
#
# 759
# 71.35% 확률로 긍정 리뷰입니다.
#
# 760
# 99.28% 확률로 긍정 리뷰입니다.
#
# 761
# 96.33% 확률로 긍정 리뷰입니다.
#
# 762
# 93.33% 확률로 긍정 리뷰입니다.
#
# 763
# 99.50% 확률로 긍정 리뷰입니다.
#
# 764
# 98.07% 확률로 긍정 리뷰입니다.
#
# 765
# 98.04% 확률로 긍정 리뷰입니다.
#
# 766
# 95.95% 확률로 긍정 리뷰입니다.
#
# 767
# 99.05% 확률로 긍정 리뷰입니다.
#
# 768
# 99.64% 확률로 긍정 리뷰입니다.
#
# 769
# 75.69% 확률로 긍정 리뷰입니다.
#
# 770
# 62.06% 확률로 부정 리뷰입니다.
#
# 771
# 60.03% 확률로 부정 리뷰입니다.
#
# 772
# 95.84% 확률로 긍정 리뷰입니다.
#
# 773
# 52.31% 확률로 부정 리뷰입니다.
#
# 774
# 74.89% 확률로 부정 리뷰입니다.
#
# 775
# 70.21% 확률로 긍정 리뷰입니다.
#
# 776
# 98.51% 확률로 긍정 리뷰입니다.
#
# 777
# 85.58% 확률로 긍정 리뷰입니다.
#
# 778
# 71.24% 확률로 긍정 리뷰입니다.
#
# 779
# 73.06% 확률로 긍정 리뷰입니다.
#
# 780
# 95.47% 확률로 긍정 리뷰입니다.
#
# 781
# 80.41% 확률로 긍정 리뷰입니다.
#
# 782
# 95.51% 확률로 긍정 리뷰입니다.
#
# 783
# 97.21% 확률로 긍정 리뷰입니다.
#
# 784
# 77.84% 확률로 긍정 리뷰입니다.
#
# 785
# 67.02% 확률로 긍정 리뷰입니다.
#
# 786
# 79.50% 확률로 긍정 리뷰입니다.
#
# 787
# 52.91% 확률로 긍정 리뷰입니다.
#
# 788
# 88.67% 확률로 긍정 리뷰입니다.
#
# 789
# 52.43% 확률로 긍정 리뷰입니다.
#
# 790
# 84.51% 확률로 긍정 리뷰입니다.
#
# 791
# 93.85% 확률로 긍정 리뷰입니다.
#
# 792
# 61.65% 확률로 부정 리뷰입니다.
#
# 793
# 95.00% 확률로 긍정 리뷰입니다.
#
# 794
# 96.43% 확률로 긍정 리뷰입니다.
#
# 795
# 74.51% 확률로 부정 리뷰입니다.
#
# 796
# 95.05% 확률로 긍정 리뷰입니다.
#
# 797
# 57.59% 확률로 긍정 리뷰입니다.
#
# 798
# 76.13% 확률로 긍정 리뷰입니다.
#
# 799
# 89.65% 확률로 긍정 리뷰입니다.
#
# 800
# 98.87% 확률로 긍정 리뷰입니다.
#
# 801
# 99.02% 확률로 긍정 리뷰입니다.
#
# 802
# 79.38% 확률로 긍정 리뷰입니다.
#
# 803
# 95.00% 확률로 긍정 리뷰입니다.
#
# 804
# 77.55% 확률로 부정 리뷰입니다.
#
# 805
# 98.51% 확률로 긍정 리뷰입니다.
#
# 806
# 71.69% 확률로 긍정 리뷰입니다.
#
# 807
# 72.88% 확률로 부정 리뷰입니다.
#
# 808
# 91.98% 확률로 긍정 리뷰입니다.
#
# 809
# 70.61% 확률로 긍정 리뷰입니다.
#
# 810
# 95.56% 확률로 긍정 리뷰입니다.
#
# 811
# 77.62% 확률로 긍정 리뷰입니다.
#
# 812
# 96.51% 확률로 긍정 리뷰입니다.
#
# 813
# 94.91% 확률로 긍정 리뷰입니다.
#
# 814
# 57.32% 확률로 긍정 리뷰입니다.
#
# 815
# 85.29% 확률로 긍정 리뷰입니다.
#
# 816
# 99.19% 확률로 긍정 리뷰입니다.
#
# 817
# 97.73% 확률로 긍정 리뷰입니다.
#
# 818
# 98.26% 확률로 긍정 리뷰입니다.
#
# 819
# 99.24% 확률로 긍정 리뷰입니다.
#
# 820
# 53.42% 확률로 부정 리뷰입니다.
#
# 821
# 61.54% 확률로 긍정 리뷰입니다.
#
# 822
# 52.12% 확률로 부정 리뷰입니다.
#
# 823
# 97.19% 확률로 긍정 리뷰입니다.
#
# 824
# 71.66% 확률로 부정 리뷰입니다.
#
# 825
# 98.80% 확률로 긍정 리뷰입니다.
#
# 826
# 87.51% 확률로 긍정 리뷰입니다.
#
# 827
# 99.14% 확률로 긍정 리뷰입니다.
#
# 828
# 88.82% 확률로 긍정 리뷰입니다.
#
# 829
# 98.82% 확률로 긍정 리뷰입니다.
#
# 830
# 68.41% 확률로 긍정 리뷰입니다.
#
# 831
# 74.12% 확률로 부정 리뷰입니다.
#
# 832
# 85.90% 확률로 긍정 리뷰입니다.
#
# 833
# 93.52% 확률로 긍정 리뷰입니다.
#
# 834
# 98.35% 확률로 긍정 리뷰입니다.
#
# 835
# 90.86% 확률로 긍정 리뷰입니다.
#
# 836
# 87.27% 확률로 긍정 리뷰입니다.
#
# 837
# 96.16% 확률로 긍정 리뷰입니다.
#
# 838
# 96.09% 확률로 긍정 리뷰입니다.
#
# 839
# 95.73% 확률로 긍정 리뷰입니다.
#
# 840
# 99.63% 확률로 긍정 리뷰입니다.
#
# 841
# 59.12% 확률로 긍정 리뷰입니다.
#
# 842
# 96.52% 확률로 긍정 리뷰입니다.
#
# 843
# 63.19% 확률로 부정 리뷰입니다.
#
# 844
# 59.13% 확률로 부정 리뷰입니다.
#
# 845
# 98.53% 확률로 긍정 리뷰입니다.
#
# 846
# 87.33% 확률로 긍정 리뷰입니다.
#
# 847
# 60.05% 확률로 긍정 리뷰입니다.
#
# 848
# 88.87% 확률로 긍정 리뷰입니다.
#
# 849
# 98.45% 확률로 긍정 리뷰입니다.
#
# 850
# 99.52% 확률로 긍정 리뷰입니다.
#
# 851
# 84.76% 확률로 긍정 리뷰입니다.
#
# 852
# 98.46% 확률로 긍정 리뷰입니다.
#
# 853
# 77.36% 확률로 긍정 리뷰입니다.
#
# 854
# 95.34% 확률로 긍정 리뷰입니다.
#
# 855
# 97.75% 확률로 긍정 리뷰입니다.
#
# 856
# 91.61% 확률로 긍정 리뷰입니다.
#
# 857
# 75.91% 확률로 긍정 리뷰입니다.
#
# 858
# 93.55% 확률로 긍정 리뷰입니다.
#
# 859
# 93.26% 확률로 긍정 리뷰입니다.
#
# 860
# 97.51% 확률로 긍정 리뷰입니다.
#
# 861
# 97.35% 확률로 긍정 리뷰입니다.
#
# 862
# 95.61% 확률로 긍정 리뷰입니다.
#
# 863
# 98.09% 확률로 긍정 리뷰입니다.
#
# 864
# 97.17% 확률로 긍정 리뷰입니다.
#
# 865
# 96.38% 확률로 긍정 리뷰입니다.
#
# 866
# 90.35% 확률로 긍정 리뷰입니다.
#
# 867
# 99.28% 확률로 긍정 리뷰입니다.
#
# 868
# 75.06% 확률로 긍정 리뷰입니다.
#
# 869
# 58.60% 확률로 부정 리뷰입니다.
#
# 870
# 78.99% 확률로 긍정 리뷰입니다.
#
# 871
# 83.56% 확률로 긍정 리뷰입니다.
#
# 872
# 96.01% 확률로 긍정 리뷰입니다.
#
# 873
# 76.67% 확률로 부정 리뷰입니다.
#
# 874
# 91.02% 확률로 긍정 리뷰입니다.
#
# 875
# 81.25% 확률로 긍정 리뷰입니다.
#
# 876
# 98.80% 확률로 긍정 리뷰입니다.
#
# 877
# 94.10% 확률로 긍정 리뷰입니다.
#
# 878
# 97.03% 확률로 긍정 리뷰입니다.
#
# 879
# 92.00% 확률로 긍정 리뷰입니다.
#
# 880
# 98.35% 확률로 긍정 리뷰입니다.
#
# 881
# 76.26% 확률로 부정 리뷰입니다.
#
# 882
# 65.92% 확률로 부정 리뷰입니다.
#
# 883
# 89.99% 확률로 긍정 리뷰입니다.
#
# 884
# 97.82% 확률로 긍정 리뷰입니다.
#
# 885
# 98.59% 확률로 긍정 리뷰입니다.
#
# 886
# 94.19% 확률로 긍정 리뷰입니다.
#
# 887
# 98.55% 확률로 긍정 리뷰입니다.
#
# 888
# 97.79% 확률로 긍정 리뷰입니다.
#
# 889
# 97.72% 확률로 긍정 리뷰입니다.
#
# 890
# 97.00% 확률로 긍정 리뷰입니다.
#
# 891
# 97.77% 확률로 긍정 리뷰입니다.
#
# 892
# 90.38% 확률로 긍정 리뷰입니다.
#
# 893
# 98.07% 확률로 긍정 리뷰입니다.
#
# 894
# 98.96% 확률로 긍정 리뷰입니다.
#
# 895
# 95.93% 확률로 긍정 리뷰입니다.
#
# 896
# 97.43% 확률로 긍정 리뷰입니다.
#
# 897
# 91.88% 확률로 긍정 리뷰입니다.
#
# 898
# 92.29% 확률로 긍정 리뷰입니다.
#
# 899
# 67.32% 확률로 부정 리뷰입니다.
#
# 900
# 82.17% 확률로 긍정 리뷰입니다.
#
# 901
# 93.82% 확률로 긍정 리뷰입니다.
#
# 902
# 92.46% 확률로 긍정 리뷰입니다.
#
# 903
# 70.38% 확률로 긍정 리뷰입니다.
#
# 904
# 85.27% 확률로 긍정 리뷰입니다.
#
# 905
# 99.04% 확률로 긍정 리뷰입니다.
#
# 906
# 97.18% 확률로 긍정 리뷰입니다.
#
# 907
# 89.61% 확률로 긍정 리뷰입니다.
#
# 908
# 98.24% 확률로 긍정 리뷰입니다.
#
# 909
# 98.62% 확률로 긍정 리뷰입니다.
#
# 910
# 95.17% 확률로 긍정 리뷰입니다.
#
# 911
# 98.66% 확률로 긍정 리뷰입니다.
#
# 912
# 98.79% 확률로 긍정 리뷰입니다.
#
# 913
# 90.50% 확률로 긍정 리뷰입니다.
#
# 914
# 98.68% 확률로 긍정 리뷰입니다.
#
# 915
# 95.66% 확률로 긍정 리뷰입니다.
#
# 916
# 95.35% 확률로 긍정 리뷰입니다.
#
# 917
# 98.72% 확률로 긍정 리뷰입니다.
#
# 918
# 99.49% 확률로 긍정 리뷰입니다.
#
# 919
# 91.93% 확률로 긍정 리뷰입니다.
#
# 920
# 95.80% 확률로 긍정 리뷰입니다.
#
# 921
# 99.41% 확률로 긍정 리뷰입니다.
#
# 922
# 99.78% 확률로 긍정 리뷰입니다.
#
# 923
# 98.41% 확률로 긍정 리뷰입니다.
#
# 924
# 66.83% 확률로 부정 리뷰입니다.
#
# 925
# 99.34% 확률로 긍정 리뷰입니다.
#
# 926
# 97.20% 확률로 긍정 리뷰입니다.
#
# 927
# 95.33% 확률로 긍정 리뷰입니다.
#
# 928
# 94.70% 확률로 긍정 리뷰입니다.
#
# 929
# 99.61% 확률로 긍정 리뷰입니다.
#
# 930
# 90.56% 확률로 긍정 리뷰입니다.
#
# 931
# 94.87% 확률로 긍정 리뷰입니다.
#
# 932
# 96.47% 확률로 긍정 리뷰입니다.
#
# 933
# 98.91% 확률로 긍정 리뷰입니다.
#
# 934
# 85.00% 확률로 부정 리뷰입니다.
#
# 935
# 92.52% 확률로 긍정 리뷰입니다.
#
# 936
# 97.35% 확률로 긍정 리뷰입니다.
#
# 937
# 88.81% 확률로 긍정 리뷰입니다.
#
# 938
# 97.39% 확률로 긍정 리뷰입니다.
#
# 939
# 67.47% 확률로 긍정 리뷰입니다.
#
# 940
# 75.50% 확률로 긍정 리뷰입니다.
#
# 941
# 98.38% 확률로 긍정 리뷰입니다.
#
# 942
# 99.30% 확률로 긍정 리뷰입니다.
#
# 943
# 97.10% 확률로 긍정 리뷰입니다.
#
# 944
# 98.46% 확률로 긍정 리뷰입니다.
#
# 945
# 85.22% 확률로 긍정 리뷰입니다.
#
# 946
# 99.18% 확률로 긍정 리뷰입니다.
#
# 947
# 96.06% 확률로 긍정 리뷰입니다.
#
# 948
# 79.76% 확률로 부정 리뷰입니다.
#
# 949
# 99.53% 확률로 긍정 리뷰입니다.
#
# 950
# 93.88% 확률로 긍정 리뷰입니다.
#
# 951
# 69.65% 확률로 긍정 리뷰입니다.
#
# 952
# 96.09% 확률로 긍정 리뷰입니다.
#
# 953
# 93.24% 확률로 긍정 리뷰입니다.
#
# 954
# 58.99% 확률로 부정 리뷰입니다.
#
# 955
# 98.95% 확률로 긍정 리뷰입니다.
#
# 956
# 82.24% 확률로 긍정 리뷰입니다.
#
# 957
# 98.21% 확률로 긍정 리뷰입니다.
#
# 958
# 96.84% 확률로 긍정 리뷰입니다.
#
# 959
# 93.48% 확률로 긍정 리뷰입니다.
#
# 960
# 87.90% 확률로 긍정 리뷰입니다.
#
# 961
# 97.96% 확률로 긍정 리뷰입니다.
#
# 962
# 98.61% 확률로 긍정 리뷰입니다.
#
# 963
# 63.45% 확률로 부정 리뷰입니다.
#
# 964
# 60.59% 확률로 부정 리뷰입니다.
#
# 965
# 95.31% 확률로 긍정 리뷰입니다.
#
# 966
# 98.91% 확률로 긍정 리뷰입니다.
#
# 967
# 83.20% 확률로 긍정 리뷰입니다.
#
# 968
# 96.33% 확률로 긍정 리뷰입니다.
#
# 969
# 71.73% 확률로 긍정 리뷰입니다.
#
# 970
# 99.62% 확률로 긍정 리뷰입니다.
#
# 971
# 94.60% 확률로 긍정 리뷰입니다.
#
# 972
# 99.22% 확률로 긍정 리뷰입니다.
#
# 973
# 98.71% 확률로 긍정 리뷰입니다.
#
# 974
# 93.51% 확률로 긍정 리뷰입니다.
#
# 975
# 96.29% 확률로 긍정 리뷰입니다.
#
# 976
# 77.66% 확률로 긍정 리뷰입니다.
#
# 977
# 99.41% 확률로 긍정 리뷰입니다.
#
# 978
# 54.91% 확률로 긍정 리뷰입니다.
#
# 979
# 92.41% 확률로 긍정 리뷰입니다.
#
# 980
# 74.44% 확률로 긍정 리뷰입니다.
#
# 981
# 90.87% 확률로 긍정 리뷰입니다.
#
# 982
# 59.32% 확률로 긍정 리뷰입니다.
#
# 983
# 98.23% 확률로 긍정 리뷰입니다.
#
# 984
# 99.22% 확률로 긍정 리뷰입니다.
#
# 985
# 98.86% 확률로 긍정 리뷰입니다.
#
# 986
# 51.00% 확률로 부정 리뷰입니다.
#
# 987
# 98.59% 확률로 긍정 리뷰입니다.
#
# 988
# 98.03% 확률로 긍정 리뷰입니다.
#
# 989
# 97.58% 확률로 긍정 리뷰입니다.
#
# 990
# 56.97% 확률로 긍정 리뷰입니다.
#
# 991
# 99.38% 확률로 긍정 리뷰입니다.
#
# 992
# 97.38% 확률로 긍정 리뷰입니다.
#
# 993
# 99.35% 확률로 긍정 리뷰입니다.
#
# 994
# 92.49% 확률로 긍정 리뷰입니다.
#
# 995
# 98.38% 확률로 긍정 리뷰입니다.
#
# 996
# 83.79% 확률로 긍정 리뷰입니다.
#
# 997
# 84.61% 확률로 긍정 리뷰입니다.
#
# 998
# 63.94% 확률로 긍정 리뷰입니다.
#
# 999
# 98.32% 확률로 긍정 리뷰입니다.
#
# 1000
# 93.32% 확률로 긍정 리뷰입니다.
#
# 1001
# 98.78% 확률로 긍정 리뷰입니다.
#
# 1002
# 99.22% 확률로 긍정 리뷰입니다.
#
# 1003
# 98.11% 확률로 긍정 리뷰입니다.
#
# 1004
# 98.83% 확률로 긍정 리뷰입니다.
#
# 1005
# 94.05% 확률로 긍정 리뷰입니다.
#
# 1006
# 65.37% 확률로 긍정 리뷰입니다.
#
# 1007
# 98.85% 확률로 긍정 리뷰입니다.
#
# 1008
# 97.37% 확률로 긍정 리뷰입니다.
#
# 1009
# 99.71% 확률로 긍정 리뷰입니다.
#
# 1010
# 82.59% 확률로 긍정 리뷰입니다.
#
# 1011
# 99.82% 확률로 긍정 리뷰입니다.
#
# 1012
# 93.53% 확률로 긍정 리뷰입니다.
#
# 1013
# 98.98% 확률로 긍정 리뷰입니다.
#
# 1014
# 83.78% 확률로 긍정 리뷰입니다.
#
# 1015
# 95.05% 확률로 긍정 리뷰입니다.
#
# 1016
# 88.71% 확률로 긍정 리뷰입니다.
#
# 1017
# 98.77% 확률로 긍정 리뷰입니다.
#
# 1018
# 94.07% 확률로 긍정 리뷰입니다.
#
# 1019
# 66.19% 확률로 부정 리뷰입니다.
#
# 1020
# 96.16% 확률로 긍정 리뷰입니다.
#
# 1021
# 98.82% 확률로 긍정 리뷰입니다.
#
# 1022
# 93.53% 확률로 긍정 리뷰입니다.
#
# 1023
# 91.24% 확률로 긍정 리뷰입니다.
#
# 1024
# 65.12% 확률로 긍정 리뷰입니다.
#
# 1025
# 92.19% 확률로 긍정 리뷰입니다.
#
# 1026
# 98.85% 확률로 긍정 리뷰입니다.
#
# 1027
# 94.35% 확률로 긍정 리뷰입니다.
#
# 1028
# 98.49% 확률로 긍정 리뷰입니다.
#
# 1029
# 95.75% 확률로 긍정 리뷰입니다.
#
# 1030
# 98.78% 확률로 긍정 리뷰입니다.
#
# 1031
# 93.51% 확률로 긍정 리뷰입니다.
#
# 1032
# 93.28% 확률로 긍정 리뷰입니다.
#
# 1033
# 98.93% 확률로 긍정 리뷰입니다.
#
# 1034
# 94.64% 확률로 긍정 리뷰입니다.
#
# 1035
# 82.20% 확률로 긍정 리뷰입니다.
#
# 1036
# 98.97% 확률로 긍정 리뷰입니다.
#
# 1037
# 98.03% 확률로 긍정 리뷰입니다.
#
# 1038
# 91.00% 확률로 긍정 리뷰입니다.
#
# 1039
# 98.82% 확률로 긍정 리뷰입니다.
#
# 1040
# 78.94% 확률로 긍정 리뷰입니다.
#
# 1041
# 99.02% 확률로 긍정 리뷰입니다.
#
# 1042
# 96.59% 확률로 긍정 리뷰입니다.
#
# 1043
# 98.16% 확률로 긍정 리뷰입니다.
#
# 1044
# 85.13% 확률로 긍정 리뷰입니다.
#
# 1045
# 86.08% 확률로 부정 리뷰입니다.
#
# 1046
# 90.28% 확률로 긍정 리뷰입니다.
#
# 1047
# 97.86% 확률로 긍정 리뷰입니다.
#
# 1048
# 54.52% 확률로 긍정 리뷰입니다.
#
# 1049
# 59.94% 확률로 긍정 리뷰입니다.
#
# 1050
# 80.27% 확률로 긍정 리뷰입니다.
#
# 1051
# 99.36% 확률로 긍정 리뷰입니다.
#
# 1052
# 98.70% 확률로 긍정 리뷰입니다.
#
# 1053
# 93.65% 확률로 긍정 리뷰입니다.
#
# 1054
# 99.57% 확률로 긍정 리뷰입니다.
#
# 1055
# 99.84% 확률로 긍정 리뷰입니다.
#
# 1056
# 69.96% 확률로 부정 리뷰입니다.
#
# 1057
# 80.09% 확률로 부정 리뷰입니다.
#
# 1058
# 97.87% 확률로 긍정 리뷰입니다.
#
# 1059
# 98.99% 확률로 긍정 리뷰입니다.
#
# 1060
# 68.76% 확률로 긍정 리뷰입니다.
#
# 1061
# 98.13% 확률로 긍정 리뷰입니다.
#
# 1062
# 54.73% 확률로 부정 리뷰입니다.
#
# 1063
# 97.58% 확률로 긍정 리뷰입니다.
#
# 1064
# 54.21% 확률로 긍정 리뷰입니다.
#
# 1065
# 55.94% 확률로 긍정 리뷰입니다.
#
# 1066
# 98.62% 확률로 긍정 리뷰입니다.
#
# 1067
# 97.78% 확률로 긍정 리뷰입니다.
#
# 1068
# 97.29% 확률로 긍정 리뷰입니다.
#
# 1069
# 56.25% 확률로 긍정 리뷰입니다.
#
# 1070
# 90.57% 확률로 긍정 리뷰입니다.
#
# 1071
# 65.89% 확률로 긍정 리뷰입니다.
#
# 1072
# 81.80% 확률로 긍정 리뷰입니다.
#
# 1073
# 91.92% 확률로 긍정 리뷰입니다.
#
# 1074
# 98.70% 확률로 긍정 리뷰입니다.
#
# 1075
# 96.56% 확률로 긍정 리뷰입니다.
#
# 1076
# 96.26% 확률로 긍정 리뷰입니다.
#
# 1077
# 70.54% 확률로 긍정 리뷰입니다.
#
# 1078
# 92.91% 확률로 긍정 리뷰입니다.
#
# 1079
# 98.27% 확률로 긍정 리뷰입니다.
#
# 1080
# 99.10% 확률로 긍정 리뷰입니다.
#
# 1081
# 95.01% 확률로 긍정 리뷰입니다.
#
# 1082
# 97.56% 확률로 긍정 리뷰입니다.
#
# 1083
# 96.90% 확률로 긍정 리뷰입니다.
#
# 1084
# 97.52% 확률로 긍정 리뷰입니다.
#
# 1085
# 98.79% 확률로 긍정 리뷰입니다.
#
# 1086
# 95.80% 확률로 부정 리뷰입니다.
#
# 1087
# 55.62% 확률로 부정 리뷰입니다.
#
# 1088
# 97.78% 확률로 긍정 리뷰입니다.
#
# 1089
# 95.96% 확률로 긍정 리뷰입니다.
#
# 1090
# 97.99% 확률로 긍정 리뷰입니다.
#
# 1091
# 92.08% 확률로 긍정 리뷰입니다.
#
# 1092
# 51.38% 확률로 긍정 리뷰입니다.
#
# 1093
# 82.65% 확률로 긍정 리뷰입니다.
#
# 1094
# 99.34% 확률로 긍정 리뷰입니다.
#
# 1095
# 96.82% 확률로 긍정 리뷰입니다.
#
# 1096
# 93.85% 확률로 긍정 리뷰입니다.
#
# 1097
# 69.58% 확률로 긍정 리뷰입니다.
#
# 1098
# 97.46% 확률로 부정 리뷰입니다.
#
# 1099
# 73.76% 확률로 부정 리뷰입니다.
#
# 1100
# 59.99% 확률로 긍정 리뷰입니다.
#
# 1101
# 73.80% 확률로 긍정 리뷰입니다.
#
# 1102
# 97.46% 확률로 긍정 리뷰입니다.
#
# 1103
# 77.80% 확률로 긍정 리뷰입니다.
#
# 1104
# 66.88% 확률로 긍정 리뷰입니다.
#
# 1105
# 69.06% 확률로 긍정 리뷰입니다.
#
# 1106
# 60.34% 확률로 부정 리뷰입니다.
#
# 1107
# 85.68% 확률로 긍정 리뷰입니다.
#
# 1108
# 95.54% 확률로 긍정 리뷰입니다.
#
# 1109
# 86.43% 확률로 긍정 리뷰입니다.
#
# 1110
# 58.01% 확률로 긍정 리뷰입니다.
#
# 1111
# 98.69% 확률로 긍정 리뷰입니다.
#
# 1112
# 98.61% 확률로 긍정 리뷰입니다.
#
# 1113
# 79.73% 확률로 긍정 리뷰입니다.
#
# 1114
# 95.57% 확률로 긍정 리뷰입니다.
#
# 1115
# 93.93% 확률로 긍정 리뷰입니다.
#
# 1116
# 80.25% 확률로 부정 리뷰입니다.
#
# 1117
# 68.39% 확률로 긍정 리뷰입니다.
#
# 1118
# 97.44% 확률로 긍정 리뷰입니다.
#
# 1119
# 94.66% 확률로 긍정 리뷰입니다.
#
# 1120
# 52.63% 확률로 긍정 리뷰입니다.
#
# 1121
# 87.65% 확률로 긍정 리뷰입니다.
#
# 1122
# 97.89% 확률로 긍정 리뷰입니다.
#
# 1123
# 73.96% 확률로 긍정 리뷰입니다.
#
# 1124
# 89.66% 확률로 긍정 리뷰입니다.
#
# 1125
# 96.27% 확률로 긍정 리뷰입니다.
#
# 1126
# 97.76% 확률로 긍정 리뷰입니다.
#
# 1127
# 97.68% 확률로 긍정 리뷰입니다.
#
# 1128
# 84.03% 확률로 긍정 리뷰입니다.
#
# 1129
# 99.45% 확률로 긍정 리뷰입니다.
#
# 1130
# 61.36% 확률로 부정 리뷰입니다.
#
# 1131
# 93.70% 확률로 긍정 리뷰입니다.
#
# 1132
# 59.39% 확률로 긍정 리뷰입니다.
#
# 1133
# 97.57% 확률로 긍정 리뷰입니다.
#
# 1134
# 74.39% 확률로 긍정 리뷰입니다.
#
# 1135
# 96.98% 확률로 긍정 리뷰입니다.
#
# 1136
# 98.53% 확률로 긍정 리뷰입니다.
#
# 1137
# 74.70% 확률로 긍정 리뷰입니다.
#
# 1138
# 69.39% 확률로 긍정 리뷰입니다.
#
# 1139
# 98.29% 확률로 긍정 리뷰입니다.
#
# 1140
# 97.52% 확률로 긍정 리뷰입니다.
#
# 1141
# 96.26% 확률로 긍정 리뷰입니다.
#
# 1142
# 95.34% 확률로 긍정 리뷰입니다.
#
# 1143
# 99.66% 확률로 긍정 리뷰입니다.
#
# 1144
# 96.99% 확률로 긍정 리뷰입니다.
#
# 1145
# 98.73% 확률로 긍정 리뷰입니다.
#
# 1146
# 95.10% 확률로 긍정 리뷰입니다.
#
# 1147
# 96.77% 확률로 긍정 리뷰입니다.
#
# 1148
# 96.19% 확률로 긍정 리뷰입니다.
#
# 1149
# 72.07% 확률로 긍정 리뷰입니다.
#
# 1150
# 96.31% 확률로 긍정 리뷰입니다.
#
# 1151
# 53.77% 확률로 긍정 리뷰입니다.
#
# 1152
# 64.54% 확률로 긍정 리뷰입니다.
#
# 1153
# 98.05% 확률로 긍정 리뷰입니다.
#
# 1154
# 99.43% 확률로 긍정 리뷰입니다.
#
# 1155
# 97.01% 확률로 긍정 리뷰입니다.
#
# 1156
# 85.97% 확률로 부정 리뷰입니다.
#
# 1157
# 95.72% 확률로 긍정 리뷰입니다.
#
# 1158
# 98.15% 확률로 긍정 리뷰입니다.
#
# 1159
# 98.31% 확률로 긍정 리뷰입니다.
#
# 1160
# 75.57% 확률로 긍정 리뷰입니다.
#
# 1161
# 98.91% 확률로 긍정 리뷰입니다.
#
# 1162
# 82.53% 확률로 부정 리뷰입니다.
#
# 1163
# 64.30% 확률로 긍정 리뷰입니다.
#
# 1164
# 73.30% 확률로 긍정 리뷰입니다.
#
# 1165
# 62.95% 확률로 긍정 리뷰입니다.
#
# 1166
# 98.38% 확률로 긍정 리뷰입니다.
#
# 1167
# 90.05% 확률로 긍정 리뷰입니다.
#
# 1168
# 98.70% 확률로 긍정 리뷰입니다.
#
# 1169
# 90.97% 확률로 부정 리뷰입니다.
#
# 1170
# 99.64% 확률로 긍정 리뷰입니다.
#
# 1171
# 81.90% 확률로 부정 리뷰입니다.
#
# 1172
# 61.69% 확률로 긍정 리뷰입니다.
#
# 1173
# 98.35% 확률로 긍정 리뷰입니다.
#
# 1174
# 98.81% 확률로 긍정 리뷰입니다.
#
# 1175
# 94.54% 확률로 긍정 리뷰입니다.
#
# 1176
# 96.24% 확률로 긍정 리뷰입니다.
#
# 1177
# 97.16% 확률로 긍정 리뷰입니다.
#
# 1178
# 94.59% 확률로 긍정 리뷰입니다.
#
# 1179
# 96.86% 확률로 긍정 리뷰입니다.
#
# 1180
# 80.61% 확률로 긍정 리뷰입니다.
#
# 1181
# 83.95% 확률로 긍정 리뷰입니다.
#
# 1182
# 93.50% 확률로 긍정 리뷰입니다.
#
# 1183
# 90.16% 확률로 긍정 리뷰입니다.
#
# 1184
# 84.13% 확률로 부정 리뷰입니다.
#
# 1185
# 98.24% 확률로 긍정 리뷰입니다.
#
# 1186
# 98.84% 확률로 긍정 리뷰입니다.
#
# 1187
# 94.21% 확률로 긍정 리뷰입니다.
#
# 1188
# 97.40% 확률로 긍정 리뷰입니다.
#
# 1189
# 78.81% 확률로 부정 리뷰입니다.
#
# 1190
# 97.89% 확률로 긍정 리뷰입니다.
#
# 1191
# 70.66% 확률로 긍정 리뷰입니다.
#
# 1192
# 55.62% 확률로 부정 리뷰입니다.
#
# 1193
# 95.53% 확률로 긍정 리뷰입니다.
#
# 1194
# 97.34% 확률로 긍정 리뷰입니다.
#
# 1195
# 99.26% 확률로 긍정 리뷰입니다.
#
# 1196
# 96.54% 확률로 긍정 리뷰입니다.
#
# 1197
# 87.62% 확률로 긍정 리뷰입니다.
#
# 1198
# 97.63% 확률로 긍정 리뷰입니다.
#
# 1199
# 96.16% 확률로 긍정 리뷰입니다.
#
# 1200
# 50.22% 확률로 부정 리뷰입니다.
#
# 1201
# 79.29% 확률로 긍정 리뷰입니다.
#
# 1202
# 74.96% 확률로 긍정 리뷰입니다.
#
# 1203
# 51.94% 확률로 부정 리뷰입니다.
#
# 1204
# 59.77% 확률로 긍정 리뷰입니다.
#
# 1205
# 59.23% 확률로 긍정 리뷰입니다.
#
# 1206
# 86.61% 확률로 긍정 리뷰입니다.
#
# 1207
# 85.47% 확률로 부정 리뷰입니다.
#
# 1208
# 89.47% 확률로 긍정 리뷰입니다.
#
# 1209
# 98.24% 확률로 긍정 리뷰입니다.
#
# 1210
# 81.25% 확률로 긍정 리뷰입니다.
#
# 1211
# 86.98% 확률로 긍정 리뷰입니다.
#
# 1212
# 92.96% 확률로 긍정 리뷰입니다.
#
# 1213
# 94.68% 확률로 긍정 리뷰입니다.
#
# 1214
# 86.51% 확률로 긍정 리뷰입니다.
#
# 1215
# 82.20% 확률로 부정 리뷰입니다.
#
# 1216
# 99.51% 확률로 긍정 리뷰입니다.
#
# 1217
# 98.90% 확률로 긍정 리뷰입니다.
#
# 1218
# 82.39% 확률로 부정 리뷰입니다.
#
# 1219
# 63.48% 확률로 긍정 리뷰입니다.
#
# 1220
# 80.54% 확률로 부정 리뷰입니다.
#
# 1221
# 94.05% 확률로 긍정 리뷰입니다.
#
# 1222
# 98.53% 확률로 긍정 리뷰입니다.
#
# 1223
# 95.85% 확률로 긍정 리뷰입니다.
#
# 1224
# 98.99% 확률로 긍정 리뷰입니다.
#
# 1225
# 66.29% 확률로 긍정 리뷰입니다.
#
# 1226
# 58.81% 확률로 긍정 리뷰입니다.
#
# 1227
# 71.63% 확률로 긍정 리뷰입니다.
#
# 1228
# 73.78% 확률로 부정 리뷰입니다.
#
# 1229
# 62.84% 확률로 긍정 리뷰입니다.
#
# 1230
# 83.75% 확률로 긍정 리뷰입니다.
#
# 1231
# 93.67% 확률로 긍정 리뷰입니다.
#
# 1232
# 98.26% 확률로 긍정 리뷰입니다.
#
# 1233
# 70.75% 확률로 부정 리뷰입니다.
#
# 1234
# 63.71% 확률로 긍정 리뷰입니다.
#
# 1235
# 94.22% 확률로 긍정 리뷰입니다.
#
# 1236
# 58.71% 확률로 부정 리뷰입니다.
#
# 1237
# 96.26% 확률로 긍정 리뷰입니다.
#
# 1238
# 99.43% 확률로 긍정 리뷰입니다.
#
# 1239
# 52.52% 확률로 긍정 리뷰입니다.
#
# 1240
# 55.00% 확률로 긍정 리뷰입니다.
#
# 1241
# 57.39% 확률로 긍정 리뷰입니다.
#
# 1242
# 72.52% 확률로 부정 리뷰입니다.
#
# 1243
# 97.04% 확률로 긍정 리뷰입니다.
#
# 1244
# 98.77% 확률로 긍정 리뷰입니다.
#
# 1245
# 96.38% 확률로 긍정 리뷰입니다.
#
# 1246
# 99.39% 확률로 긍정 리뷰입니다.
#
# 1247
# 80.49% 확률로 긍정 리뷰입니다.
#
# 1248
# 98.23% 확률로 긍정 리뷰입니다.
#
# 1249
# 98.84% 확률로 긍정 리뷰입니다.
#
# 1250
# 98.44% 확률로 긍정 리뷰입니다.
#
# 1251
# 98.21% 확률로 긍정 리뷰입니다.
#
# 1252
# 70.34% 확률로 긍정 리뷰입니다.
#
# 1253
# 95.14% 확률로 긍정 리뷰입니다.
#
# 1254
# 98.62% 확률로 긍정 리뷰입니다.
#
# 1255
# 96.35% 확률로 긍정 리뷰입니다.
#
# 1256
# 51.71% 확률로 부정 리뷰입니다.
#
# 1257
# 91.08% 확률로 긍정 리뷰입니다.
#
# 1258
# 58.90% 확률로 부정 리뷰입니다.
#
# 1259
# 81.87% 확률로 긍정 리뷰입니다.
#
# 1260
# 93.72% 확률로 긍정 리뷰입니다.
#
# 1261
# 97.90% 확률로 긍정 리뷰입니다.
#
# 1262
# 59.94% 확률로 긍정 리뷰입니다.
#
# 1263
# 98.23% 확률로 긍정 리뷰입니다.
#
# 1264
# 98.13% 확률로 긍정 리뷰입니다.
#
# 1265
# 96.07% 확률로 긍정 리뷰입니다.
#
# 1266
# 79.05% 확률로 긍정 리뷰입니다.
#
# 1267
# 58.40% 확률로 긍정 리뷰입니다.
#
# 1268
# 99.10% 확률로 긍정 리뷰입니다.
#
# 1269
# 72.56% 확률로 부정 리뷰입니다.
#
# 1270
# 51.94% 확률로 부정 리뷰입니다.
#
# 1271
# 99.48% 확률로 긍정 리뷰입니다.
#
# 1272
# 99.18% 확률로 긍정 리뷰입니다.
#
# 1273
# 99.14% 확률로 긍정 리뷰입니다.
#
# 1274
# 98.30% 확률로 긍정 리뷰입니다.
#
# 1275
# 79.93% 확률로 긍정 리뷰입니다.
#
# 1276
# 95.03% 확률로 긍정 리뷰입니다.
#
# 1277
# 97.33% 확률로 긍정 리뷰입니다.
#
# 1278
# 90.84% 확률로 긍정 리뷰입니다.
#
# 1279
# 81.27% 확률로 긍정 리뷰입니다.
#
# 1280
# 89.88% 확률로 긍정 리뷰입니다.
#
# 1281
# 98.98% 확률로 긍정 리뷰입니다.
#
# 1282
# 98.16% 확률로 긍정 리뷰입니다.
#
# 1283
# 99.34% 확률로 긍정 리뷰입니다.
#
# 1284
# 93.87% 확률로 긍정 리뷰입니다.
#
# 1285
# 96.33% 확률로 긍정 리뷰입니다.
#
# 1286
# 98.80% 확률로 긍정 리뷰입니다.
#
# 1287
# 73.09% 확률로 긍정 리뷰입니다.
#
# 1288
# 95.50% 확률로 긍정 리뷰입니다.
#
# 1289
# 93.04% 확률로 긍정 리뷰입니다.
#
# 1290
# 96.97% 확률로 긍정 리뷰입니다.
#
# 1291
# 88.41% 확률로 긍정 리뷰입니다.
#
# 1292
# 87.16% 확률로 긍정 리뷰입니다.
#
# 1293
# 82.01% 확률로 긍정 리뷰입니다.
#
# 1294
# 97.63% 확률로 긍정 리뷰입니다.
#
# 1295
# 70.77% 확률로 긍정 리뷰입니다.
#
# 1296
# 97.97% 확률로 긍정 리뷰입니다.
#
# 1297
# 95.86% 확률로 긍정 리뷰입니다.
#
# 1298
# 91.97% 확률로 긍정 리뷰입니다.
#
# 1299
# 67.86% 확률로 긍정 리뷰입니다.
#
# 1300
# 98.83% 확률로 긍정 리뷰입니다.
#
# 1301
# 70.91% 확률로 긍정 리뷰입니다.
#
# 1302
# 77.85% 확률로 긍정 리뷰입니다.
#
# 1303
# 96.18% 확률로 긍정 리뷰입니다.
#
# 1304
# 98.28% 확률로 긍정 리뷰입니다.
#
# 1305
# 88.81% 확률로 부정 리뷰입니다.
#
# 1306
# 97.55% 확률로 긍정 리뷰입니다.
#
# 1307
# 97.28% 확률로 긍정 리뷰입니다.
#
# 1308
# 70.13% 확률로 긍정 리뷰입니다.
#
# 1309
# 80.37% 확률로 긍정 리뷰입니다.
#
# 1310
# 94.90% 확률로 긍정 리뷰입니다.
#
# 1311
# 63.03% 확률로 부정 리뷰입니다.
#
# 1312
# 94.22% 확률로 긍정 리뷰입니다.
#
# 1313
# 76.30% 확률로 긍정 리뷰입니다.
#
# 1314
# 91.66% 확률로 긍정 리뷰입니다.
#
# 1315
# 52.89% 확률로 긍정 리뷰입니다.
#
# 1316
# 92.70% 확률로 긍정 리뷰입니다.
#
# 1317
# 72.37% 확률로 부정 리뷰입니다.
#
# 1318
# 99.02% 확률로 긍정 리뷰입니다.
#
# 1319
# 97.51% 확률로 긍정 리뷰입니다.
#
# 1320
# 99.04% 확률로 긍정 리뷰입니다.
#
# 1321
# 97.00% 확률로 긍정 리뷰입니다.
#
# 1322
# 65.01% 확률로 부정 리뷰입니다.
#
# 1323
# 98.91% 확률로 긍정 리뷰입니다.
#
# 1324
# 96.71% 확률로 긍정 리뷰입니다.
#
# 1325
# 85.38% 확률로 긍정 리뷰입니다.
#
# 1326
# 98.49% 확률로 긍정 리뷰입니다.
#
# 1327
# 97.23% 확률로 긍정 리뷰입니다.
#
# 1328
# 93.85% 확률로 긍정 리뷰입니다.
#
# 1329
# 94.49% 확률로 긍정 리뷰입니다.
#
# 1330
# 99.14% 확률로 긍정 리뷰입니다.
#
# 1331
# 97.77% 확률로 긍정 리뷰입니다.
#
# 1332
# 99.26% 확률로 긍정 리뷰입니다.
#
# 1333
# 94.50% 확률로 긍정 리뷰입니다.
#
# 1334
# 60.65% 확률로 긍정 리뷰입니다.
#
# 1335
# 92.12% 확률로 긍정 리뷰입니다.
#
# 1336
# 82.11% 확률로 긍정 리뷰입니다.
#
# 1337
# 97.81% 확률로 긍정 리뷰입니다.
#
# 1338
# 95.57% 확률로 긍정 리뷰입니다.
#
# 1339
# 76.17% 확률로 긍정 리뷰입니다.
#
# 1340
# 52.26% 확률로 부정 리뷰입니다.
#
# 1341
# 98.26% 확률로 긍정 리뷰입니다.
#
# 1342
# 98.86% 확률로 긍정 리뷰입니다.
#
# 1343
# 88.15% 확률로 긍정 리뷰입니다.
#
# 1344
# 99.37% 확률로 긍정 리뷰입니다.
#
# 1345
# 98.74% 확률로 긍정 리뷰입니다.
#
# 1346
# 95.57% 확률로 긍정 리뷰입니다.
#
# 1347
# 50.58% 확률로 긍정 리뷰입니다.
#
# 1348
# 56.70% 확률로 긍정 리뷰입니다.
#
# 1349
# 71.71% 확률로 긍정 리뷰입니다.
#
# 1350
# 98.85% 확률로 긍정 리뷰입니다.
#
# 1351
# 97.69% 확률로 긍정 리뷰입니다.
#
# 1352
# 97.40% 확률로 긍정 리뷰입니다.
#
# 1353
# 82.03% 확률로 긍정 리뷰입니다.
#
# 1354
# 86.58% 확률로 긍정 리뷰입니다.
#
# 1355
# 58.36% 확률로 긍정 리뷰입니다.
#
# 1356
# 97.54% 확률로 긍정 리뷰입니다.
#
# 1357
# 96.58% 확률로 긍정 리뷰입니다.
#
# 1358
# 96.62% 확률로 긍정 리뷰입니다.
#
# 1359
# 87.77% 확률로 긍정 리뷰입니다.
#
# 1360
# 67.49% 확률로 부정 리뷰입니다.
#
# 1361
# 98.65% 확률로 긍정 리뷰입니다.
#
# 1362
# 98.21% 확률로 긍정 리뷰입니다.
#
# 1363
# 92.42% 확률로 긍정 리뷰입니다.
#
# 1364
# 90.74% 확률로 긍정 리뷰입니다.
#
# 1365
# 62.53% 확률로 긍정 리뷰입니다.
#
# 1366
# 62.42% 확률로 긍정 리뷰입니다.
#
# 1367
# 74.83% 확률로 긍정 리뷰입니다.
#
# 1368
# 87.75% 확률로 긍정 리뷰입니다.
#
# 1369
# 98.59% 확률로 긍정 리뷰입니다.
#
# 1370
# 83.76% 확률로 긍정 리뷰입니다.
#
# 1371
# 91.08% 확률로 긍정 리뷰입니다.
#
# 1372
# 98.71% 확률로 긍정 리뷰입니다.
#
# 1373
# 83.71% 확률로 긍정 리뷰입니다.
#
# 1374
# 94.68% 확률로 긍정 리뷰입니다.
#
# 1375
# 97.92% 확률로 긍정 리뷰입니다.
#
# 1376
# 54.63% 확률로 긍정 리뷰입니다.
#
# 1377
# 95.79% 확률로 긍정 리뷰입니다.
#
# 1378
# 75.75% 확률로 긍정 리뷰입니다.
#
# 1379
# 65.39% 확률로 긍정 리뷰입니다.
#
# 1380
# 98.41% 확률로 긍정 리뷰입니다.
#
# 1381
# 81.32% 확률로 긍정 리뷰입니다.
#
# 1382
# 99.38% 확률로 긍정 리뷰입니다.
#
# 1383
# 98.30% 확률로 긍정 리뷰입니다.
#
# 1384
# 99.21% 확률로 긍정 리뷰입니다.
#
# 1385
# 64.38% 확률로 긍정 리뷰입니다.
#
# 1386
# 76.44% 확률로 긍정 리뷰입니다.
#
# 1387
# 85.45% 확률로 긍정 리뷰입니다.
#
# 1388
# 59.50% 확률로 부정 리뷰입니다.
#
# 1389
# 94.58% 확률로 긍정 리뷰입니다.
#
# 1390
# 95.30% 확률로 긍정 리뷰입니다.
#
# 1391
# 68.76% 확률로 긍정 리뷰입니다.
#
# 1392
# 84.53% 확률로 긍정 리뷰입니다.
#
# 1393
# 97.40% 확률로 긍정 리뷰입니다.
#
# 1394
# 98.84% 확률로 긍정 리뷰입니다.
#
# 1395
# 71.70% 확률로 긍정 리뷰입니다.
#
# 1396
# 98.65% 확률로 긍정 리뷰입니다.
#
# 1397
# 85.38% 확률로 긍정 리뷰입니다.
#
# 1398
# 72.98% 확률로 긍정 리뷰입니다.
#
# 1399
# 96.23% 확률로 긍정 리뷰입니다.
#
# 1400
# 91.95% 확률로 긍정 리뷰입니다.
#
# 1401
# 85.81% 확률로 긍정 리뷰입니다.
#
# 1402
# 94.03% 확률로 긍정 리뷰입니다.
#
# 1403
# 83.90% 확률로 긍정 리뷰입니다.
#
# 1404
# 96.46% 확률로 긍정 리뷰입니다.
#
# 1405
# 98.58% 확률로 긍정 리뷰입니다.
#
# 1406
# 95.11% 확률로 긍정 리뷰입니다.
#
# 1407
# 71.70% 확률로 긍정 리뷰입니다.
#
# 1408
# 90.00% 확률로 긍정 리뷰입니다.
#
# 1409
# 96.73% 확률로 긍정 리뷰입니다.
#
# 1410
# 96.52% 확률로 긍정 리뷰입니다.
#
# 1411
# 95.87% 확률로 긍정 리뷰입니다.
#
# 1412
# 97.40% 확률로 긍정 리뷰입니다.
#
# 1413
# 95.76% 확률로 긍정 리뷰입니다.
#
# 1414
# 94.31% 확률로 긍정 리뷰입니다.
#
# 1415
# 52.76% 확률로 부정 리뷰입니다.
#
# 1416
# 98.87% 확률로 긍정 리뷰입니다.
#
# 1417
# 58.43% 확률로 긍정 리뷰입니다.
#
# 1418
# 93.80% 확률로 긍정 리뷰입니다.
#
# 1419
# 56.19% 확률로 긍정 리뷰입니다.
#
# 1420
# 56.24% 확률로 부정 리뷰입니다.
#
# 1421
# 78.80% 확률로 긍정 리뷰입니다.
#
# 1422
# 78.09% 확률로 긍정 리뷰입니다.
