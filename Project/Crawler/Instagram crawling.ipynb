# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.options import Options
import csv
import pandas as pd
import urllib
import ssl
import random
import re
from konlpy.tag import Okt
from tqdm.notebook import tqdm

# %%
def get_tags(text, ntags=200):
    spliter = Okt()
    nouns = spliter.nouns(text)
    count = Counter(nouns)
    return_list = []
    for n, c in count.most_common(ntags):  #count로 단어의 갯수를 파악한걸 정렬해서 ntags갯수만큼 리스트로 가져온다.
        temp = {'tag': n, 'count': c}
        return_list.append(temp)
    # return return_list
    return dict(count.most_common(ntags))       #[(커피, 1200),(카페, 800)] -> {커피:1200, 카페:800}

def clean_str(s):
    hangul = re.compile('[^ ㄱ-ㅣ가-힣]+')    #한글만 남겨놓고 나머지 삭제
    s = hangul.sub(r'',str(s))

    cp = re.compile("["u"\U00010000-\U0010FFFF""]+", flags=re.UNICODE)  #BMP characters 이외 이모티콘삭제
    s=cp.sub(r'',s)

    s = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', '', s) #특수기호 삭제
 
    return s.strip()

# %%
search = input('검색어 : ')
search1 = urllib.parse.quote(search)
url = 'https://www.instagram.com/explore/tags/'+str(search1)+'/'

driver = webdriver.Chrome('C:/3pm/pythonwork/analysis/chromedriver/chromedriver') # 크롬드라이버 위치 수정
driver.implicitly_wait(1)
driver.get(url)
time.sleep(20)

driver.get(url)
time.sleep(random.randint(5, 9))
driver.find_element_by_class_name('eLAPa').click()

time.sleep(30)

with open(search+'인스타.csv', 'a', newline='', encoding='utf-8') as out:
    writer = csv.writer(out)
    replylist = []
    for temp in tqdm(range(170,1000)):
        html = driver.page_source
        soup = BeautifulSoup(html, 'lxml')
        #result = soup.find_all('a', {'class': 'xil3i'})  #해시태그가 있는 클래스
        rdata = soup.find_all('div', {'class': 'C4VMK'})  #댓글이 있는 클래스

        if len(rdata) > 0:  #댓글이 있으면
            hstr = ''   #게시글 하나의 댓글을 하나의 문장으로 저장한다.
            rresult = []
            for temp1 in rdata:
                temp1 = temp1.find_all('span')[1]
                print(temp1)
                hstr = hstr + ' ' + temp1.text
            replylist.append(hstr)
            rresult.append(hstr)

            datelist = list()
            time_raw = driver.find_element_by_css_selector('body > div._2dDPU.CkGkG > div.zZYga > div > article > div.eo2As > div.k_Q0X.I0_K8.NnvRN > a > time')
            time_info = pd.to_datetime(time_raw.get_attribute('datetime')).normalize()
            datelist.append(time_info)
            print(datelist)

            writer.writerow(datelist + rresult)
        driver.find_element_by_link_text('다음').click()  #다음 클릭
        time.sleep(random.randint(3,10)) #로딩이 느리면 시간을 좀 늘려주기 #봇으로 인식하는걸 막기 위해 랜덤으로 넣어줌
            #random.randint(3,10)

print(search1)
print(replylist)
print(datelist)
# Out:
# 검색어 : 샤오미휴대폰
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=830.0), HTML(value='')))
# <span class="">중국판 갤럭시 Z 플립! 샤오미에서 곧 출시한다!<br/><br/>중국 스마트폰 업체 샤오미가 폴더블폰을 처음<br/>출시하게 되는데, 이 폴더블폰이 삼성전자의<br/>갤럭시 Z 플립 모델과 매우 흡사하다는 소식이<br/>들려오고 있네요 ㅠㅠ<br/><br/>IT 관련 따근따근한 소식을 받고 싶다면,<br/>탑클폰 인스타를 팔로우 하시라~!!<br/><br/><a class=" xil3i" href="/explore/tags/샤오미/" tabindex="0">#샤오미</a> <a class=" xil3i" href="/explore/tags
# [Timestamp('2018-08-01 00:00:00+0000', tz='UTC')]
# <span class="" title="수정됨"><a class=" xil3i" href="/explore/tags/내꺼아님😭/" tabindex="0">#내꺼아님😭</a> <a class=" xil3i" href="/explore/tags/탐나넹/" tabindex="0">#탐나넹</a>!!!!!!<br/><a class=" xil3i" href="/explore/tags/샤오미휴대폰/" tabindex="0">#샤오미휴대폰</a>  이거이거 <a class=" xil3i" href="/explore/tags/그럴싸하쥬😆/" tabindex="0">#그럴싸하쥬😆</a> <br/>완젼 탐났던!!!!아이 <a class=" xil3i" href="/explore/tags/지문인식도됨/" tabindex="0">#지문인식도됨</a><br/><br/>좀더 꼼꼼히 볼껄 ~~~하여간 <a class=" xil3i" href="/explore/tags/가격대비좋타/" tabindex="0">#가격대비좋타</a></span>
# <span class=""><a class="notranslate" href="/hittouch1112/" tabindex="0">@hittouch1112</a> 언니언니 샤오미 17만원도 안한데용!!!! 지문인식되고 화질도 좋고 메모리도 많이들어가고 괜찮더라구용</span>
# <span class="">이거 사는것보다 개통이 힘들어요.. 설정할것도 많고 가격싼대신 수고로움이.. 그래서 제가 귀찮아서 못삼ㅋㅋ</span>
# <span class=""><a class="notranslate" href="/soomin.mari/" tabindex="0">@soomin.mari</a> 앗 진짜요?? 산애한테 물어봐야겠다뇽 ㅎㅎ</span>
# <span class=""><a class="notranslate" href="/soomin.mari/" tabindex="0">@soomin.mari</a> ㅎ 잘못 알고 계신거 같아요..기존 사용하고있는 심카드만 꽂으면 바로 사용 가능합니다😊</span>
# <span class=""><a class="notranslate" href="/khyuni/" tabindex="0">@khyuni</a> 음.. 기본전화기능외에 lte 밴드 같은건 따로 통신사 문의해야하지 않나요?</span>
# <span class=""><a class="notranslate" href="/soomin.mari/" tabindex="0">@soomin.mari</a> LG U+ 는 아예 안되구요..KT와 SKT는 사용 가능합니다. 밴드 대역은 애초에 단말기를 그 통신사에서 사용 가능한지 안한지 판단 할 때 필요하구, 그 통신사에서 사용 가능하다면 통신사에 문의 할건 없습니다^^ 아예 유심 기변으로 사용 바로 가능해요. 다만 좀 더 디테일하게 가게되면 VoLTE 지원 때문에 음성 통화때 요즘 VoLTE단말 사용자끼리 지원하는 완전 깨끗한 통화가 힘듭니다. 단말기가 미지원이 아닌사 단말기는 지원하지만 국내서는 다양한 의견이 분분하지만, 한 가지 의견으로는 국내 통신사 거치지 않은 모델만 해당 기능을 지원 한다는 얘기도있고 여러 가지 설이 있더라구요. 어쨋든 결론은 유심 꽂는것 만으로  그냥 사용은 가능합니다. LG U+ 빼구요^^</span>
# <span class=""><a class="notranslate" href="/khyuni/" tabindex="0">@khyuni</a> 아! 그거군요 volte! 듀얼심이라 알뜰폰이랑 같이 쓸까 생각했었는데 hd보이스 쓰려면 전화해서 imei불러줘야하고 어쩌고 뭐가 귀찮은게 많은듯했거든요 자세한 설명 감사드려요~ 😊🙆🙇</span>
# <span class=""><a class="notranslate" href="/soomin.mari/" tabindex="0">@soomin.mari</a> 근데 말씀 하신 것처럼 HD Voice 같은건 선택사항이구요, 그걸 등록 하려면 고객센터에 요청 해야 하는건 맞습니다. 하지만 그걸 등록 안했다고 사용 못하는건 아니구요ㅎ 어쨋든 많이 알고 계시네요ㅎㅎ</span>
# <span class="">Very cute</span>
# <span class="">오늘 핑크로 주문완료했네요 ㅎㅎ 동생꼬임에 넘어갔다지요😅😅</span>
# <span class="">관심있어서 후기등등 찾아봤었는데 언듯 봐서 제대로 알고있지는 않았네요😂 스냅 820급 부터는 volte 도 된다는거 같았는데 잘몰라서 포기했지요😥</span>
# <span class="">카카오배경화면 정보 좀 알 수 있을까요?!?!</span>
# [Timestamp('2017-03-12 00:00:00+0000', tz='UTC')]
# <span class="">샤오미 미맥스 직구<br/>가격대비 가성비 좋네 ㅋㅋ<br/><a class=" xil3i" href="/explore/tags/휴대폰/" tabindex="0">#휴대폰</a> <a class=" xil3i" href="/explore/tags/가성비갑/" tabindex="0">#가성비갑</a> <a class=" xil3i" href="/explore/tags/샤오미미맥스/" tabindex="0">#샤오미미맥스</a> <a class=" xil3i" href="/explore/tags/샤오미/" tabindex="0">#샤오미</a> <a class=" xil3i" href="/explore/tags/데일리/" tabindex="0">#데일리</a> <a class=" xil3i" href="/explore/tags/일상/" tabindex="0">#일상</a> <a class=" xil3i" href="/explore/tags/일상그램/" tabindex="0">#일상그램</a> <a class=" xil3i" href="/explore/tags/목요일/" tabindex="0">#목요일</a> <a class=" xil3i" href="/explore/tags/소통/" tabindex="0">#소통</a> <a class=" xil3i" href="/explore/tags/맞팔/" tabindex="0">#맞팔</a> <a class=" xil3i" href="/explore/tags/샤오미휴대폰/" tabindex="0">#샤오미휴대폰</a></span>
# <span class=""><a class="notranslate" href="/iboyeon3515/" tabindex="0">@iboyeon3515</a> 네 4g구요 유심만 바꿔끼우셔서 쓰시면 되요 ㅋㅋ가성비 좋아요</span>
# [Timestamp('2016-10-27 00:00:00+0000', tz='UTC')]
# <span class="">.<br/><a class=" xil3i" href="/explore/tags/샤오미휴대폰/" tabindex="0">#샤오미휴대폰</a> 카메라 나이성별이 인식댄다 ㅋ<br/>신기방기ㅋ .<br/>.<br/><a class=" xil3i" href="/explore/tags/베이징/" tabindex="0">#베이징</a> <a class=" xil3i" href="/explore/tags/bejing/" tabindex="0">#bejing</a> <a class=" xil3i" href="/explore/tags/여행/" tabindex="0">#여행</a> <a class=" xil3i" href="/explore/tags/좋은사람과/" tabindex="0">#좋은사람과</a> <a class=" xil3i" href="/explore/tags/샤오미/" tabindex="0">#샤오미</a></span>
# <span class="">이거 사기다ㅋ</span>
# <span class="">21???~~^^</span>
# <span class=""><a class="notranslate" href="/evidence_base/" tabindex="0">@evidence_base</a> 긍가바 ~ 아무폰 들고 했는디 ㅋㅋ</span>
# <span class=""><a class="notranslate" href="/yk3616/" tabindex="0">@yk3616</a> ㅋㅋ 에이 ~ 25짤언니 ㅋㅋ</span>
# <span class=""><a class="notranslate" href="/dennis.lee.5030/" tabindex="0">@dennis.lee.5030</a> ㅋㅋㅋ 기계는 거짓말많이 하지? ㅋㅋ</span>
# <span class="">스티커로좀 가리고해야지</span>
# [Timestamp('2016-09-12 00:00:00+0000', tz='UTC')]
# <span class="" title="수정됨">듀얼 USIM 샤오미<br/><br/><a class=" xil3i" href="/explore/tags/샤오미/" tabindex="0">#샤오미</a> <a class=" xil3i" href="/explore/tags/샤오미휴대폰/" tabindex="0">#샤오미휴대폰</a> <a class=" xil3i" href="/explore/tags/샤오미/" tabindex="0">#샤오미</a><br/><a class=" xil3i" href="/explore/tags/xiaomi/" tabindex="0">#xiaomi</a> <a class=" xil3i" href="/explore/tags/휴대폰/" tabindex="0">#휴대폰</a> <a class=" xil3i" href="/explore/tags/핸드폰/" tabindex="0">#핸드폰</a></span>
# <span class="">이거한국에서 사용가능?</span>
# <span class="">굿굿 ! 잘봤습니다! ^^😺😸</span>
# <span class="">우와아앙~~~~</span>
# [Timestamp('2016-08-03 00:00:00+0000', tz='UTC')]
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-5-372832ccc5c4> in <module>
#      40
#      41             writer.writerow(datelist + rresult)
# ---> 42         driver.find_element_by_link_text('다음').click()  #다음 클릭
#      43         time.sleep(random.randint(3,10)) #로딩이 느리면 시간을 좀 늘려주기 #봇으로 인식하는걸 막기 위해 랜덤으로 넣어줌
#      44             #random.randint(3,10)
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     426             element = driver.find_element_by_link_text('Sign In')
#     427         """
# --> 428         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     429
#     430     def find_elements_by_link_text(self, text):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     974                 by = By.CSS_SELECTOR
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#     978             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"다음"}
#   (Session info: chrome=92.0.4515.131)

# %%
# 파일명 입력
data = pd.read_csv("갤럭시기어인스타.csv", header = None)
data
# Out:
#                              0  \
# 0    2020-11-24 00:00:00+00:00
# 1    2021-02-19 00:00:00+00:00
# 2    2021-02-17 00:00:00+00:00
# 3    2020-11-23 00:00:00+00:00
# 4    2020-11-23 00:00:00+00:00
# ..                         ...
# 438  2019-06-21 00:00:00+00:00
# 439  2019-06-21 00:00:00+00:00
# 440  2019-06-21 00:00:00+00:00
# 441  2019-06-19 00:00:00+00:00
# 442  2019-06-17 00:00:00+00:00
#
#                                                      1
# 0     많이 기다리셨죠?!가죽루프 "크림 베이지" 재입고 와...
# 1     [정신의학신문 계정 팔로우, 좋아요 부ᄐ...
# 2     #셀프선물 #세뱃돈플렉스 집에만 있기 너어~무 지루하고 따분한 요즘!셀프선물로 분...
# 3     인디고/오렌지 컬러조합 완벽한 가죽스트랩✨ #유세라샵 #갤럭시워치 #갤럭시워치3 ...
# 4     -첫 조카가 생겼을 때 넘 예뻐서 물고 빨고 했는데벌써 그 아기가 커서 오늘 나한...
# ..                                                 ...
# 438   ⌚ MECHANICAL MESH 👉 Find on #Samsung #Galaxy ...
# 439   ⌚ MECHANICAL MESH 👉 Find on #Samsung #Galaxy ...
# 440   ⌚ MECHANICAL MESH 👉 Find on #Samsung #Galaxy ...
# 441   아빠의 특별주문 ♥ 갤럭시기어 스트랩 바꾸기~~ 스틸로 바꿔드렸는데요, 골드제품 ...
# 442   지난번에 출근길에 공항철도 에스컬레이터를 막 뛰어내려가다가 귀에서 블루투스 이어폰...
#
# [443 rows x 2 columns]
